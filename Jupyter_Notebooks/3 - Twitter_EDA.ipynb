# %%
import sys
sys.path.append("..")
# Import necessary python packages and functions
from Py_Files.imports import *
from Py_Files.max_range import *
# %matplotlib inline

# %%
df = pd.read_csv('../Data/Twitter_Data_Final.csv', index_col=0)

# %%
df.shape
# Out:
# (11739, 29)

# %%
df.describe().T
# Out:
#                                                count           mean            std     min     25%      50%       75%        max
# tweets_favorite_count                        11739.0       1.730641      23.288991     0.0     0.0      0.0       0.0     1755.0
# tweets_user_friends_count                    11739.0    2182.340830    2017.331159     0.0   670.0   1566.0    3388.0    15361.0
# tweets_user_followers_count                  11739.0    3221.494591    2183.035365   945.0  1547.5   2385.0    4365.5     9998.0
# tweets_user_favourites_count                 11739.0   33263.219525   71766.249295     0.0   656.0   6773.0   33300.0  1311211.0
# tweets_user_statuses_count                   11739.0  157686.133061  416013.843387     2.0  9541.5  32168.0  103785.0  3441757.0
# deets_reply_count                            11739.0       0.859954      62.739946     0.0     0.0      0.0       0.0     6766.0
# ...

# %%
p_df = df[['deets_text_character_length', 'retweet_class']]
p_df2 = df[['tweets_user_favourites_count', 'retweet_class']]
p_df3 = df[['users_listed_count', 'retweet_class']]

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(15,20) 
plt.axis([0,2,0,325])
ax.yaxis.set_major_locator(ticker.MultipleLocator(10))
ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
sns.boxplot(x="retweet_class", y="deets_text_character_length", data=p_df, color='#00acee')
plt.xlabel('Retweet Category', fontsize=40, weight='bold')
plt.ylabel('Tweet Character Length', fontsize=40, weight='bold')
plt.savefig('../Images/Tweet_Character_Length3.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %%
p_df.loc[df['retweet_class'] == 2].sum()
# Out:
# deets_text_character_length    118991.0
# retweet_class                    1716.0
# dtype: float64

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(15,20) 
plt.axis([0,2,0,275000])
ax.yaxis.set_major_locator(ticker.MultipleLocator(25000))
ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
sns.boxplot(x="retweet_class", y="tweets_user_favourites_count", data=p_df2, color='#00acee')
plt.xlabel('Retweet Category', fontsize=40, weight='bold')
plt.ylabel('User Favourites Count', fontsize=40, weight='bold')
plt.savefig('../Images/User_Favorites_Count3.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(15,20) 
plt.axis([0,2,0,350])
ax.yaxis.set_major_locator(ticker.MultipleLocator(50))
ax.yaxis.set_major_formatter(ticker.ScalarFormatter())
sns.boxplot(x="retweet_class", y="users_listed_count", data=p_df3, color='#00acee')
plt.xlabel('Retweet Category', fontsize=40, weight='bold')
plt.ylabel('User Listed Count', fontsize=40, weight='bold')
plt.savefig('../Images/User_Listed_Count3.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %% [markdown]
# - Distribution (Hist) of retweets
# - Cumulative Density Function of Retweets (retweet on x, cum_prob on y)

# %%
df2 = pd.read_csv('../Data/Twitter_Data.csv', index_col=0)

# %%
df2.head()
# Out:
#             tweets_created_at            tweets_id  tweets_is_quote_status  tweets_favorited  tweets_favorite_count  tweets_retweeted  tweets_retweet_count  tweets_user_id tweets_user_name tweet_user_screen_name       tweets_user_location                            tweets_user_description  tweets_user_friends_count  tweets_user_followers_count  tweets_user_favourites_count  tweets_user_geo_enabled  tweets_user_verified  tweets_user_statuses_count tweets_user_profile_background_color tweets_user_profile_text_color  tweets_user_profile_use_background_image  tweets_user_has_extended_profile  tweets_user_default_profile_image  deets_possibly_sensitive                                         deets_text  deets_reply_count  deets_like_count  deets_quote_count     users_id           users_created_at                                  users_description      users_name users_username  users_verified  users_protected                users_url  users_followers_count  users_following_count  \
# ...

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,10) 
sns.distplot(df2['tweets_retweet_count'], color='#00acee', kde=False)
plt.xlabel('Number of Retweets', fontsize=40, weight='bold')
plt.ylabel('Number of Tweets', fontsize=40, weight='bold')
plt.savefig('../Images/Retweet_Hist_All.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,10)
plt.axis([0,100,0,1200])
sns.distplot(df2['tweets_retweet_count'], color='#00acee', kde=False, bins=10000)
plt.xlabel('Number of Retweets', fontsize=40, weight='bold')
plt.ylabel('Number of Tweets', fontsize=40, weight='bold')
plt.savefig('../Images/Retweet_Hist_100.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,10)
plt.axis([0,75,0,1])
plt.hist(df2['tweets_retweet_count'], bins=1000000, density=True, cumulative=True, fill=True, label='CDF',
         histtype='step', alpha=0.8, color='#00acee')
plt.xlabel('Retweets', fontsize=40, weight='bold')
plt.ylabel('% Likelihood', fontsize=40, weight='bold')
plt.savefig('../Images/CDF_100.pdf', transparent=True, dpi=150, bbox_inches='tight')

# %%
sns.set(font_scale = 5)
sns.set(style="whitegrid", color_codes=True, font_scale = 1.7)
fig, ax = plt.subplots()
fig.set_size_inches(30,10)
plt.hist(df2['tweets_retweet_count'], bins=1000000, density=True, cumulative=True, fill=True, label='CDF',
         histtype='step', alpha=0.8, color='#00acee')
plt.xlabel('Retweets', fontsize=40, weight='bold')
plt.ylabel('% Likelihood', fontsize=40, weight='bold')
plt.savefig('../Images/CDF_All.pdf', transparent=True, dpi=150, bbox_inches='tight')
