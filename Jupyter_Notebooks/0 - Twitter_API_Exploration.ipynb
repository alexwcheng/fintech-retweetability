# %% [markdown]
# # Twitter API

# %% [markdown]
# **Rules:**
# - Request window is 15 minute.
# - Requests per 15 minutes is as little as 15 requests, and as much as 900 requests.
# - See Twitter rate limit documentation here: https://developer.twitter.com/en/docs/basics/rate-limiting
# - See Twitter Basic API endpoint documentation here: https://developer.twitter.com/en/docs/basics/rate-limits
# - See complete Twitter API Reference Index here: https://developer.twitter.com/en/docs/api-reference-index

# %% [markdown]
# ### Twitter GET Endpoints
#
# - **/1.1/search/tweets.json**
#     - Returns a collection of relevant Tweets matching a specified query. The Twitter Search API searches against a sampling of recent Tweets published in the past 7 days. It’s important to know that the standard search API is focused on relevance and not completeness.
#         - id (of the tweet)
#         - id (of the user)
#         - name (of the user)
#         - id (user_mentions)
#         - name (user_mentions)
#         - text (of the tweet)
#         - location
#         - entities
#         - followers_count (user)
#         - friends_count (user)
#         - listed_count
#         - favourites_count
#         - statuses_count
#         - retweet_count (of the tweet)
#         - favorite_count
#
#
# - **/1.1/trends/place.json**
#     - Returns the top 50 trending topics for a specific WOEID, if trending information is available for it. The tweet_volume for the last 24 hours is also returned for many trends if this is available.
#         - name (of the trend)
#         - tweet_volume
#
#
# ### Twitter Labs GET Endpoints
#
#
# - **/labs/1/users**
#     - Returns a variety of information about one or more Users specified by the requested IDs or usernames.
#         - description
#         - id
#         - location
#         - name
#         - username
#         - stats
#             - followers_count
#             - following_count
#             - tweet_count
#             - listed_count
#
#
# - **/labs/1/tweets**
#     - Returns a variety of information about the Tweet specified by the requested ID or list of IDs.
#         - attachments (to the tweet)
#         - stats (for the tweet)
#             - retweet_count
#             - reply_count
#             - like_count
#             - quote_count
#         - text (tweet content)
#
#
# - **/labs/1/tweets/search**
#     - Returns Tweets from the last 7 days that match a search query (max 100 results per call).
#         - all keys from /search/tweets.json
#         - next_token (to paginate)
#
#
# - **/labs/1/tweets/stream/filter**
#     - Streams Tweets in real-time based on a specific set of filter rules.
#         - all keys from /search/tweets.json
#         - next_token (to paginate)
#
#
# - **/labs/1/tweets/stream/sample**
#     - Streams about 1% of all Tweets in real-time. (TAKES A LONG TIME: >10 MINUTES)
#         - ???
#         - ???
#         - ???

# %% [markdown]
# ### Workflow
# - **Step 1.** Use **/1.1/search/tweets.json** endpoint to get tweets from the past 7 days for a particular query.
#
# - **Step 2.** Use **/labs/1/tweets** to get detailed tweet metrics using the tweet ID extracted from Step 1.
#
# - **Step 3.** Use **/labs/1/users** to get detailed info about the users for the tweets in our query from Step 1.
#
# - **Step 4.** Merge all data into one DataFrame and export to .CSV.

# %% [markdown]
# ___

# %% [markdown]
# # Use Case

# %% [markdown]
# - Classify if a **tweet** will cross a **high threshold of retweets** using certain predictors (hashtags, likes, total user tweets, followers, reply count, quote count, location, etc...)

# %% [markdown]
# ___

# %% [markdown]
# # Business Cases

# %% [markdown]
# - **SCENARIO 1: A startup tech company just deployed a new mobile app and wants to get the word out. They want to maximize retweets of their "launch" tweet about their new app. They want to know how to make a tweet cross a high threshold of retweets.**
#
#
# - **Pulling Tweets Strategy: (7 day history of tweets)**
#     - Randomly "live stream" all tweets 1%...what are other things that people are talking about?
#     - OR:
#     - Search tweets by query criteria:
#         - The word "tech"
#         - The word "app"
#         - The word "download"
#         - The word "phone"
#         - The word "tablet"
#         - The word "apple"
#         - The word "android"
#         - The word "App Store"
#         - The word "Google Play Store"
#         - The word "mobile"
#
#
# - **SCENARIO 2: A startup financial tech company just deployed a new mobile app and wants to get the word out globally. They want to maximize retweets of their "launch" tweet about their new app. They want to know how to make a tweet cross a high threshold of retweets.**
#
#
# - **Pulling Financial Tweets Strategy: (7 day history of tweets)**
#     - Search tweets by query criteria:
#         - The word "investing"
#         - The word "mobile transfer"
#         - The word "mobile wallet"
#         - The word "online banking"
#         - The word "trading"
#         - The word "insurance"
#         - The word "financial"
#         - The word "money management"
#         - The word "stocks"
#         - The word "transaction"

# %% [markdown]
# ___

# %% [markdown]
# # Setup

# %%
import requests
import json

# %%
client_key = 'DaaVvjhdnfMrmU7cJcciQQuil'
client_secret = 'etyYWRFf6wwyYSJvjyr2JxdcxHzlzfnsPcBdOq68GY9qwVf6RH'

import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

# %%
auth_resp.status_code
# Out:
# 200

# %%
auth_resp.json().keys()
# Out:
# dict_keys(['token_type', 'access_token'])

# %%
auth_resp.json()
# Out:
# {'token_type': 'bearer',
#  'access_token': 'AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz'}

# %% [markdown]
# ___

# %% [markdown]
# # Test Call To /1.1/search/tweets.json Endpoint

# %% [markdown]
# **Returns a collection of relevant Tweets matching a specified query.**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'q': 'General Election',
    'result_type': 'recent',
    'count': 2
}

search_url = '{}1.1/search/tweets.json'.format(base_url)

search_resp = requests.get(search_url, headers=search_headers, params=search_params)
response = search_resp.json()
response
# Out:
# {'statuses': [{'created_at': 'Fri Jan 31 00:22:27 +0000 2020',
#    'id': 1223038801519562752,
#    'id_str': '1223038801519562752',
#    'text': "RT @jvgraz: While centrists clutch their pearls over Bernie's fictional oppo research file, just imagine this video played on a loop during…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jvgraz',
#       'name': "Plain Ol' Johnny Graz",
#       'id': 16959075,
#       'id_str': '16959075',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 975373644959449089,
#     'id_str': '975373644959449089',
#     'name': 'theMAOrganic',
#     'screen_name': 'MaOrganic',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5,
#     'friends_count': 119,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 18 14:09:33 +0000 2018',
#     'favourites_count': 1078,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 857,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jan 30 05:23:03 +0000 2020',
#     'id': 1222752060040286209,
#     'id_str': '1222752060040286209',
#     'text': "While centrists clutch their pearls over Bernie's fictional oppo research file, just imagine this video played on a… https://t.co/9jtvCBgZug",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9jtvCBgZug',
#        'expanded_url': 'https://twitter.com/i/web/status/1222752060040286209',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 16959075,
#      'id_str': '16959075',
#      'name': "Plain Ol' Johnny Graz",
#      'screen_name': 'jvgraz',
#      'location': 'California, USA',
#      'description': 'Veteran of NeXT, Apple, and Pixar. Creator of XCode. Parrot whisperer. Jazz pianist. Kitchen guru.  Chief Technical Officer to the @Sema4Texas campaign.',
#      'url': 'https://t.co/qxZrYDmib4',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/qxZrYDmib4',
#          'expanded_url': 'http://semafortexas.com',
#          'display_url': 'semafortexas.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 21259,
#      'friends_count': 9316,
#      'listed_count': 290,
#      'created_at': 'Fri Oct 24 23:41:31 +0000 2008',
#      'favourites_count': 94696,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 124061,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/995535838426492928/htFBNJYh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/995535838426492928/htFBNJYh_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16959075/1558992627',
#      'profile_link_color': '58A6FF',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'F6F6F6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1222684242364289030,
#     'quoted_status_id_str': '1222684242364289030',
#     'quoted_status': {'created_at': 'Thu Jan 30 00:53:34 +0000 2020',
#      'id': 1222684242364289030,
#      'id_str': '1222684242364289030',
#      'text': 'This is so fucking funny. Worth watching the whole thing but even just the first segment is devastating. https://t.co/mNEu0Hf1pU',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1222540279783350272,
#         'id_str': '1222540279783350272',
#         'indices': [105, 128],
#         'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1222540279783350272/img/KUXsvDeeWOL1KiNJ.jpg',
#         'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1222540279783350272/img/KUXsvDeeWOL1KiNJ.jpg',
#         'url': 'https://t.co/mNEu0Hf1pU',
#         'display_url': 'pic.twitter.com/mNEu0Hf1pU',
#         'expanded_url': 'https://twitter.com/shaunking/status/1222579400664850432/video/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#          'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#         'source_status_id': 1222579400664850432,
#         'source_status_id_str': '1222579400664850432',
#         'source_user_id': 755113,
#         'source_user_id_str': '755113'}]},
#      'extended_entities': {'media': [{'id': 1222540279783350272,
#         'id_str': '1222540279783350272',
#         'indices': [105, 128],
#         'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1222540279783350272/img/KUXsvDeeWOL1KiNJ.jpg',
#         'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1222540279783350272/img/KUXsvDeeWOL1KiNJ.jpg',
#         'url': 'https://t.co/mNEu0Hf1pU',
#         'display_url': 'pic.twitter.com/mNEu0Hf1pU',
#         'expanded_url': 'https://twitter.com/shaunking/status/1222579400664850432/video/1',
#         'type': 'video',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#          'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#         'source_status_id': 1222579400664850432,
#         'source_status_id_str': '1222579400664850432',
#         'source_user_id': 755113,
#         'source_user_id_str': '755113',
#         'video_info': {'aspect_ratio': [16, 9],
#          'duration_millis': 292170,
#          'variants': [{'content_type': 'application/x-mpegURL',
#            'url': 'https://video.twimg.com/amplify_video/1222540279783350272/pl/fPm1I0SUQBOfvI5y.m3u8?tag=13'},
#           {'bitrate': 832000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/amplify_video/1222540279783350272/vid/640x360/Ns6o9zq6vQ6ufTdr.mp4?tag=13'},
#           {'bitrate': 2176000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/amplify_video/1222540279783350272/vid/1280x720/KGEa9Obmvm5DEmH-.mp4?tag=13'},
#           {'bitrate': 288000,
#            'content_type': 'video/mp4',
#            'url': 'https://video.twimg.com/amplify_video/1222540279783350272/vid/480x270/DJkZD6E-4aDOsJ4f.mp4?tag=13'}]},
#         'additional_media_info': {'title': 'In 1987 Joe Biden was proven to be a pathological liar',
#          'description': 'In 1987, when Joe Biden was running for President, he did not get caught in a lie - he got caught in at least 9 lies. \n\nThey engulfed his entire campaign and almost derailed his political career. ',
#          'call_to_actions': {'visit_site': {'url': 'https://shaunking.substack.com/p/2-truths-and-31-lies-joe-biden-has'}},
#          'embeddable': True,
#          'monetizable': False}}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 277880167,
#       'id_str': '277880167',
#       'name': 'Eoin Higgins',
#       'screen_name': 'EoinHiggins_',
#       'location': '',
#       'description': 'It\'s pronounced "Owen." Senior Editor, Staff Writer @commondreams. Opinions my own. eoin@commondreams.org eoinhiggins@gmail.com',
#       'url': None,
#       'entities': {'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 28596,
#       'friends_count': 953,
#       'listed_count': 481,
#       'created_at': 'Wed Apr 06 06:09:53 +0000 2011',
#       'favourites_count': 53400,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': True,
#       'statuses_count': 15961,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': '000000',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1138438735329189889/4s9Gq8tm_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138438735329189889/4s9Gq8tm_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/277880167/1580005185',
#       'profile_link_color': '7FDBB6',
#       'profile_sidebar_border_color': '000000',
#       'profile_sidebar_fill_color': '000000',
#       'profile_text_color': '000000',
#       'profile_use_background_image': False,
#       'has_extended_profile': True,
#       'default_profile': False,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 7281,
#      'favorite_count': 21741,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 193,
#     'favorite_count': 501,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1222684242364289030,
#    'quoted_status_id_str': '1222684242364289030',
#    'retweet_count': 193,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 00:22:26 +0000 2020',
#    'id': 1223038795181723648,
#    'id_str': '1223038795181723648',
#    'text': 'RT @MattMinerXVX: @landis_melinda @shaunking @JoeBiden Would you rather Trump’s team expose these lies in the General election or Shaun do…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'MattMinerXVX',
#       'name': 'Matt Miner',
#       'id': 3439061,
#       'id_str': '3439061',
#       'indices': [3, 16]},
#      {'screen_name': 'landis_melinda',
#       'name': '11CatsAgainstNazis&Hidy🌈OTB',
#       'id': 4260487493,
#       'id_str': '4260487493',
#       'indices': [18, 33]},
#      {'screen_name': 'shaunking',
#       'name': 'Shaun King',
#       'id': 755113,
#       'id_str': '755113',
#       'indices': [34, 44]},
#      {'screen_name': 'JoeBiden',
#       'name': 'Joe Biden (Text Join to 30330)',
#       'id': 939091,
#       'id_str': '939091',
#       'indices': [45, 54]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1207899384366555136,
#     'id_str': '1207899384366555136',
#     'name': 'dr.nec',
#     'screen_name': 'drnec3',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8,
#     'friends_count': 60,
#     'listed_count': 0,
#     'created_at': 'Fri Dec 20 05:44:16 +0000 2019',
#     'favourites_count': 1487,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 173,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jan 30 12:16:16 +0000 2020',
#     'id': 1222856048677138435,
#     'id_str': '1222856048677138435',
#     'text': '@landis_melinda @shaunking @JoeBiden Would you rather Trump’s team expose these lies in the General election or Sha… https://t.co/Ngkc8IaO6I',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'landis_melinda',
#        'name': '11CatsAgainstNazis&Hidy🌈OTB',
#        'id': 4260487493,
#        'id_str': '4260487493',
#        'indices': [0, 15]},
#       {'screen_name': 'shaunking',
#        'name': 'Shaun King',
#        'id': 755113,
#        'id_str': '755113',
#        'indices': [16, 26]},
#       {'screen_name': 'JoeBiden',
#        'name': 'Joe Biden (Text Join to 30330)',
#        'id': 939091,
#        'id_str': '939091',
#        'indices': [27, 36]}],
#      'urls': [{'url': 'https://t.co/Ngkc8IaO6I',
#        'expanded_url': 'https://twitter.com/i/web/status/1222856048677138435',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1222851423756603393,
#     'in_reply_to_status_id_str': '1222851423756603393',
#     'in_reply_to_user_id': 4260487493,
#     'in_reply_to_user_id_str': '4260487493',
#     'in_reply_to_screen_name': 'landis_melinda',
#     'user': {'id': 3439061,
#      'id_str': '3439061',
#      'name': 'Matt Miner',
#      'screen_name': 'MattMinerXVX',
#      'location': 'South Queens, NYC',
#      'description': 'NY Times featured comic writer/editor - Ringo Nominated. Field Director #NY5 @Shaniyat2020, Dog rescuer, @GWAR’s comic pal, aging punk, he/him Opinions=mine. 🌹',
#      'url': 'https://t.co/HgX8FSYCzU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/HgX8FSYCzU',
#          'expanded_url': 'http://MattMinerXVX.com',
#          'display_url': 'MattMinerXVX.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5307,
#      'friends_count': 1329,
#      'listed_count': 152,
#      'created_at': 'Wed Apr 04 16:47:03 +0000 2007',
#      'favourites_count': 42388,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 42848,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1099034619868049410/NShmkNIF_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1099034619868049410/NShmkNIF_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3439061/1573991490',
#      'profile_link_color': '000000',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 250,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.032,
#   'max_id': 1223038801519562752,
#   'max_id_str': '1223038801519562752',
#   'next_results': '?max_id=1223038795181723647&q=General%20Election&count=2&include_entities=1&result_type=recent',
#   'query': 'General+Election',
#   'refresh_url': '?since_id=1223038801519562752&q=General%20Election&result_type=recent&include_entities=1',
#   'count': 2,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# with open('search_tweets.json', 'w', encoding='utf-8') as f:
#     json.dump(response, f, ensure_ascii=False, indent=4)

# %%
for x in response['statuses']:
    print(x['text'] + '\n')
# Out:
# RT @peterdaou: FACT CHECK: IS #BERNIE VETTED?
#
# I've forcefully rebutted the myth that @BernieSanders faces a damaging oppo dump in a genera…
#
# RT @damian_from: Starmer and Thornberry got it terribly wrong.
#
# Their refusal to respect the largest mandate in UK history (17.4m leave vot…

# %%
#two primary keys in the response
response.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %% [markdown]
# ### "statuses"

# %%
#what keys are in the "statuses" dictionary?
list(response['statuses'][0].keys())
# Out:
# ['created_at',
#  'id',
#  'id_str',
#  'text',
#  'truncated',
#  'entities',
#  'metadata',
#  'source',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'in_reply_to_screen_name',
#  'user',
#  'geo',
#  'coordinates',
#  'place',
#  'contributors',
#  'retweeted_status',
#  'is_quote_status',
#  'retweet_count',
#  'favorite_count',
#  'favorited',
#  'retweeted',
#  'lang']

# %%
#looks like the text of the tweet is cut off after a certain number of characters.
#there is also some clean up involved with "\n" inserted instead of spaces.

response['statuses'][0]['text'].replace('\n',' ')
# Out:
# "RT @peterdaou: FACT CHECK: IS #BERNIE VETTED?  I've forcefully rebutted the myth that @BernieSanders faces a damaging oppo dump in a genera…"

# %%
#"entities" shows who the tweet "@" mentioned, and which "#" hashtags they used in the tweet.
response['statuses'][0]['entities']
# Out:
# {'hashtags': [{'text': 'BERNIE', 'indices': [30, 37]}],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'peterdaou',
#    'name': 'Peter Daou',
#    'id': 18464266,
#    'id_str': '18464266',
#    'indices': [3, 13]},
#   {'screen_name': 'BernieSanders',
#    'name': 'Bernie Sanders',
#    'id': 216776631,
#    'id_str': '216776631',
#    'indices': [86, 100]}],
#  'urls': []}

# %%
#what's in "metadata"?
response['statuses'][0]['metadata']
# Out:
# {'iso_language_code': 'en', 'result_type': 'recent'}

# %%
#"user" key has a LOT of juicy information about the Twitter user.
#name, followers, friends, date Twitter account was made, total number of "statuses", profile image, etc...
response['statuses'][0]['user']
# Out:
# {'id': 773966501451890688,
#  'id_str': '773966501451890688',
#  'name': 'Pat Miguel Tomaino',
#  'screen_name': 'Pat_Tomaino',
#  'location': 'Boston',
#  'description': 'Research & activism at @ZevinAssetMgmt. Mexican American socialist he/him. Board/adviser: @UUA, @UjimaBoston. Former researcher: Warren 2012, @1199SEIU 🌹🇲🇽\U0001f9a7',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1325,
#  'friends_count': 5001,
#  'listed_count': 25,
#  'created_at': 'Thu Sep 08 19:29:28 +0000 2016',
#  'favourites_count': 20103,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 14230,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1047233129621147648/8A5arum6_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047233129621147648/8A5arum6_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773966501451890688/1561642799',
#  'profile_link_color': '191970',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None,
#  'translator_type': 'none'}

# %%
#source of tweet (iPhone, Android, etc...)
response['statuses'][0]['source']
# Out:
# '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'

# %%
#note that the following keys have no data...Twitter probably restricts this info.
# 'geo'
# 'coordinates'
# 'place'
# 'contributors'

# %%
response['statuses'][0]['retweeted_status']
# Out:
# {'created_at': 'Wed Jan 29 14:19:35 +0000 2020',
#  'id': 1222524697117646849,
#  'id_str': '1222524697117646849',
#  'text': "FACT CHECK: IS #BERNIE VETTED?\n\nI've forcefully rebutted the myth that @BernieSanders faces a damaging oppo dump in… https://t.co/mjiV2VOJiO",
#  'truncated': True,
#  'entities': {'hashtags': [{'text': 'BERNIE', 'indices': [15, 22]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'BernieSanders',
#     'name': 'Bernie Sanders',
#     'id': 216776631,
#     'id_str': '216776631',
#     'indices': [71, 85]}],
#   'urls': [{'url': 'https://t.co/mjiV2VOJiO',
#     'expanded_url': 'https://twitter.com/i/web/status/1222524697117646849',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [117, 140]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 18464266,
#   'id_str': '18464266',
#   'name': 'Peter Daou',
#   'screen_name': 'peterdaou',
#   'location': '',
#   'description': 'War survivor | Author | Keyboardist @DevotionWork | Husband to @LeelaDaou | Adviser to @LindseyBoylan, @VoteAshcraft, @RebeccaforWA, @DarrigoMelanie.',
#   'url': 'http://t.co/PAymxiYMXb',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/PAymxiYMXb',
#       'expanded_url': 'http://peterdaou.com',
#       'display_url': 'peterdaou.com',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 286072,
#   'friends_count': 1080,
#   'listed_count': 3635,
#   'created_at': 'Tue Dec 30 00:21:14 +0000 2008',
#   'favourites_count': 35300,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 82940,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '709397',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1201935988303499271/A8TvCLQ3_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201935988303499271/A8TvCLQ3_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18464266/1556539249',
#   'profile_link_color': '30547D',
#   'profile_sidebar_border_color': '86A4A6',
#   'profile_sidebar_fill_color': 'A0C5C7',
#   'profile_text_color': '4E6D83',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 661,
#  'favorite_count': 2555,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
response['statuses'][0]['retweet_count']
# Out:
# 661

# %%
response['statuses'][0]['favorite_count']
# Out:
# 0

# %%
response['statuses'][0]['retweeted']
# Out:
# False

# %%
response['statuses'][0]['lang']
# Out:
# 'en'

# %% [markdown]
# ___

# %% [markdown]
# ### "search_metadata"

# %%
#what keys are in the "search_metadata" dictionary?
list(response['search_metadata'].keys())
# Out:
# ['completed_in',
#  'max_id',
#  'max_id_str',
#  'next_results',
#  'query',
#  'refresh_url',
#  'count',
#  'since_id',
#  'since_id_str']

# %%
response['search_metadata']
# Out:
# {'completed_in': 0.022,
#  'max_id': 1222603464804589569,
#  'max_id_str': '1222603464804589569',
#  'next_results': '?max_id=1222603459377205247&q=General%20Election&count=2&include_entities=1&result_type=recent',
#  'query': 'General+Election',
#  'refresh_url': '?since_id=1222603464804589569&q=General%20Election&result_type=recent&include_entities=1',
#  'count': 2,
#  'since_id': 0,
#  'since_id_str': '0'}

# %% [markdown]
# # Test Call To /1.1/trends/place.json Endpoint

# %% [markdown]
# **Returns the top 50 trending topics for a specific WOEID, if trending information is available for it. The tweet_volume for the last 24 hours is also returned for many trends if this is available.**
#
# The response is an array of trend objects that encode the name of the trending topic, the query parameter that can be used to search for the topic on Twitter Search, and the Twitter Search URL.

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'id': '1'
}

search_url = 'https://api.twitter.com/1.1/trends/place.json'

request_0 = requests.get(search_url, headers=search_headers, params=search_params)
trends = request_0.json()
trends
# Out:
# [{'trends': [{'name': '#BBBB20',
#     'url': 'http://twitter.com/search?q=%23BBBB20',
#     'promoted_content': None,
#     'query': '%23BBBB20',
#     'tweet_volume': 73478},
#    {'name': '#AEWDynamite',
#     'url': 'http://twitter.com/search?q=%23AEWDynamite',
#     'promoted_content': None,
#     'query': '%23AEWDynamite',
#     'tweet_volume': 19901},
#    {'name': 'Marcela',
#     'url': 'http://twitter.com/search?q=Marcela',
#     'promoted_content': None,
#     'query': 'Marcela',
#     'tweet_volume': 281772},
#    {'name': '#BellLetsTaIk',
#     'url': 'http://twitter.com/search?q=%23BellLetsTaIk',
#     'promoted_content': None,
#     'query': '%23BellLetsTaIk',
#     'tweet_volume': 21218},
#    {'name': '#sbgcbud',
#     'url': 'http://twitter.com/search?q=%23sbgcbud',
#     'promoted_content': None,
#     'query': '%23sbgcbud',
#     'tweet_volume': 12872},
#    {'name': '#RokuSurroundSound',
#     'url': 'http://twitter.com/search?q=%23RokuSurroundSound',
#     'promoted_content': None,
#     'query': '%23RokuSurroundSound',
#     'tweet_volume': None},
#    {'name': 'Nenê',
#     'url': 'http://twitter.com/search?q=Nen%C3%AA',
#     'promoted_content': None,
#     'query': 'Nen%C3%AA',
#     'tweet_volume': 64751},
#    {'name': 'São Luiz',
#     'url': 'http://twitter.com/search?q=%22S%C3%A3o+Luiz%22',
#     'promoted_content': None,
#     'query': '%22S%C3%A3o+Luiz%22',
#     'tweet_volume': None},
#    {'name': 'Osorio',
#     'url': 'http://twitter.com/search?q=Osorio',
#     'promoted_content': None,
#     'query': 'Osorio',
#     'tweet_volume': None},
#    {'name': 'Traer',
#     'url': 'http://twitter.com/search?q=Traer',
#     'promoted_content': None,
#     'query': 'Traer',
#     'tweet_volume': 16467},
#    {'name': 'Leanne',
#     'url': 'http://twitter.com/search?q=Leanne',
#     'promoted_content': None,
#     'query': 'Leanne',
#     'tweet_volume': 125490},
#    {'name': 'Coimbra',
#     'url': 'http://twitter.com/search?q=Coimbra',
#     'promoted_content': None,
#     'query': 'Coimbra',
#     'tweet_volume': None},
#    {'name': 'Oladipo',
#     'url': 'http://twitter.com/search?q=Oladipo',
#     'promoted_content': None,
#     'query': 'Oladipo',
#     'tweet_volume': 33844},
#    {'name': 'Kraken',
#     'url': 'http://twitter.com/search?q=Kraken',
#     'promoted_content': None,
#     'query': 'Kraken',
#     'tweet_volume': 13127},
#    {'name': 'Thiago Galhardo',
#     'url': 'http://twitter.com/search?q=%22Thiago+Galhardo%22',
#     'promoted_content': None,
#     'query': '%22Thiago+Galhardo%22',
#     'tweet_volume': None},
#    {'name': 'Commanders in Chief',
#     'url': 'http://twitter.com/search?q=%22Commanders+in+Chief%22',
#     'promoted_content': None,
#     'query': '%22Commanders+in+Chief%22',
#     'tweet_volume': None},
#    {'name': 'Jason Whitlock',
#     'url': 'http://twitter.com/search?q=%22Jason+Whitlock%22',
#     'promoted_content': None,
#     'query': '%22Jason+Whitlock%22',
#     'tweet_volume': None},
#    {'name': 'Estética E-Girl',
#     'url': 'http://twitter.com/search?q=%22Est%C3%A9tica+E-Girl%22',
#     'promoted_content': None,
#     'query': '%22Est%C3%A9tica+E-Girl%22',
#     'tweet_volume': None},
#    {'name': 'Hernanes',
#     'url': 'http://twitter.com/search?q=Hernanes',
#     'promoted_content': None,
#     'query': 'Hernanes',
#     'tweet_volume': None},
#    {'name': 'Cancela Jesus',
#     'url': 'http://twitter.com/search?q=%22Cancela+Jesus%22',
#     'promoted_content': None,
#     'query': '%22Cancela+Jesus%22',
#     'tweet_volume': 16164},
#    {'name': 'American Heartland',
#     'url': 'http://twitter.com/search?q=%22American+Heartland%22',
#     'promoted_content': None,
#     'query': '%22American+Heartland%22',
#     'tweet_volume': None},
#    {'name': 'リメンバーミー',
#     'url': 'http://twitter.com/search?q=%E3%83%AA%E3%83%A1%E3%83%B3%E3%83%90%E3%83%BC%E3%83%9F%E3%83%BC',
#     'promoted_content': None,
#     'query': '%E3%83%AA%E3%83%A1%E3%83%B3%E3%83%90%E3%83%BC%E3%83%9F%E3%83%BC',
#     'tweet_volume': 10568},
#    {'name': 'Winter Package',
#     'url': 'http://twitter.com/search?q=%22Winter+Package%22',
#     'promoted_content': None,
#     'query': '%22Winter+Package%22',
#     'tweet_volume': 52126},
#    {'name': '#ラスボス度診断',
#     'url': 'http://twitter.com/search?q=%23%E3%83%A9%E3%82%B9%E3%83%9C%E3%82%B9%E5%BA%A6%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23%E3%83%A9%E3%82%B9%E3%83%9C%E3%82%B9%E5%BA%A6%E8%A8%BA%E6%96%AD',
#     'tweet_volume': None},
#    {'name': '#큥_데뷔8주년_축하해',
#     'url': 'http://twitter.com/search?q=%23%ED%81%A5_%EB%8D%B0%EB%B7%948%EC%A3%BC%EB%85%84_%EC%B6%95%ED%95%98%ED%95%B4',
#     'promoted_content': None,
#     'query': '%23%ED%81%A5_%EB%8D%B0%EB%B7%948%EC%A3%BC%EB%85%84_%EC%B6%95%ED%95%98%ED%95%B4',
#     'tweet_volume': 153874},
#    {'name': '#GreatPresidentsNever',
#     'url': 'http://twitter.com/search?q=%23GreatPresidentsNever',
#     'promoted_content': None,
#     'query': '%23GreatPresidentsNever',
#     'tweet_volume': 15193},
#    {'name': '#MarriedAtFirstSight',
#     'url': 'http://twitter.com/search?q=%23MarriedAtFirstSight',
#     'promoted_content': None,
#     'query': '%23MarriedAtFirstSight',
#     'tweet_volume': None},
#    {'name': '#my600lblife',
#     'url': 'http://twitter.com/search?q=%23my600lblife',
#     'promoted_content': None,
#     'query': '%23my600lblife',
#     'tweet_volume': None},
#    {'name': '#SKZUNLOCKinNYC',
#     'url': 'http://twitter.com/search?q=%23SKZUNLOCKinNYC',
#     'promoted_content': None,
#     'query': '%23SKZUNLOCKinNYC',
#     'tweet_volume': 78336},
#    {'name': '#girlsdad',
#     'url': 'http://twitter.com/search?q=%23girlsdad',
#     'promoted_content': None,
#     'query': '%23girlsdad',
#     'tweet_volume': None},
#    {'name': '#FLAxFLU',
#     'url': 'http://twitter.com/search?q=%23FLAxFLU',
#     'promoted_content': None,
#     'query': '%23FLAxFLU',
#     'tweet_volume': 22985},
#    {'name': '#REINVENTEESSAPROMO',
#     'url': 'http://twitter.com/search?q=%23REINVENTEESSAPROMO',
#     'promoted_content': None,
#     'query': '%23REINVENTEESSAPROMO',
#     'tweet_volume': None},
#    {'name': '#EstamosConCarabineros',
#     'url': 'http://twitter.com/search?q=%23EstamosConCarabineros',
#     'promoted_content': None,
#     'query': '%23EstamosConCarabineros',
#     'tweet_volume': 67334},
#    {'name': '#SistasOnBET',
#     'url': 'http://twitter.com/search?q=%23SistasOnBET',
#     'promoted_content': None,
#     'query': '%23SistasOnBET',
#     'tweet_volume': None},
#    {'name': '#NosArruinaronLaVida',
#     'url': 'http://twitter.com/search?q=%23NosArruinaronLaVida',
#     'promoted_content': None,
#     'query': '%23NosArruinaronLaVida',
#     'tweet_volume': None},
#    {'name': '#UykuTutmuyor',
#     'url': 'http://twitter.com/search?q=%23UykuTutmuyor',
#     'promoted_content': None,
#     'query': '%23UykuTutmuyor',
#     'tweet_volume': None},
#    {'name': '#พี่โต้ล้านแตกแล้ว',
#     'url': 'http://twitter.com/search?q=%23%E0%B8%9E%E0%B8%B5%E0%B9%88%E0%B9%82%E0%B8%95%E0%B9%89%E0%B8%A5%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B9%81%E0%B8%95%E0%B8%81%E0%B9%81%E0%B8%A5%E0%B9%89%E0%B8%A7',
#     'promoted_content': None,
#     'query': '%23%E0%B8%9E%E0%B8%B5%E0%B9%88%E0%B9%82%E0%B8%95%E0%B9%89%E0%B8%A5%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B9%81%E0%B8%95%E0%B8%81%E0%B9%81%E0%B8%A5%E0%B9%89%E0%B8%A7',
#     'tweet_volume': 29022},
#    {'name': '#kamisambyar',
#     'url': 'http://twitter.com/search?q=%23kamisambyar',
#     'promoted_content': None,
#     'query': '%23kamisambyar',
#     'tweet_volume': None},
#    {'name': '#癒してくれるものを二文字で',
#     'url': 'http://twitter.com/search?q=%23%E7%99%92%E3%81%97%E3%81%A6%E3%81%8F%E3%82%8C%E3%82%8B%E3%82%82%E3%81%AE%E3%82%92%E4%BA%8C%E6%96%87%E5%AD%97%E3%81%A7',
#     'promoted_content': None,
#     'query': '%23%E7%99%92%E3%81%97%E3%81%A6%E3%81%8F%E3%82%8C%E3%82%8B%E3%82%82%E3%81%AE%E3%82%92%E4%BA%8C%E6%96%87%E5%AD%97%E3%81%A7',
#     'tweet_volume': None},
#    {'name': '#OprahMeetYang',
#     'url': 'http://twitter.com/search?q=%23OprahMeetYang',
#     'promoted_content': None,
#     'query': '%23OprahMeetYang',
#     'tweet_volume': None},
#    {'name': '#من_قلبك_اش_تعشق',
#     'url': 'http://twitter.com/search?q=%23%D9%85%D9%86_%D9%82%D9%84%D8%A8%D9%83_%D8%A7%D8%B4_%D8%AA%D8%B9%D8%B4%D9%82',
#     'promoted_content': None,
#     'query': '%23%D9%85%D9%86_%D9%82%D9%84%D8%A8%D9%83_%D8%A7%D8%B4_%D8%AA%D8%B9%D8%B4%D9%82',
#     'tweet_volume': None},
#    {'name': '#クウガ20周年',
#     'url': 'http://twitter.com/search?q=%23%E3%82%AF%E3%82%A6%E3%82%AC20%E5%91%A8%E5%B9%B4',
#     'promoted_content': None,
#     'query': '%23%E3%82%AF%E3%82%A6%E3%82%AC20%E5%91%A8%E5%B9%B4',
#     'tweet_volume': 28274},
#    {'name': '#AlChavismoNoLoParaNadie',
#     'url': 'http://twitter.com/search?q=%23AlChavismoNoLoParaNadie',
#     'promoted_content': None,
#     'query': '%23AlChavismoNoLoParaNadie',
#     'tweet_volume': 15777},
#    {'name': '#WeWantWitnesses',
#     'url': 'http://twitter.com/search?q=%23WeWantWitnesses',
#     'promoted_content': None,
#     'query': '%23WeWantWitnesses',
#     'tweet_volume': 324037},
#    {'name': '#TahaÖzerveEscortEkibi',
#     'url': 'http://twitter.com/search?q=%23Taha%C3%96zerveEscortEkibi',
#     'promoted_content': None,
#     'query': '%23Taha%C3%96zerveEscortEkibi',
#     'tweet_volume': None},
#    {'name': '#FirstManProject',
#     'url': 'http://twitter.com/search?q=%23FirstManProject',
#     'promoted_content': None,
#     'query': '%23FirstManProject',
#     'tweet_volume': None},
#    {'name': '#MCIMUN',
#     'url': 'http://twitter.com/search?q=%23MCIMUN',
#     'promoted_content': None,
#     'query': '%23MCIMUN',
#     'tweet_volume': 32530},
#    {'name': '#TitleOfMyFamilysAutobiography',
#     'url': 'http://twitter.com/search?q=%23TitleOfMyFamilysAutobiography',
#     'promoted_content': None,
#     'query': '%23TitleOfMyFamilysAutobiography',
#     'tweet_volume': None},
#    {'name': '#coronavirusec',
#     'url': 'http://twitter.com/search?q=%23coronavirusec',
#     'promoted_content': None,
#     'query': '%23coronavirusec',
#     'tweet_volume': None},
#    {'name': '#çoközlediğinbirinietiketle',
#     'url': 'http://twitter.com/search?q=%23%C3%A7ok%C3%B6zledi%C4%9Finbirinietiketle',
#     'promoted_content': None,
#     'query': '%23%C3%A7ok%C3%B6zledi%C4%9Finbirinietiketle',
#     'tweet_volume': None}],
#   'as_of': '2020-01-30T02:44:33Z',
#   'created_at': '2020-01-30T02:39:39Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
len(trends[0]['trends'])
# Out:
# 50

# %%
#let's see tweet_volumes

volume=[]
for x in trends[0]['trends']:
    volume.append(x['tweet_volume'])
volume
# Out:
# [73478,
#  19901,
#  281772,
#  21218,
#  12872,
#  None,
#  64751,
#  None,
#  None,
#  16467,
#  125490,
#  None,
#  33844,
#  13127,
#  None,
#  None,
#  None,
#  None,
#  None,
#  16164,
#  None,
#  10568,
#  52126,
#  None,
#  153874,
#  15193,
#  None,
#  None,
#  78336,
#  None,
#  22985,
#  None,
#  67334,
#  None,
#  None,
#  None,
#  29022,
#  None,
#  None,
#  None,
#  None,
#  28274,
#  15777,
#  324037,
#  None,
#  None,
#  32530,
#  None,
#  None,
#  None]

# %% [markdown]
# ___

# %% [markdown]
# # Twitter Labs Endpoints

# %% [markdown]
# # Test Call To "labs/1/users" Endpoint

# %% [markdown]
# **Getting information about a particular Twitter user here (Donald Trump)**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'usernames': 'realDonaldTrump,Twitter,MichelleObama,sundarpichai,tim_cook',
    'user.format': 'detailed',
    'format': 'detailed'
}

search_url = 'https://api.twitter.com/labs/1/users?'

request_1 = requests.get(search_url, headers=search_headers, params=search_params)
users = request_1.json()
users
# Out:
# {'data': [{'created_at': '2009-03-18T13:46:38.000Z',
#    'description': '45th President of the United States of America🇺🇸',
#    'entities': {'url': {'urls': [{'start': 0,
#        'end': 23,
#        'url': 'https://t.co/OMxB0x7xC5',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'display_url': 'Instagram.com/realDonaldTrump'}]}},
#    'id': '25073877',
#    'location': 'Washington, DC',
#    'most_recent_tweet_id': '1223038027234267137',
#    'name': 'Donald J. Trump',
#    'pinned_tweet_id': '1222655839573565440',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'protected': False,
#    'stats': {'followers_count': 71873110,
#     'following_count': 47,
#     'tweet_count': 48500,
#     'listed_count': 113961},
#    'url': 'https://t.co/OMxB0x7xC5',
#    'username': 'realDonaldTrump',
#    'verified': True,
#    'format': 'detailed'},
#   {'created_at': '2007-02-20T14:35:54.000Z',
#    'description': 'What’s happening?!',
#    'entities': {'url': {'urls': [{'start': 0,
#        'end': 23,
#        'url': 'https://t.co/TAXQpsHa5X',
#        'expanded_url': 'https://about.twitter.com/',
#        'display_url': 'about.twitter.com'}]}},
#    'id': '783214',
#    'location': 'Everywhere',
#    'most_recent_tweet_id': '1222972807639896064',
#    'name': 'Twitter',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/1111729635610382336/_65QFl7B_normal.png',
#    'protected': False,
#    'stats': {'followers_count': 57135266,
#     'following_count': 1,
#     'tweet_count': 12909,
#     'listed_count': 90552},
#    'url': 'https://t.co/TAXQpsHa5X',
#    'username': 'Twitter',
#    'verified': True,
#    'format': 'detailed'},
#   {'created_at': '2011-11-10T20:13:01.000Z',
#    'description': 'Girl from the South Side and former First Lady. Wife, mother, dog lover. Always hugger-in-chief.',
#    'entities': {'url': {'urls': [{'start': 0,
#        'end': 23,
#        'url': 'https://t.co/0UVvR5L6vm',
#        'expanded_url': 'http://obama.org',
#        'display_url': 'obama.org'}]}},
#    'id': '409486555',
#    'location': 'Washington, DC',
#    'most_recent_tweet_id': '1219257438949597185',
#    'name': 'Michelle Obama',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/1192811236242722816/-r8d4_d3_normal.jpg',
#    'protected': False,
#    'stats': {'followers_count': 14331923,
#     'following_count': 18,
#     'tweet_count': 1225,
#     'listed_count': 24897},
#    'url': 'https://t.co/0UVvR5L6vm',
#    'username': 'MichelleObama',
#    'verified': True,
#    'format': 'detailed'},
#   {'created_at': '2008-03-12T05:51:53.000Z',
#    'description': 'CEO,  Google and Alphabet',
#    'id': '14130366',
#    'most_recent_tweet_id': '1221298825786089472',
#    'name': 'Sundar Pichai',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/864282616597405701/M-FEJMZ0_normal.jpg',
#    'protected': False,
#    'stats': {'followers_count': 2636216,
#     'following_count': 337,
#     'tweet_count': 1316,
#     'listed_count': 6747},
#    'url': '',
#    'username': 'sundarpichai',
#    'verified': True,
#    'format': 'detailed'},
#   {'created_at': '2013-07-31T22:41:25.000Z',
#    'description': "Apple CEO \uf8ff Auburn 🏀 🏈 Duke 🏀 National Parks 🏞️ “Life's most persistent and urgent question is, 'What are you doing for others?'” - MLK",
#    'id': '1636590253',
#    'location': 'Cupertino',
#    'most_recent_tweet_id': '1221813908576464896',
#    'name': 'Tim Cook',
#    'profile_image_url': 'https://pbs.twimg.com/profile_images/1194113737092935681/63O1znGw_normal.jpg',
#    'protected': False,
#    'stats': {'followers_count': 11677552,
#     'following_count': 68,
#     'tweet_count': 976,
#     'listed_count': 21430},
#    'url': '',
#    'username': 'tim_cook',
#    'verified': True,
#    'format': 'detailed'}]}

# %%
# with open('users.json', 'w', encoding='utf-8') as f:
#     json.dump(users, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Test Call To "labs/1/tweets" Endpoint

# %% [markdown]
# **Getting detailed information about a tweet here (most recent tweet from Donald Trump)**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'ids': '1223038027234267137,1222972807639896064,1219257438949597185,1221298825786089472,1221813908576464896',
    'format': 'detailed',
    'tweet.format': 'detailed',
    'user.format': 'detailed',
    'place.format': 'detailed'
}

search_url = 'https://api.twitter.com/labs/1/tweets'

request_2 = requests.get(search_url, headers=search_headers, params=search_params)
get_tweets = request_2.json()
get_tweets
# Out:
# {'data': [{'attachments': {'media_keys': ['3_1223038022867935232']},
#    'author_id': '25073877',
#    'created_at': '2020-01-31T00:19:23.000Z',
#    'entities': {'hashtags': [{'start': 57, 'end': 65, 'tag': 'KAG2020'}],
#     'urls': [{'start': 68,
#       'end': 91,
#       'url': 'https://t.co/4YCo01XYCn',
#       'expanded_url': 'https://twitter.com/realDonaldTrump/status/1223038027234267137/photo/1',
#       'display_url': 'pic.twitter.com/4YCo01XYCn'}]},
#    'id': '1223038027234267137',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 2406,
#     'reply_count': 1346,
#     'like_count': 8517,
#     'quote_count': 192},
#    'text': 'Great poll in Iowa, where I just landed for a Big Rally! #KAG2020🇺🇸 https://t.co/4YCo01XYCn',
#    'format': 'detailed'},
#   {'author_id': '783214',
#    'created_at': '2020-01-30T20:00:13.000Z',
#    'id': '1222972807639896064',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#    'stats': {'retweet_count': 28532,
#     'reply_count': 3049,
#     'like_count': 77352,
#     'quote_count': 4354},
#    'text': "Yes, it's still January",
#    'format': 'detailed'},
#   {'author_id': '409486555',
#    'created_at': '2020-01-20T13:56:40.000Z',
#    'entities': {'hashtags': [{'start': 227, 'end': 234, 'tag': 'MLKDay'}],
#     'urls': [{'start': 256,
#       'end': 279,
#       'url': 'https://t.co/cBTTn9yuTH',
#       'expanded_url': 'http://whenweallvote.org',
#       'display_url': 'whenweallvote.org'},
#      {'start': 280,
#       'end': 303,
#       'url': 'https://t.co/xYqQFNY5kT',
#       'expanded_url': 'https://twitter.com/whenweallvote/status/1219255758879166466',
#       'display_url': 'twitter.com/whenweallvote/…'}]},
#    'id': '1219257438949597185',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1219255758879166466'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 10107,
#     'reply_count': 508,
#     'like_count': 44343,
#     'quote_count': 253},
#    'text': "To honor Dr. King's legacy, we all can play a role in ensuring our friends and family make their voices heard in every election. By sitting out, we're allowing others to make decisions for us. \n\nHelp register your community on #MLKDay and throughout 2020: https://t.co/cBTTn9yuTH https://t.co/xYqQFNY5kT",
#    'format': 'detailed'},
#   {'author_id': '14130366',
#    'created_at': '2020-01-26T05:08:25.000Z',
#    'entities': {'mentions': [{'start': 135,
#       'end': 145,
#       'username': 'Googleorg'},
#      {'start': 159, 'end': 165, 'username': 'NAACP'}],
#     'urls': [{'start': 261,
#       'end': 284,
#       'url': 'https://t.co/SwZbVZGqOW',
#       'expanded_url': 'http://g.co/blackhistorymonth',
#       'display_url': 'g.co/blackhistorymo…'}]},
#    'id': '1221298825786089472',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 153,
#     'reply_count': 56,
#     'like_count': 1068,
#     'quote_count': 8},
#    'text': 'This Black History Month, we’ll be celebrating some of the most-searched moments &amp; individuals in America. We’re also making a $3M @Googleorg grant to the @NAACP ACT-SO program, supporting future history makers in STEM, humanities, business &amp; the arts. https://t.co/SwZbVZGqOW',
#    'format': 'detailed'},
#   {'author_id': '1636590253',
#    'created_at': '2020-01-27T15:15:10.000Z',
#    'entities': {'hashtags': [{'start': 249,
#       'end': 273,
#       'tag': 'HolocaustRemembranceDay'}]},
#    'id': '1221813908576464896',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'stats': {'retweet_count': 678,
#     'reply_count': 119,
#     'like_count': 5556,
#     'quote_count': 32},
#    'text': 'Today, we remember the millions of lives lost. Tomorrow and always, we vow to reject cruelty so that it never happens again. “History, despite its wrenching pain, cannot be unlived, but if faced with courage, need not be lived again.”— Maya Angelou #HolocaustRemembranceDay',
#    'format': 'detailed'}]}

# %%
# with open('tweets_deets.json', 'w', encoding='utf-8') as f:
#     json.dump(get_tweets, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Test Call To "/labs/1/tweets/search" Endpoint

# %% [markdown]
# **/labs/1/tweets/search endpoint returns Tweets from the last 7 days that match a search query. Query is for "Kobe".**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'query': 'kobe',
    'max_results': 100,
    'format': 'detailed',
    'tweet.format': 'detailed',
    'user.format': 'detailed',
    'place.format': 'detailed'
}

search_url = 'https://api.twitter.com/labs/1/tweets/search'

request_3 = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search = request_3.json()
tweets_search
# Out:
# {'data': [{'attachments': {'media_keys': ['13_1222613410485014529']},
#    'author_id': '2742356057',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'espn'}],
#     'urls': [{'start': 74,
#       'end': 97,
#       'url': 'https://t.co/ThBIjzKWVN',
#       'expanded_url': 'https://twitter.com/espn/status/1222614701277949952/video/1',
#       'display_url': 'pic.twitter.com/ThBIjzKWVN'}]},
#    'id': '1222680977165647874',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222614701277949952'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 4970,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @espn: Zaire Wade hit the Kobe celebration after throwing down a dunk. https://t.co/ThBIjzKWVN',
#    'format': 'detailed'},
#   {'author_id': '1113108537239048194',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'hashtags': [{'start': 12, 'end': 23, 'tag': 'KobeBryant'},
#      {'start': 28, 'end': 41, 'tag': 'GiannaBryant'},
#      {'start': 90, 'end': 99, 'tag': 'YangGang'},
#      {'start': 100, 'end': 111, 'tag': 'BlackMamba'}],
#     'urls': [{'start': 229,
#       'end': 252,
#       'url': 'https://t.co/ZSoBuCDbUU',
#       'expanded_url': 'https://twitter.com/abolitionist4ay/status/1222650626410151936',
#       'display_url': 'twitter.com/abolitionist4a…'}]},
#    'id': '1222680977077608448',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222650626410151936'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'In honor of #KobeBryant and #GiannaBryant. Anyone up for a match to honor their passing? \n#YangGang\n#BlackMamba \nKobe’s favorite charity was Make-Wish-Foundation. If you’d rather donate to them in his honor, I 100% get that too. https://t.co/ZSoBuCDbUU',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222005099897057280']},
#    'author_id': '940705970451288067',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'TheSportsHubb'}],
#     'urls': [{'start': 76,
#       'end': 99,
#       'url': 'https://t.co/47iuXVqF28',
#       'expanded_url': 'https://twitter.com/TheSportsHubb/status/1222005643940265985/video/1',
#       'display_url': 'pic.twitter.com/47iuXVqF28'}]},
#    'id': '1222680977031532546',
#    'lang': 'en',
#    'possibly_sensitive': True,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222005643940265985'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 95124,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @TheSportsHubb: Kobe &amp; Vanessa. If it ain’t this. I don’t want it♾❤️ https://t.co/47iuXVqF28',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222543841020071937']},
#    'author_id': '933730772',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SportsCenter'},
#      {'start': 80, 'end': 94, 'username': 'BrundageMagic'}],
#     'urls': [{'start': 96,
#       'end': 119,
#       'url': 'https://t.co/qzH4MM0O5B',
#       'expanded_url': 'https://twitter.com/SportsCenter/status/1222543977095802881/video/1',
#       'display_url': 'pic.twitter.com/qzH4MM0O5B'}]},
#    'id': '1222680976704274432',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222543977095802881'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 25647,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @SportsCenter: He made a portrait of Kobe Bryant with Rubik's Cubes 👏 \n\n(via @brundagemagic) https://t.co/qzH4MM0O5B",
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222385118674747393']},
#    'author_id': '1149759361',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'samstaydipped'}],
#     'urls': [{'start': 93,
#       'end': 116,
#       'url': 'https://t.co/iAziryOjer',
#       'expanded_url': 'https://twitter.com/samstaydipped/status/1222385128866861057/photo/1',
#       'display_url': 'pic.twitter.com/iAziryOjer'}]},
#    'id': '1222680976691802112',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222385128866861057'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 1063,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @samstaydipped: Kobe said never stop shooting your shot and that’s exactly what we gon do https://t.co/iAziryOjer',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '2338675081',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680976540696578',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'author_id': '989905728',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'heisTactic'}]},
#    'id': '1222680976146518021',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222398836519383040'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 34963,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @heisTactic: This guy legit drew Kobe and Gigi using just their names!!!! \n\nThis has to be the best thing I've seen today 💔 💔 💔 https://…",
#    'format': 'detailed'},
#   {'author_id': '3302080008',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'BleacherReport'}]},
#    'id': '1222680975932624902',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222265711000805377'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 4162,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @BleacherReport: Before basketball, Gianna wanted to be a gymnast, so Kobe told her a bedtime story called “Gigi The Gymnast.”\n\nKobe fel…',
#    'format': 'detailed'},
#   {'author_id': '1139738921976434689',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'id': '1222680975915790338',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'We been talking about Kobe all week at school',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['16_1222680969183928321']},
#    'author_id': '909218762',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'urls': [{'start': 75,
#       'end': 98,
#       'url': 'https://t.co/cL8Xo3sIYb',
#       'expanded_url': 'https://twitter.com/poproyaltystan/status/1222680975831916545/photo/1',
#       'display_url': 'pic.twitter.com/cL8Xo3sIYb'}]},
#    'id': '1222680975831916545',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'They illuminated the seats @ Barclays where Kobe &amp; Gianna were sitting https://t.co/cL8Xo3sIYb',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1131978224798453760']},
#    'author_id': '232716436',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'Mamba_Insider'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/w5NSVL75MZ',
#       'expanded_url': 'https://twitter.com/Mamba_Insider/status/1222670763079106567/video/1',
#       'display_url': 'pic.twitter.com/w5NSVL75MZ'}]},
#    'id': '1222680975823470592',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222670763079106567'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 385,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Mamba_Insider: Never forget when Kobe hit SEVEN game winners in ONE season 🐐 https://t.co/w5NSVL75MZ',
#    'format': 'detailed'},
#   {'author_id': '95133563',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': '_KevinSosa_'}]},
#    'id': '1222680975517323264',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222188009401044992'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 22434,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @_KevinSosa_: Bad Bunny on his Tribute song to Kobe was talkin bout his daughter and said “y pensar que una se fue contigo me descontrol…',
#    'format': 'detailed'},
#   {'author_id': '2502282627',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'AndrewGreif'}]},
#    'id': '1222680975357960192',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222629314941685760'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 1993,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @AndrewGreif: Kawhi called Kobe’s pilot, Ara Zobayan, a “good dude” and used him to fly to and from games. He also discussed if this giv…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222643233798356994']},
#    'author_id': '4515209662',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'Pasion_Basket1'}],
#     'urls': [{'start': 107,
#       'end': 130,
#       'url': 'https://t.co/48di8hV2v7',
#       'expanded_url': 'https://twitter.com/Pasion_Basket1/status/1222643582110195713/video/1',
#       'display_url': 'pic.twitter.com/48di8hV2v7'}]},
#    'id': '1222680975219576833',
#    'lang': 'es',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222643582110195713'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 395,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Pasion_Basket1: Kobe Bryant hablando maravillas de la amistad que mantenía con Pau Gasol. Para guardar https://t.co/48di8hV2v7',
#    'format': 'detailed'},
#   {'author_id': '1088861978536431617',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'hashtags': [{'start': 83, 'end': 93, 'tag': 'persevere'}],
#     'mentions': [{'start': 3, 'end': 12, 'username': 'AshMWill'}]},
#    'id': '1222680975165050882',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222678636236546048'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @AshMWill: "You know things are never perfect but through love, you continue to #persevere, you move through them and then through that…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['16_1222200623862550532']},
#    'author_id': '147003534',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 13, 'username': 'walkertkl'}],
#     'urls': [{'start': 34,
#       'end': 57,
#       'url': 'https://t.co/rFwXMLColo',
#       'expanded_url': 'https://twitter.com/walkertkl/status/1222200644926410752/photo/1',
#       'display_url': 'pic.twitter.com/rFwXMLColo'}]},
#    'id': '1222680975144112129',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222200644926410752'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 12704,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @walkertkl: kobe's last jumper https://t.co/rFwXMLColo",
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222679389797638144']},
#    'author_id': '851177847670661122',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'BleacherReport'}],
#     'urls': [{'start': 105,
#       'end': 128,
#       'url': 'https://t.co/p6ZkxQWeh4',
#       'expanded_url': 'https://twitter.com/BleacherReport/status/1222679618840170497/video/1',
#       'display_url': 'pic.twitter.com/p6ZkxQWeh4'}]},
#    'id': '1222680974997229571',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222679618840170497'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 541,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @BleacherReport: Pacers fans honored Kobe with purple and gold signs when both teams hit 24 points 💜💛 https://t.co/p6ZkxQWeh4',
#    'format': 'detailed'},
#   {'author_id': '3387573489',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'OfficialOctt'}]},
#    'id': '1222680974850433029',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222355109314748417'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 153358,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @OfficialOctt: Lord knows I wasn't supposed to hit this Kobe crossover to a 1 yr old so I paid for it at the end 😂😂😂 https://t.co/Ui9wvI…",
#    'format': 'detailed'},
#   {'author_id': '1373533387',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'stefonmoss'}]},
#    'id': '1222680974678466560',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1221893561311879168'},
#     {'type': 'retweeted', 'id': '1222037778663387141'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 54681,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @stefonmoss: nah, i miss KOBE bitch',
#    'format': 'detailed'},
#   {'author_id': '56767349',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'id': '1222680974628196353',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Every time I see a Kobe tribute I’m just hoping somebody got they information wrong 😭',
#    'format': 'detailed'},
#   {'author_id': '1345613491',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'bryanmsamson'}]},
#    'id': '1222680974552719360',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222015430945955840'},
#     {'type': 'retweeted', 'id': '1222314620326535168'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 8263,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @bryanmsamson: God lettin us know that Kobe and Gigi’s safe with him 🙏🏼💛💜',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '1835781787',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680974510764037',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222669238088994817']},
#    'author_id': '341643599',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SportsNation'}],
#     'urls': [{'start': 103,
#       'end': 126,
#       'url': 'https://t.co/91e0rjMtLk',
#       'expanded_url': 'https://twitter.com/SportsNation/status/1222671866420178944/video/1',
#       'display_url': 'pic.twitter.com/91e0rjMtLk'}]},
#    'id': '1222680974066057216',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222671866420178944'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 328,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @SportsNation: Kobe was a legend on the court.\n\nHis sense of humor was just as good. We’ll miss it. https://t.co/91e0rjMtLk',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222010724668657664']},
#    'author_id': '1176292814763651072',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'hashtags': [{'start': 53, 'end': 66, 'tag': 'KobeFarewell'}],
#     'mentions': [{'start': 3, 'end': 14, 'username': 'bramante__'}],
#     'urls': [{'start': 67,
#       'end': 90,
#       'url': 'https://t.co/PkPL2N5hMq',
#       'expanded_url': 'https://twitter.com/bramante__/status/1222010762228641793/video/1',
#       'display_url': 'pic.twitter.com/PkPL2N5hMq'}]},
#    'id': '1222680973738774529',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222010762228641793'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 161824,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @bramante__: My favorite part of Kobe’s last game #KobeFarewell https://t.co/PkPL2N5hMq',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222379531975065601']},
#    'author_id': '2536186896',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'Corridosmp3'}],
#     'urls': [{'start': 48,
#       'end': 71,
#       'url': 'https://t.co/uwYQyRnIsF',
#       'expanded_url': 'https://twitter.com/loccdoutjoe/status/1222379559502303233/video/1',
#       'display_url': 'pic.twitter.com/uwYQyRnIsF'}]},
#    'id': '1222680973667655681',
#    'lang': 'ht',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222397798609346560'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 15459,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Corridosmp3: Esta va pa ti Kobe Bryant 🏀  👑 https://t.co/uwYQyRnIsF',
#    'format': 'detailed'},
#   {'author_id': '987650520',
#    'created_at': '2020-01-30T00:40:35.000Z',
#    'entities': {'hashtags': [{'start': 106, 'end': 114, 'tag': 'girldad'}],
#     'mentions': [{'start': 3, 'end': 18, 'username': 'elleduncanESPN'}]},
#    'id': '1222680973382504449',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222207808780873730'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 16385,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @elleduncanESPN: I’m so moved by the outpouring of support behind my story about Kobe. And I love that #girldad is trending.. so for all…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222375690768535553']},
#    'author_id': '488082182',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'TheLakersReview'}],
#     'urls': [{'start': 67,
#       'end': 90,
#       'url': 'https://t.co/fSdaazHKBf',
#       'expanded_url': 'https://twitter.com/TheLakersReview/status/1222375696049197057/photo/1',
#       'display_url': 'pic.twitter.com/fSdaazHKBf'}]},
#    'id': '1222680973256667139',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222375696049197057'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 296,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @TheLakersReview: Darren Collison on Kobe Bryant via Instagram: https://t.co/fSdaazHKBf',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222402178779734019']},
#    'author_id': '772322514',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SportsCenter'},
#      {'start': 19, 'end': 24, 'username': 'SHAQ'}],
#     'urls': [{'start': 96,
#       'end': 119,
#       'url': 'https://t.co/oIGQdPuzC2',
#       'expanded_url': 'https://twitter.com/SportsCenter/status/1222402284211953665/video/1',
#       'display_url': 'pic.twitter.com/oIGQdPuzC2'}]},
#    'id': '1222680973164322816',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222402284211953665'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 18359,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @SportsCenter: .@SHAQ leading "Kobe" chants near Staples Center.\n\n(via omerdrinks/Instagram) https://t.co/oIGQdPuzC2',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222673274363973632']},
#    'author_id': '2852627035',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'hashtags': [{'start': 47, 'end': 55, 'tag': 'RIPKOBE'}],
#     'mentions': [{'start': 3, 'end': 13, 'username': 'BdotAdot5'}],
#     'urls': [{'start': 75,
#       'end': 98,
#       'url': 'https://t.co/hAEiYfn0CV',
#       'expanded_url': 'https://youtu.be/uDXnHbxo_GU',
#       'display_url': 'youtu.be/uDXnHbxo_GU'},
#      {'start': 99,
#       'end': 122,
#       'url': 'https://t.co/MaIQYbtJUU',
#       'expanded_url': 'https://twitter.com/BdotAdot5/status/1222673373655789568/video/1',
#       'display_url': 'pic.twitter.com/MaIQYbtJUU'}]},
#    'id': '1222680973155893249',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222673373655789568'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 5,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @BdotAdot5: Game of 24 in Honor of KOBE! 💜💛 #RIPKOBE 2️⃣4️⃣\n\nFull Game: https://t.co/hAEiYfn0CV https://t.co/MaIQYbtJUU',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222243991846080513']},
#    'author_id': '1612298576',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'NBAonTNT'}],
#     'urls': [{'start': 107,
#       'end': 130,
#       'url': 'https://t.co/gaOUBT4CIb',
#       'expanded_url': 'https://twitter.com/NBAonTNT/status/1222640563788189696/video/1',
#       'display_url': 'pic.twitter.com/gaOUBT4CIb'}]},
#    'id': '1222680973130846210',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222640563788189696'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 1880,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @NBAonTNT: “It’s been beautiful to watch you…”\n\nNBA on TNT looks back at all of the memories with Kobe. https://t.co/gaOUBT4CIb',
#    'format': 'detailed'},
#   {'author_id': '764885102',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'bryanmsamson'}]},
#    'id': '1222680972799414272',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222015430945955840'},
#     {'type': 'retweeted', 'id': '1222314620326535168'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 8263,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @bryanmsamson: God lettin us know that Kobe and Gigi’s safe with him 🙏🏼💛💜',
#    'format': 'detailed'},
#   {'author_id': '903846188323020800',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'ketengahketepi'}]},
#    'id': '1222680972744744961',
#    'lang': 'in',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222475872155795456'},
#     {'type': 'retweeted', 'id': '1222478935205666817'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 13373,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @ketengahketepi: Macam macam ye jadi january ni. Ingatkan 2020 ada kereta terbang lepastu semua kene scam. Datang coronavirus pulak, PU…',
#    'format': 'detailed'},
#   {'author_id': '1073826100080328704',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'OfficialOctt'}]},
#    'id': '1222680972556001280',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222355109314748417'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 153359,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @OfficialOctt: Lord knows I wasn't supposed to hit this Kobe crossover to a 1 yr old so I paid for it at the end 😂😂😂 https://t.co/Ui9wvI…",
#    'format': 'detailed'},
#   {'author_id': '2521570410',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 9, 'username': 'RapUp'}],
#     'urls': [{'start': 95,
#       'end': 118,
#       'url': 'https://t.co/X02dBIooMW',
#       'expanded_url': 'http://bit.ly/2RCUxkY',
#       'display_url': 'bit.ly/2RCUxkY'}]},
#    'id': '1222680972371431424',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222606011015389184'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 37,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @RapUp: Tinashe pays tribute to Kobe Bryant on the original version of "Hopscotch." Listen: https://t.co/X02dBIooMW 💛💜 https://t.co/dDm2…',
#    'format': 'detailed'},
#   {'author_id': '2901204679',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'OfficialOctt'}]},
#    'id': '1222680972174360576',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222355109314748417'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 153364,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @OfficialOctt: Lord knows I wasn't supposed to hit this Kobe crossover to a 1 yr old so I paid for it at the end 😂😂😂 https://t.co/Ui9wvI…",
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222009769990377472']},
#    'author_id': '385513784',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 13, 'username': 'DuragCody'}],
#     'urls': [{'start': 107,
#       'end': 130,
#       'url': 'https://t.co/YuPSwzUFfB',
#       'expanded_url': 'https://twitter.com/DuragCody/status/1222009801598595073/video/1',
#       'display_url': 'pic.twitter.com/YuPSwzUFfB'}]},
#    'id': '1222680971956322304',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222009801598595073'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 42707,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DuragCody: LeBron the rest of this season after telling Kobe he was gonna “put this shit on his back”: https://t.co/YuPSwzUFfB',
#    'format': 'detailed'},
#   {'author_id': '219419491',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'urls': [{'start': 45,
#       'end': 68,
#       'url': 'https://t.co/LUHkQwigjp',
#       'expanded_url': 'https://twitter.com/goknickstape/status/1222546077838123008',
#       'display_url': 'twitter.com/goknickstape/s…'}]},
#    'id': '1222680971927080963',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222546077838123008'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': '0-24 coming soon... 🗣🗣”Kobe this is for you” https://t.co/LUHkQwigjp',
#    'format': 'detailed'},
#   {'author_id': '790019230389248000',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'hashtags': [{'start': 100, 'end': 107, 'tag': 'Sports'}],
#     'urls': [{'start': 76,
#       'end': 99,
#       'url': 'https://t.co/uqmbSyUHCH',
#       'expanded_url': 'https://hedgeaccordingly.com/2020/01/26/sports/lakers-legend-jerry-west-delivers-heartfelt-remembrance-of-late-kobe-bryant/',
#       'display_url': 'hedgeaccordingly.com/2020/01/26/spo…'}]},
#    'id': '1222680971872493569',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="https://hedgeaccordingly.com" rel="nofollow">HEDGEP</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Lakers legend Jerry West delivers heartfelt remembrance of late Kobe Bryant https://t.co/uqmbSyUHCH #Sports',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222363440380952576']},
#    'author_id': '2326997014',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'barstoolsports'}],
#     'urls': [{'start': 117,
#       'end': 140,
#       'url': 'https://t.co/Qpbpn7Rps8',
#       'expanded_url': 'https://twitter.com/Brayden28__/status/1222363633327325184/video/1',
#       'display_url': 'pic.twitter.com/Qpbpn7Rps8'}]},
#    'id': '1222680971859955712',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222395669647908864'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 7904,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @barstoolsports: He hit a game winner wearing the #24 jersey with the whole crowd chanting Kobe. Mamba mentality. https://t.co/Qpbpn7Rps8',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222313264698159106']},
#    'author_id': '168830435',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'BleacherReport'},
#      {'start': 49, 'end': 58, 'username': 'NBAonTNT'}],
#     'urls': [{'start': 60,
#       'end': 83,
#       'url': 'https://t.co/BXgDiJ1L0u',
#       'expanded_url': 'https://twitter.com/BleacherReport/status/1222313578184597504/video/1',
#       'display_url': 'pic.twitter.com/BXgDiJ1L0u'}]},
#    'id': '1222680971809640448',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222313578184597504'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 94675,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @BleacherReport: Shaq reflects on Kobe.\n\n(via @NBAonTNT) https://t.co/BXgDiJ1L0u',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222648728437370881']},
#    'author_id': '2288941402',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 13, 'username': 'PettyNorm'}],
#     'urls': [{'start': 75,
#       'end': 98,
#       'url': 'https://t.co/8rw0euAq26',
#       'expanded_url': 'https://twitter.com/PettyNorm/status/1222649016762142720/video/1',
#       'display_url': 'pic.twitter.com/8rw0euAq26'}]},
#    'id': '1222680971700510723',
#    'lang': 'en',
#    'possibly_sensitive': True,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222649016762142720'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 5,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @PettyNorm: When your boy yells out Kobe before he shoot but he miss... https://t.co/8rw0euAq26',
#    'format': 'detailed'},
#   {'author_id': '296610312',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'urls': [{'start': 45,
#       'end': 68,
#       'url': 'https://t.co/Iwkvyeorve',
#       'expanded_url': 'https://twitter.com/randallpnkfloyd/status/1221976704031215616',
#       'display_url': 'twitter.com/randallpnkfloy…'}]},
#    'geo': {'place_id': 'fef01a8cb0eacb64'},
#    'id': '1222680971608231936',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1221976704031215616'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Kobe\nBron\nMegatron \nReggie Bush \nSean Taylor https://t.co/Iwkvyeorve',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222621467789209603']},
#    'author_id': '398219498',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SportsCenter'}],
#     'urls': [{'start': 71,
#       'end': 94,
#       'url': 'https://t.co/VwE80UFfHR',
#       'expanded_url': 'https://twitter.com/SportsCenter/status/1222623839315808257/video/1',
#       'display_url': 'pic.twitter.com/VwE80UFfHR'}]},
#    'id': '1222680971549577216',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222623839315808257'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 8808,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @SportsCenter: Kobe had bounce at 15 years old.\n\n(via Brian Gefter) https://t.co/VwE80UFfHR',
#    'format': 'detailed'},
#   {'author_id': '253750904',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'heisTactic'}]},
#    'id': '1222680971436285954',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222398836519383040'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 34963,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @heisTactic: This guy legit drew Kobe and Gigi using just their names!!!! \n\nThis has to be the best thing I've seen today 💔 💔 💔 https://…",
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222616307193012225']},
#    'author_id': '2324942969',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'hashtags': [{'start': 79, 'end': 93, 'tag': 'GeneraciónNBA'}],
#     'mentions': [{'start': 3, 'end': 15, 'username': 'MovistarNBA'}],
#     'urls': [{'start': 94,
#       'end': 117,
#       'url': 'https://t.co/uJA9eHX8te',
#       'expanded_url': 'https://twitter.com/MovistarNBA/status/1222640059066642434/video/1',
#       'display_url': 'pic.twitter.com/uJA9eHX8te'}]},
#    'id': '1222680971310444544',
#    'lang': 'es',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222640059066642434'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 2235,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @MovistarNBA: ¿Y qué hacemos ahora nosotros sin ti? Gracias por todo, Kobe. #GeneraciónNBA https://t.co/uJA9eHX8te',
#    'format': 'detailed'},
#   {'author_id': '817985614981251074',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': '70sluvchild'}]},
#    'id': '1222680971226615808',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222538260280500225'},
#     {'type': 'retweeted', 'id': '1222538826142318593'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 8913,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @70sluvchild: well u wasnt no Kobe lol',
#    'format': 'detailed'},
#   {'author_id': '968819891724627969',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'ComplexSneakers'},
#      {'start': 22, 'end': 32, 'username': 'KingJames'},
#      {'start': 108, 'end': 121, 'username': 'SptShtr_Bert'}]},
#    'id': '1222680970999943169',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222657352308023296'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 451,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @ComplexSneakers: .@KingJames laced up the “Chaos” Nike Kobe 5s for the Lakers’ return to practice 🐍👑\n📸: @SptShtr_Bert https://t.co/otnG…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '2516687460',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680970957996033',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'author_id': '1076924757285789697',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': '70sluvchild'}]},
#    'id': '1222680970794393600',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222538260280500225'},
#     {'type': 'retweeted', 'id': '1222538826142318593'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 8913,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @70sluvchild: well u wasnt no Kobe lol',
#    'format': 'detailed'},
#   {'author_id': '159340377',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'OfficialOctt'}]},
#    'id': '1222680970790363137',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222355109314748417'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 153364,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @OfficialOctt: Lord knows I wasn't supposed to hit this Kobe crossover to a 1 yr old so I paid for it at the end 😂😂😂 https://t.co/Ui9wvI…",
#    'format': 'detailed'},
#   {'author_id': '469751209',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': '_KevinSosa_'}]},
#    'id': '1222680970752454656',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222188009401044992'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 22434,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @_KevinSosa_: Bad Bunny on his Tribute song to Kobe was talkin bout his daughter and said “y pensar que una se fue contigo me descontrol…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222675105198809093',
#      '3_1222675105815367681']},
#    'author_id': '1125939890',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 7, 'username': 'NHL'},
#      {'start': 33, 'end': 38, 'username': 'ovi8'}],
#     'urls': [{'start': 91,
#       'end': 114,
#       'url': 'https://t.co/AcPvwCh4xH',
#       'expanded_url': 'https://twitter.com/NHL/status/1222675116963901441/photo/1',
#       'display_url': 'pic.twitter.com/AcPvwCh4xH'},
#      {'start': 91,
#       'end': 114,
#       'url': 'https://t.co/AcPvwCh4xH',
#       'expanded_url': 'https://twitter.com/NHL/status/1222675116963901441/photo/1',
#       'display_url': 'pic.twitter.com/AcPvwCh4xH'}]},
#    'id': '1222680970630967297',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222675116963901441'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 574,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @NHL: Tonight, Alex Ovechkin (@ovi8) honors Kobe Bryant by wearing No. 24 in warmup. 💜💛 https://t.co/AcPvwCh4xH',
#    'format': 'detailed'},
#   {'author_id': '899642265777340416',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'heisTactic'}]},
#    'id': '1222680970584907777',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222398836519383040'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 34963,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @heisTactic: This guy legit drew Kobe and Gigi using just their names!!!! \n\nThis has to be the best thing I've seen today 💔 💔 💔 https://…",
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222223478020947968']},
#    'author_id': '781141894751522816',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'Guru_of_Finesse'}],
#     'urls': [{'start': 114,
#       'end': 137,
#       'url': 'https://t.co/RQW0pn9j2T',
#       'expanded_url': 'https://twitter.com/Guru_of_Finesse/status/1222223950211452929/video/1',
#       'display_url': 'pic.twitter.com/RQW0pn9j2T'}]},
#    'id': '1222680970115125251',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222223950211452929'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 16903,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Guru_of_Finesse: This is for the ones who think that there Kobe . Rip Kobe Bryant Mamba Mentality lifestyle . https://t.co/RQW0pn9j2T',
#    'format': 'detailed'},
#   {'author_id': '469427202',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'Dan_082505'}]},
#    'id': '1222680970073006081',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1221788086645878784'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 58261,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Dan_082505: January teaches us to\n1. Love ourself (Corona Virus)\n2. Love others (WW3)\n3. Love our nature (Taal Volcano and Australia Wi…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222668497106481152']},
#    'author_id': '1036986168578125824',
#    'created_at': '2020-01-30T00:40:34.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'Capitals'}],
#     'urls': [{'start': 36,
#       'end': 59,
#       'url': 'https://t.co/EZvtTj0hjJ',
#       'expanded_url': 'https://twitter.com/Capitals/status/1222669631275573255/photo/1',
#       'display_url': 'pic.twitter.com/EZvtTj0hjJ'}]},
#    'id': '1222680970031222786',
#    'lang': 'en',
#    'possibly_sensitive': False,
# ...
#     'quote_count': 0},
#    'text': 'RT @kemperboyd: Ein ungeordenter Nachruf. https://t.co/o2izC07Zsc https://t.co/QtrFevdZxS',
#    'format': 'detailed'},
#   {'author_id': '813552826609729536',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'BeWarmers'}]},
#    'id': '1222680964641574915',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1221529509159165952'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 203019,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @BeWarmers: To the generation who grew up shouting 'KOBE' anytime they threw something.\n\nDon't stop doing it, don't let the tradition di…",
#    'format': 'detailed'},
#   {'author_id': '1100596192046542849',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'nicaguieb'}]},
#    'id': '1222680964565848065',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222101472759799809'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 22964,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @nicaguieb: hello, with all due respect, may I interrupt your mourning for Kobe for a while and let us take a look with this, let us kee…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '580353731',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680964540792833',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222205841346048007']},
#    'author_id': '1098772014846930944',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'skrttgangg'}],
#     'urls': [{'start': 34,
#       'end': 57,
#       'url': 'https://t.co/7nXpP6tDxX',
#       'expanded_url': 'https://twitter.com/skrttgangg/status/1222205848174374912/photo/1',
#       'display_url': 'pic.twitter.com/7nXpP6tDxX'}]},
#    'id': '1222680964419198976',
#    'lang': 'ht',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222205848174374912'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 5570,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @skrttgangg: Kenan, Kel e Kobe https://t.co/7nXpP6tDxX',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_856360344020582401']},
#    'author_id': '953419211056979968',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'LakersEmpire'}],
#     'urls': [{'start': 79,
#       'end': 102,
#       'url': 'https://t.co/RGmQUXrMIi',
#       'expanded_url': 'https://twitter.com/NBALakersNation/status/856360657209274368/video/1',
#       'display_url': 'pic.twitter.com/RGmQUXrMIi'}]},
#    'id': '1222680964393918465',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222657967859757057'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 587,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @LakersEmpire: Jeanie Buss thanks Kobe Bryant with a retirement ring (TB)\n\n https://t.co/RGmQUXrMIi',
#    'format': 'detailed'},
#   {'author_id': '967617043548790784',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'Charged_UpDolo'}]},
#    'id': '1222680964209360896',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'quoted', 'id': '1222313578184597504'},
#     {'type': 'retweeted', 'id': '1222316150933073921'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 13717,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Charged_UpDolo: Damn Shaq shedding real nigga genuine tears on live tv. Kobe man you got the whole NBA hurting 🙏🏾😢',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['13_1222679025950298112']},
#    'author_id': '754930194528468992',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 7, 'username': 'NHL'},
#      {'start': 52, 'end': 57, 'username': 'ovi8'}],
#     'urls': [{'start': 108,
#       'end': 131,
#       'url': 'https://t.co/v3jgbpCqQK',
#       'expanded_url': 'https://twitter.com/NHL/status/1222679648515100673/video/1',
#       'display_url': 'pic.twitter.com/v3jgbpCqQK'}]},
#    'id': '1222680964121481216',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222679648515100673'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 116,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @NHL: From one great to another.\n\nAlex Ovechkin (@ovi8) honors the late Kobe Bryant in tonight's warmup. https://t.co/v3jgbpCqQK",
#    'format': 'detailed'},
#   {'author_id': '1263954156',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'Bellingersworld'}]},
#    'id': '1222680963907346432',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222308402434641920'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 9496,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Bellingersworld: Kobe and Vanessa made a pact years ago that they would never ride a helicopter together just in case it crashed so the…',
#    'format': 'detailed'},
#   {'author_id': '1174490153282412544',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'bonecarrier'}]},
#    'id': '1222680963731333120',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222239188780822536'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 29799,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @bonecarrier: i love how Kobe Said “I love the challenge of raising women” all of you “i’m scared to have a daughter” losers look even m…',
#    'format': 'detailed'},
#   {'author_id': '498388127',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'gfstarr1'}]},
#    'id': '1222680963710431232',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1221981257048973313'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 9549,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @gfstarr1: If you want to honor the lives of Kobe and Gigi Bryant, support women in sports and women’s sports teams. Give them your time…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['3_1222668497106481152']},
#    'author_id': '171568879',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'Capitals'}],
#     'urls': [{'start': 36,
#       'end': 59,
#       'url': 'https://t.co/EZvtTj0hjJ',
#       'expanded_url': 'https://twitter.com/Capitals/status/1222669631275573255/photo/1',
#       'display_url': 'pic.twitter.com/EZvtTj0hjJ'}]},
#    'id': '1222680963584491527',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222669631275573255'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 2503,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Capitals: 8 —&gt; 24\n\nFor Kobe. https://t.co/EZvtTj0hjJ',
#    'format': 'detailed'},
#   {'author_id': '1012410890673623040',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'KingTrillaX'}]},
#    'id': '1222680963165106176',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1221569481803292673'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 137601,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @KingTrillaX: TMZ broke the news that Kobe and Gianna passed away before his family was informed.\n\nI don’t know how we’re going to do it…',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '2717731599',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680963060305920',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'author_id': '208053736',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'urls': [{'start': 63,
#       'end': 86,
#       'url': 'https://t.co/6ybVhU9MvJ',
#       'expanded_url': 'https://www.teenoi.net/?p=23536',
#       'display_url': 'teenoi.net/?p=23536'}]},
#    'id': '1222680963035082754',
#    'lang': 'fr',
#    'possibly_sensitive': False,
#    'source': '<a href="https://www.wtbass.com/" rel="nofollow">wtbass</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Basket esport – Kobe Bryant était aussi une icône vidéoludique https://t.co/6ybVhU9MvJ',
#    'format': 'detailed'},
#   {'author_id': '1222135764466749440',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'hashtags': [{'start': 50, 'end': 59, 'tag': 'LakeShow'}],
#     'mentions': [{'start': 0, 'end': 14, 'username': 'ComplexSports'},
#      {'start': 15, 'end': 27, 'username': 'npowell2404'},
#      {'start': 84, 'end': 96, 'username': 'kellyamedia'},
#      {'start': 97, 'end': 111, 'username': 'ComplexSports'},
#      {'start': 112, 'end': 120, 'username': 'Complex'},
#      {'start': 121, 'end': 133, 'username': 'npowell2404'},
#      {'start': 134, 'end': 148, 'username': 'giannahaneeey'},
#      {'start': 149, 'end': 162, 'username': 'not_benkelly'},
#      {'start': 163, 'end': 179, 'username': 'SuperDudeYoGurl'},
#      {'start': 180, 'end': 196, 'username': 'DominickGallant'},
#      {'start': 197, 'end': 211, 'username': 'jesus87594789'},
#      {'start': 212, 'end': 225, 'username': 'jerryvalles_'},
#      {'start': 226, 'end': 237, 'username': 'tonebloker'},
#      {'start': 238, 'end': 250, 'username': 'SheuliTaher'},
#      {'start': 251, 'end': 263, 'username': 'jessicuh_19'},
#      {'start': 264, 'end': 273, 'username': 'DaveCIII'},
#      {'start': 274, 'end': 284, 'username': 'Ricca_Ric'},
#      {'start': 285, 'end': 295, 'username': 'OgClutch1'},
#      {'start': 296, 'end': 302, 'username': 'p2foe'}],
#     'urls': [{'start': 60,
#       'end': 83,
#       'url': 'https://t.co/uP6HKRF6OY',
#       'expanded_url': 'https://teelisst.com/product/kobe-gigi-unisex-hoodie/',
#       'display_url': 'teelisst.com/product/kobe-g…'}]},
#    'id': '1222680962871578624',
#    'in_reply_to_user_id': '262715431',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1222300146442145794'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': '@ComplexSports @npowell2404 I got shirt from here\n#LakeShow\nhttps://t.co/uP6HKRF6OY\n@kellyamedia\n@ComplexSports\n@Complex\n@npowell2404\n@giannahaneeey\n@not_benkelly\n@SuperDudeYoGurl\n@DominickGallant\n@jesus87594789\n@jerryvalles_\n@tonebloker\n@SheuliTaher\n@jessicuh_19\n@DaveCIII\n@Ricca_Ric\n@OgClutch1\n@p2foe',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222380323658518529']},
#    'author_id': '91637508',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'DANNYOLGETREE'}],
#     'urls': [{'start': 81,
#       'end': 104,
#       'url': 'https://t.co/uph7LGur2g',
#       'expanded_url': 'https://twitter.com/DANNYOLGETREE/status/1222380427614224385/video/1',
#       'display_url': 'pic.twitter.com/uph7LGur2g'}]},
#    'id': '1222680962871570438',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222380427614224385'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 19213,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @DANNYOLGETREE: This is hands down the best description of Kobe Bryant yet 😭😔 https://t.co/uph7LGur2g',
#    'format': 'detailed'},
#   {'attachments': {'media_keys': ['7_1222598651802943490']},
#    'author_id': '39555815',
#    'created_at': '2020-01-30T00:40:32.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'SLAMRewind'}],
#     'urls': [{'start': 74,
#       'end': 97,
#       'url': 'https://t.co/iAK5TvySfj',
#       'expanded_url': 'https://twitter.com/SLAMRewind/status/1222598736431501315/video/1',
#       'display_url': 'pic.twitter.com/iAK5TvySfj'}]},
#    'id': '1222680962334674945',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222598736431501315'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 3740,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @SLAMRewind: The love that Kobe showed to other players was so real ✊🏽 https://t.co/iAK5TvySfj',
#    'format': 'detailed'}],
#  'meta': {'newest_id': '1222680977165647874',
#   'oldest_id': '1222680962334674945',
#   'next_token': 'b26v89c19zqg8o3fo71enouyxs7qu9ewm0wc8f0xz8uwt',
#   'result_count': 100}}

# %%
tweets_search['data'][0]
# Out:
# {'attachments': {'media_keys': ['13_1222613410485014529']},
#  'author_id': '2742356057',
#  'created_at': '2020-01-30T00:40:35.000Z',
#  'entities': {'mentions': [{'start': 3, 'end': 8, 'username': 'espn'}],
#   'urls': [{'start': 74,
#     'end': 97,
#     'url': 'https://t.co/ThBIjzKWVN',
#     'expanded_url': 'https://twitter.com/espn/status/1222614701277949952/video/1',
#     'display_url': 'pic.twitter.com/ThBIjzKWVN'}]},
#  'id': '1222680977165647874',
#  'lang': 'en',
#  'possibly_sensitive': False,
#  'referenced_tweets': [{'type': 'retweeted', 'id': '1222614701277949952'}],
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'stats': {'retweet_count': 4970,
#   'reply_count': 0,
#   'like_count': 0,
#   'quote_count': 0},
#  'text': 'RT @espn: Zaire Wade hit the Kobe celebration after throwing down a dunk. https://t.co/ThBIjzKWVN',
#  'format': 'detailed'}

# %% [markdown]
# # Test Call To "/labs/1/tweets/stream/search" Endpoint

# %% [markdown]
# **The Labs recent search endpoint returns Tweets from the last 7 days that match a search query.**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'query': 'data',
    'format': 'detailed',
    'tweet.format': 'detailed',
    'user.format': 'detailed',
    'place.format': 'detailed'
}

search_url = 'https://api.twitter.com/labs/1/tweets/search'

request_4 = requests.get(search_url, headers=search_headers, params=search_params)
tweets_stream = request_4.json()
tweets_stream
# Out:
# {'data': [{'attachments': {'media_keys': ['7_1222670186265960448']},
#    'author_id': '735610146001424385',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'hashtags': [{'start': 105, 'end': 114, 'tag': 'PS4share'}],
#     'mentions': [{'start': 3, 'end': 12, 'username': 'acerikus'}],
#     'urls': [{'start': 115,
#       'end': 138,
#       'url': 'https://t.co/Pd5iXup0nl',
#       'expanded_url': 'https://twitter.com/acerikus/status/1222670895833133060/video/1',
#       'display_url': 'pic.twitter.com/Pd5iXup0nl'}]},
#    'id': '1222682645844369410',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222670895833133060'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @acerikus: Here's  a quick guide to using both sides of the island at the same time in data greeting! #PS4share https://t.co/Pd5iXup0nl",
#    'format': 'detailed'},
#   {'author_id': '56302852',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SenTomCotton'}]},
#    'id': '1222682645580013568',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222622439202574338'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 161,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @SenTomCotton: China's government restricts information about outbreaks to control its citizens. During the 2003 SARS outbreak, restrict…",
#    'format': 'detailed'},
#   {'author_id': '840314166091034624',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'Politidope'},
#      {'start': 24, 'end': 32, 'username': 'Reuters'}]},
#    'id': '1222682645286420480',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222631887295959040'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 584,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Politidope: NEW via @Reuters: 60% of voters believe Trump should be removed or censured.\n\nOnly 30% (🚨) of voters believe the charges ag…',
#    'format': 'detailed'},
#   {'author_id': '1045491629149237249',
#    'created_at': '2020-01-30T00:47:12.000Z',
#    'entities': {'hashtags': [{'start': 187,
#       'end': 203,
#       'tag': 'rstudioconf2020'}],
#     'mentions': [{'start': 28, 'end': 38, 'username': 'ryantimpe'}]},
#    'id': '1222682640899178496',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "Feeling really inspired by  @ryantimpe's talk on using fun/funny/silly/cool side projects to become a better data scientist. This talk had it all: drinking games, dinosaurs and Legos! 💥\n\n#rstudioconf2020",
#    'format': 'detailed'},
#   {'author_id': '57032961',
#    'created_at': '2020-01-30T00:47:12.000Z',
#    'entities': {'hashtags': [{'start': 126, 'end': 137, 'tag': 'DataMining'}],
#     'mentions': [{'start': 3, 'end': 19, 'username': 'machinelearnflx'}],
#     'urls': [{'start': 101,
#       'end': 124,
#       'url': 'https://t.co/FZFAlsX1jC',
#       'expanded_url': 'https://www.forbes.com/sites/andygreenberg/2013/08/14/agent-of-intelligence-how-a-deviant-philosopher-built-palantir-a-cia-funded-data-mining-juggernaut/#',
#       'display_url': 'forbes.com/sites/andygree…'}]},
#    'id': '1222682640123228160',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222489221908267008'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 13,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @machinelearnflx: How A 'Deviant' Philosopher Built Palantir, A CIA-Funded Data-Mining Juggernaut https://t.co/FZFAlsX1jC  #DataMining",
#    'format': 'detailed'},
#   {'author_id': '100377929',
#    'created_at': '2020-01-30T00:47:11.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'IlilliIlilillll'}],
#     'urls': [{'start': 78,
#       'end': 101,
#       'url': 'https://t.co/dFDkvkx0od',
#       'expanded_url': 'http://www.newdaily.co.kr/site/data/html/2020/01/29/2020012900195.html',
#       'display_url': 'newdaily.co.kr/site/data/html…'}]},
#    'id': '1222682637396922368',
#    'lang': 'ko',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222547661548441600'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 275,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @IlilliIlilillll: [단독] 민주당 '영입인재' 조동인 스펙용 창업?… 1주일 만에 기업 3개 설립, 2년 뒤 동시 폐업\nhttps://t.co/dFDkvkx0od\n\n어쩜 쎄한건 틀리질 않는건지.....\n이해찬은 지한테 딸랑거리면…",
#    'format': 'detailed'},
#   {'author_id': '1711148635',
#    'created_at': '2020-01-30T00:47:11.000Z',
#    'entities': {'hashtags': [{'start': 89, 'end': 99, 'tag': 'Australia'}],
#     'mentions': [{'start': 3, 'end': 14, 'username': 'MJVentrice'}]},
#    'id': '1222682634528206848',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222547920349810688'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 177,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @MJVentrice: This video of firefighters narrowly escaping an escalating brush fire in #Australia illustrates the collaboration that is n…',
#    'format': 'detailed'},
#   {'author_id': '2547175225',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'derektmead'},
#      {'start': 17, 'end': 22, 'username': 'VICE'}]},
#    'id': '1222682633894858752',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222608551128027141'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 559,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @derektmead: .@VICE has gotten its hands on fare evasion data that the NYPD has fought tooth and nail to hide. Spoiler: enforcement is p…',
#    'format': 'detailed'},
#   {'author_id': '908887412310409216',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'hashtags': [{'start': 9, 'end': 18, 'tag': 'Facebook'},
#      {'start': 19, 'end': 29, 'tag': 'TrollFarm'},
#      {'start': 30, 'end': 38, 'tag': 'BotArmy'},
#      {'start': 39, 'end': 51, 'tag': 'TrumpRussia'},
#      {'start': 117, 'end': 131, 'tag': 'DrainTheSwamp'}],
#     'urls': [{'start': 150,
#       'end': 173,
#       'url': 'https://t.co/isRrp4vSDz',
#       'expanded_url': 'https://data.world/d1gi/missing-fb-posts-w-share-stats',
#       'display_url': 'data.world/d1gi/missing-f…'}]},
#    'id': '1222682631311110144',
#    'lang': 'cs',
#    'possibly_sensitive': False,
#    'source': '<a href="http://www.test.com" rel="nofollow">PaxAutomica</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Here\'s a #Facebook #TrollFarm #BotArmy #TrumpRussia example: "Make America great and strong again! Do\u200b \u200byou\u200b \u200bagree? #DrainTheSwamp" Angry? отличный! https://t.co/isRrp4vSDz',
#    'format': 'detailed'},
#   {'author_id': '1116606101129064448',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 10, 'username': 'itysM3'}],
#     'urls': [{'start': 111,
#       'end': 134,
#       'url': 'https://t.co/r703oZz2m9',
#       'expanded_url': 'https://wa.me/966548061405',
#       'display_url': 'wa.me/966548061405'}]},
#    'id': '1222682630866579458',
#    'lang': 'ar',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222474405802016768'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 48,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @itysM3: نستقدم سواقين في15يوم والدفع بعد وصول السواق باذن الله تعالى\nمن الهند السودان مصر باكستان\nللطلب / \nhttps://t.co/r703oZz2m9',
#    'format': 'detailed'}],
#  'meta': {'newest_id': '1222682645844369410',
#   'oldest_id': '1222682630866579458',
#   'next_token': 'b26v89c19zqg8o3fo71enouz0stfojruisiyptn3hz059',
#   'result_count': 10}}

# %%
#10 real-time streamed tweets are returned from around the world for the query
#you can use 'next_token' to paginate through Twitter results
tweets_stream['meta']['result_count']
# Out:
# 10

# %% [markdown]
# # Test Call To "/labs/1/tweets/stream/sample" Endpoint

# %% [markdown]
# **/labs/1/tweets/stream/sample endpoint Streams about 1% of all Tweets in real-time.**

# %%
#code commented out because it takes too long to run.

# search_headers = {
#     'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
# }

# search_params = {
#     'format': 'detailed',
#     'tweet.format': 'detailed',
#     'user.format': 'detailed',
#     'place.format': 'detailed'
# }

# search_url = 'https://api.twitter.com/labs/1/tweets/stream/sample'

# request_5 = requests.get(search_url, headers=search_headers, params=search_params)
# tweets_sample = request_5.json()
# tweets_sample

# %% [markdown]
# # Test Call To "/labs/1/tweets/stream/filter" Endpoint

# %% [markdown]
# **/labs/1/tweets/stream/filter endpoint streams Tweets in real-time based on a specific set of filter rules**

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'query': 'data',
    'format': 'detailed',
    'tweet.format': 'detailed',
    'user.format': 'detailed',
    'place.format': 'detailed'
}

search_url = 'https://api.twitter.com/labs/1/tweets/search'

request_4 = requests.get(search_url, headers=search_headers, params=search_params)
tweets_stream = request_4.json()
tweets_stream
# Out:
# {'data': [{'attachments': {'media_keys': ['7_1222670186265960448']},
#    'author_id': '735610146001424385',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'hashtags': [{'start': 105, 'end': 114, 'tag': 'PS4share'}],
#     'mentions': [{'start': 3, 'end': 12, 'username': 'acerikus'}],
#     'urls': [{'start': 115,
#       'end': 138,
#       'url': 'https://t.co/Pd5iXup0nl',
#       'expanded_url': 'https://twitter.com/acerikus/status/1222670895833133060/video/1',
#       'display_url': 'pic.twitter.com/Pd5iXup0nl'}]},
#    'id': '1222682645844369410',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222670895833133060'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 10,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @acerikus: Here's  a quick guide to using both sides of the island at the same time in data greeting! #PS4share https://t.co/Pd5iXup0nl",
#    'format': 'detailed'},
#   {'author_id': '56302852',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'SenTomCotton'}]},
#    'id': '1222682645580013568',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222622439202574338'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 161,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @SenTomCotton: China's government restricts information about outbreaks to control its citizens. During the 2003 SARS outbreak, restrict…",
#    'format': 'detailed'},
#   {'author_id': '840314166091034624',
#    'created_at': '2020-01-30T00:47:13.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'Politidope'},
#      {'start': 24, 'end': 32, 'username': 'Reuters'}]},
#    'id': '1222682645286420480',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222631887295959040'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 584,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @Politidope: NEW via @Reuters: 60% of voters believe Trump should be removed or censured.\n\nOnly 30% (🚨) of voters believe the charges ag…',
#    'format': 'detailed'},
#   {'author_id': '1045491629149237249',
#    'created_at': '2020-01-30T00:47:12.000Z',
#    'entities': {'hashtags': [{'start': 187,
#       'end': 203,
#       'tag': 'rstudioconf2020'}],
#     'mentions': [{'start': 28, 'end': 38, 'username': 'ryantimpe'}]},
#    'id': '1222682640899178496',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "Feeling really inspired by  @ryantimpe's talk on using fun/funny/silly/cool side projects to become a better data scientist. This talk had it all: drinking games, dinosaurs and Legos! 💥\n\n#rstudioconf2020",
#    'format': 'detailed'},
#   {'author_id': '57032961',
#    'created_at': '2020-01-30T00:47:12.000Z',
#    'entities': {'hashtags': [{'start': 126, 'end': 137, 'tag': 'DataMining'}],
#     'mentions': [{'start': 3, 'end': 19, 'username': 'machinelearnflx'}],
#     'urls': [{'start': 101,
#       'end': 124,
#       'url': 'https://t.co/FZFAlsX1jC',
#       'expanded_url': 'https://www.forbes.com/sites/andygreenberg/2013/08/14/agent-of-intelligence-how-a-deviant-philosopher-built-palantir-a-cia-funded-data-mining-juggernaut/#',
#       'display_url': 'forbes.com/sites/andygree…'}]},
#    'id': '1222682640123228160',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222489221908267008'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 13,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @machinelearnflx: How A 'Deviant' Philosopher Built Palantir, A CIA-Funded Data-Mining Juggernaut https://t.co/FZFAlsX1jC  #DataMining",
#    'format': 'detailed'},
#   {'author_id': '100377929',
#    'created_at': '2020-01-30T00:47:11.000Z',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'IlilliIlilillll'}],
#     'urls': [{'start': 78,
#       'end': 101,
#       'url': 'https://t.co/dFDkvkx0od',
#       'expanded_url': 'http://www.newdaily.co.kr/site/data/html/2020/01/29/2020012900195.html',
#       'display_url': 'newdaily.co.kr/site/data/html…'}]},
#    'id': '1222682637396922368',
#    'lang': 'ko',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222547661548441600'}],
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'stats': {'retweet_count': 275,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': "RT @IlilliIlilillll: [단독] 민주당 '영입인재' 조동인 스펙용 창업?… 1주일 만에 기업 3개 설립, 2년 뒤 동시 폐업\nhttps://t.co/dFDkvkx0od\n\n어쩜 쎄한건 틀리질 않는건지.....\n이해찬은 지한테 딸랑거리면…",
#    'format': 'detailed'},
#   {'author_id': '1711148635',
#    'created_at': '2020-01-30T00:47:11.000Z',
#    'entities': {'hashtags': [{'start': 89, 'end': 99, 'tag': 'Australia'}],
#     'mentions': [{'start': 3, 'end': 14, 'username': 'MJVentrice'}]},
#    'id': '1222682634528206848',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222547920349810688'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 177,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @MJVentrice: This video of firefighters narrowly escaping an escalating brush fire in #Australia illustrates the collaboration that is n…',
#    'format': 'detailed'},
#   {'author_id': '2547175225',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'derektmead'},
#      {'start': 17, 'end': 22, 'username': 'VICE'}]},
#    'id': '1222682633894858752',
#    'lang': 'en',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222608551128027141'}],
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'stats': {'retweet_count': 559,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @derektmead: .@VICE has gotten its hands on fare evasion data that the NYPD has fought tooth and nail to hide. Spoiler: enforcement is p…',
#    'format': 'detailed'},
#   {'author_id': '908887412310409216',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'hashtags': [{'start': 9, 'end': 18, 'tag': 'Facebook'},
#      {'start': 19, 'end': 29, 'tag': 'TrollFarm'},
#      {'start': 30, 'end': 38, 'tag': 'BotArmy'},
#      {'start': 39, 'end': 51, 'tag': 'TrumpRussia'},
#      {'start': 117, 'end': 131, 'tag': 'DrainTheSwamp'}],
#     'urls': [{'start': 150,
#       'end': 173,
#       'url': 'https://t.co/isRrp4vSDz',
#       'expanded_url': 'https://data.world/d1gi/missing-fb-posts-w-share-stats',
#       'display_url': 'data.world/d1gi/missing-f…'}]},
#    'id': '1222682631311110144',
#    'lang': 'cs',
#    'possibly_sensitive': False,
#    'source': '<a href="http://www.test.com" rel="nofollow">PaxAutomica</a>',
#    'stats': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'Here\'s a #Facebook #TrollFarm #BotArmy #TrumpRussia example: "Make America great and strong again! Do\u200b \u200byou\u200b \u200bagree? #DrainTheSwamp" Angry? отличный! https://t.co/isRrp4vSDz',
#    'format': 'detailed'},
#   {'author_id': '1116606101129064448',
#    'created_at': '2020-01-30T00:47:10.000Z',
#    'entities': {'mentions': [{'start': 3, 'end': 10, 'username': 'itysM3'}],
#     'urls': [{'start': 111,
#       'end': 134,
#       'url': 'https://t.co/r703oZz2m9',
#       'expanded_url': 'https://wa.me/966548061405',
#       'display_url': 'wa.me/966548061405'}]},
#    'id': '1222682630866579458',
#    'lang': 'ar',
#    'possibly_sensitive': False,
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1222474405802016768'}],
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'stats': {'retweet_count': 48,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'text': 'RT @itysM3: نستقدم سواقين في15يوم والدفع بعد وصول السواق باذن الله تعالى\nمن الهند السودان مصر باكستان\nللطلب / \nhttps://t.co/r703oZz2m9',
#    'format': 'detailed'}],
#  'meta': {'newest_id': '1222682645844369410',
#   'oldest_id': '1222682630866579458',
#   'next_token': 'b26v89c19zqg8o3fo71enouz0stfojruisiyptn3hz059',
#   'result_count': 10}}

# %%
tweets_stream['meta']['result_count']
# Out:
# 10

# %% [markdown]
# ___

# %%
search_headers = {
    'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
}

search_params = {
    'q': 'financial',
    'result_type': 'mixed',
    'count': 100
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

response_mixed = requests.get(search_url, headers=search_headers, params=search_params)
mixed = response_mixed.json()
mixed
# Out:
# {'statuses': [{'created_at': 'Thu Jan 30 18:38:55 +0000 2020',
#    'id': 1222952347548164098,
#    'id_str': '1222952347548164098',
#    'text': 'I am sad to see our British friends leave the EU. We will act within our mandate to ensure Brexit causes as little… https://t.co/yeOkM8gyWI',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yeOkM8gyWI',
#       'expanded_url': 'https://twitter.com/i/web/status/1222952347548164098',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 304909941,
#     'id_str': '304909941',
#     'name': 'Christine Lagarde',
#     'screen_name': 'Lagarde',
#     'location': 'Frankfurt on the Main, Germany',
#     'description': 'President of the @ecb, the central bank for the euro. I manage this account with my team.',
#     'url': 'https://t.co/1hCHcAJ7sd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/1hCHcAJ7sd',
#         'expanded_url': 'http://www.ecb.europa.eu',
#         'display_url': 'ecb.europa.eu',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 599522,
#     'friends_count': 68,
#     'listed_count': 6452,
#     'created_at': 'Wed May 25 09:40:07 +0000 2011',
#     'favourites_count': 12,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 1755,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190193703006154753/6UyRHcPE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190193703006154753/6UyRHcPE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/304909941/1571394907',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1461,
#    'favorite_count': 6192,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 02:26:09 +0000 2020',
#    'id': 1223069930540630017,
#    'id_str': '1223069930540630017',
#    'text': 'Wealth is the power to choose.\n\nFinancial wealth is the power to choose how to spend money.\n\nSocial wealth is the p… https://t.co/7HiCxWwADY',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/7HiCxWwADY',
#       'expanded_url': 'https://twitter.com/i/web/status/1223069930540630017',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 226428094,
#     'id_str': '226428094',
#     'name': 'James Clear',
#     'screen_name': 'JamesClear',
#     'location': 'Columbus, OH',
#     'description': 'Author of the NYT bestseller, Atomic Habits (https://t.co/S97QUDuBUa). I write about how to build better habits. Over 500k people read my 3-2-1 newsletter (see link).',
#     'url': 'https://t.co/9KfuKZ2MO1',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/9KfuKZ2MO1',
#         'expanded_url': 'http://jamesclear.com/3-2-1',
#         'display_url': 'jamesclear.com/3-2-1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/S97QUDuBUa',
#         'expanded_url': 'http://atomichabits.com',
#         'display_url': 'atomichabits.com',
#         'indices': [45, 68]}]}},
#     'protected': False,
#     'followers_count': 245065,
#     'friends_count': 396,
#     'listed_count': 3790,
#     'created_at': 'Tue Dec 14 03:58:09 +0000 2010',
#     'favourites_count': 8739,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 10847,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'FAFAFA',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/958932211973152769/FUpkmn4u_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958932211973152769/FUpkmn4u_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226428094/1557171326',
#     'profile_link_color': '0071BC',
#     'profile_sidebar_border_color': 'E3E3E3',
#     'profile_sidebar_fill_color': 'D1EDFF',
#     'profile_text_color': '222222',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1232,
#    'favorite_count': 4429,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 13:28:42 +0000 2020',
#    'id': 1223236665138929664,
#    'id_str': '1223236665138929664',
#    'text': 'In next 2 weeks, we will introduce a new program under Ehsaas. We will be giving cows to deserving women. For examp… https://t.co/dyJZlCbVvK',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/dyJZlCbVvK',
#       'expanded_url': 'https://twitter.com/i/web/status/1223236665138929664',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'result_type': 'popular', 'iso_language_code': 'en'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1040146057093627904,
#     'id_str': '1040146057093627904',
#     'name': "Prime Minister's Office, Pakistan",
#     'screen_name': 'PakPMO',
#     'location': 'Islamabad, Pakistan',
#     'description': "Official account of Prime Minister's Office, Government of Pakistan",
#     'url': 'https://t.co/UFEbzKWrBk',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/UFEbzKWrBk',
#         'expanded_url': 'http://www.pmo.gov.pk/',
#         'display_url': 'pmo.gov.pk',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 158654,
#     'friends_count': 11,
#     'listed_count': 140,
#     'created_at': 'Thu Sep 13 07:51:59 +0000 2018',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 2536,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1041290611209449473/GOcu2y2a_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041290611209449473/GOcu2y2a_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1040146057093627904/1567182310',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 357,
#    'favorite_count': 1678,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:25 +0000 2020',
#    'id': 1223337507846266881,
#    'id_str': '1223337507846266881',
#    'text': 'RT @blakesmustache: The impeachment inquiry is *NOT* over. \n\nWe will get Mueller’s grand jury materials. We will get Trump’s tax and financ…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'blakesmustache',
#       'name': 'Uncle Blazer',
#       'id': 2341440244,
#       'id_str': '2341440244',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 85513216,
#     'id_str': '85513216',
#     'name': 'JoePineSD',
#     'screen_name': 'JoePineSD',
#     'location': 'San Diego CA / Columbus OH',
#     'description': 'Drummer, music video director, Mobile Crane Op, student of film and politics. JNP Productions owner. #Resist I enjoy fact based debate, but that seldom happens',
#     'url': 'https://t.co/WgX58NUb68',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WgX58NUb68',
#         'expanded_url': 'http://www.jnpproductions.com',
#         'display_url': 'jnpproductions.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1473,
#     'friends_count': 1897,
#     'listed_count': 3,
#     'created_at': 'Tue Oct 27 06:40:30 +0000 2009',
#     'favourites_count': 35031,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9794,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1014180565203836928/_NWtVJvC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014180565203836928/_NWtVJvC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/85513216/1531974945',
#     'profile_link_color': 'F70808',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 12:00:55 +0000 2020',
#     'id': 1223214572825432064,
#     'id_str': '1223214572825432064',
#     'text': 'The impeachment inquiry is *NOT* over. \n\nWe will get Mueller’s grand jury materials. We will get Trump’s tax and fi… https://t.co/zh5BUFeLkB',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/zh5BUFeLkB',
#        'expanded_url': 'https://twitter.com/i/web/status/1223214572825432064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2341440244,
#      'id_str': '2341440244',
#      'name': 'Uncle Blazer',
#      'screen_name': 'blakesmustache',
#      'location': '',
#      'description': 'Lawyer w/o inside info who follows the Trump investigations closely and applies deductive reasoning. No affiliation w/ Blake Anderson. FOLLOW THE MONEY!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 75289,
#      'friends_count': 57,
#      'listed_count': 443,
#      'created_at': 'Thu Feb 13 14:55:59 +0000 2014',
#      'favourites_count': 34937,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6526,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1215256274146856960/4botFA48_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215256274146856960/4botFA48_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3785,
#     'favorite_count': 14214,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3785,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:24 +0000 2020',
#    'id': 1223337507124695041,
#    'id_str': '1223337507124695041',
#    'text': 'RT @blakesmustache: The impeachment inquiry is *NOT* over. \n\nWe will get Mueller’s grand jury materials. We will get Trump’s tax and financ…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'blakesmustache',
#       'name': 'Uncle Blazer',
#       'id': 2341440244,
#       'id_str': '2341440244',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 752252888794165248,
#     'id_str': '752252888794165248',
#     'name': 'Roz Devin',
#     'screen_name': 'rozdance5678',
#     'location': 'Los Gatos, CA',
#     'description': 'dancer, actor - advocate for victims of narcissistic abuse, c-ptsd, writer@ https://t.co/OeUY83n2Rf - Happiness@#HNP #theresisters- #VoteBlueNoMatterWho',
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/OeUY83n2Rf',
#         'expanded_url': 'http://Quora.com',
#         'display_url': 'Quora.com',
#         'indices': [76, 99]}]}},
#     'protected': False,
#     'followers_count': 683,
#     'friends_count': 1465,
#     'listed_count': 0,
#     'created_at': 'Sun Jul 10 21:27:19 +0000 2016',
#     'favourites_count': 14529,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 15164,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/938541357013942272/GfMzwkq7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/938541357013942272/GfMzwkq7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/752252888794165248/1580000213',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 12:00:55 +0000 2020',
#     'id': 1223214572825432064,
#     'id_str': '1223214572825432064',
#     'text': 'The impeachment inquiry is *NOT* over. \n\nWe will get Mueller’s grand jury materials. We will get Trump’s tax and fi… https://t.co/zh5BUFeLkB',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/zh5BUFeLkB',
#        'expanded_url': 'https://twitter.com/i/web/status/1223214572825432064',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2341440244,
#      'id_str': '2341440244',
#      'name': 'Uncle Blazer',
#      'screen_name': 'blakesmustache',
#      'location': '',
#      'description': 'Lawyer w/o inside info who follows the Trump investigations closely and applies deductive reasoning. No affiliation w/ Blake Anderson. FOLLOW THE MONEY!',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 75289,
#      'friends_count': 57,
#      'listed_count': 443,
#      'created_at': 'Thu Feb 13 14:55:59 +0000 2014',
#      'favourites_count': 34937,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 6526,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1215256274146856960/4botFA48_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215256274146856960/4botFA48_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3785,
#     'favorite_count': 14214,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3785,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:24 +0000 2020',
#    'id': 1223337505430429696,
#    'id_str': '1223337505430429696',
#    'text': 'RT @NJSLTBBC: Do you need help with #disability benefits, #financial planning, or a #loan to purchase #assistive #technology? Reach out to…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'disability', 'indices': [36, 47]},
#      {'text': 'financial', 'indices': [58, 68]},
#      {'text': 'loan', 'indices': [84, 89]},
#      {'text': 'assistive', 'indices': [102, 112]},
#      {'text': 'technology', 'indices': [113, 124]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NJSLTBBC',
#       'name': 'NJSL TBBC',
#       'id': 161750739,
#       'id_str': '161750739',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3739732035,
#     'id_str': '3739732035',
#     'name': 'Diversity & Outreach',
#     'screen_name': 'njlaDO',
#     'location': 'New Jersey, USA',
#     'description': "New Jersey Library Association's Diversity & Outreach Section.   Collaborate, Share & Showcase!\nhttps://t.co/bZl0mBSQqg",
#     'url': 'http://t.co/s9cY2PXjpn',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/s9cY2PXjpn',
#         'expanded_url': 'http://njlamembers.org/dosection',
#         'display_url': 'njlamembers.org/dosection',
#         'indices': [0, 22]}]},
#      'description': {'urls': [{'url': 'https://t.co/bZl0mBSQqg',
#         'expanded_url': 'http://librarylinknj.org/do-diversity',
#         'display_url': 'librarylinknj.org/do-diversity',
#         'indices': [96, 119]}]}},
#     'protected': False,
#     'followers_count': 237,
#     'friends_count': 162,
#     'listed_count': 11,
#     'created_at': 'Tue Sep 22 14:50:11 +0000 2015',
#     'favourites_count': 2420,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1576,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/646335946426814464/MyKhIHh3_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/646335946426814464/MyKhIHh3_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3739732035/1442935109',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 20:05:02 +0000 2020',
#     'id': 1223336407613263874,
#     'id_str': '1223336407613263874',
#     'text': 'Do you need help with #disability benefits, #financial planning, or a #loan to purchase #assistive #technology? Rea… https://t.co/1GRvhZReki',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'disability', 'indices': [22, 33]},
#       {'text': 'financial', 'indices': [44, 54]},
#       {'text': 'loan', 'indices': [70, 75]},
#       {'text': 'assistive', 'indices': [88, 98]},
#       {'text': 'technology', 'indices': [99, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/1GRvhZReki',
#        'expanded_url': 'https://twitter.com/i/web/status/1223336407613263874',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 161750739,
#      'id_str': '161750739',
#      'name': 'NJSL TBBC',
#      'screen_name': 'NJSLTBBC',
#      'location': 'Trenton, NJ',
#      'description': 'New Jersey State Library Talking Book & Braille Center, a no-cost public library serving NJ children, teens & adults who have difficulty reading standard print.',
#      'url': 'http://t.co/qyntIYf6G9',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/qyntIYf6G9',
#          'expanded_url': 'http://njstatelib.org/tbbc',
#          'display_url': 'njstatelib.org/tbbc',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 687,
#      'friends_count': 642,
#      'listed_count': 41,
#      'created_at': 'Thu Jul 01 17:37:27 +0000 2010',
#      'favourites_count': 139,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 3187,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/689892974830878722/2RNlAmQO_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/689892974830878722/2RNlAmQO_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/161750739/1575565798',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:24 +0000 2020',
#    'id': 1223337504012677120,
#    'id_str': '1223337504012677120',
#    'text': "RT @NBCNews: US Supreme Court says it has scheduled oral argument March 31 for 3 cases involving access to President Trump's financial docu…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'NBCNews',
#       'name': 'NBC News',
#       'id': 14173315,
#       'id_str': '14173315',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1220799380757807104,
#     'id_str': '1220799380757807104',
#     'name': 'groundrunner2020',
#     'screen_name': 'groundrunner201',
#     'location': '',
#     'description': 'Independentme2020',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13,
#     'friends_count': 216,
#     'listed_count': 0,
#     'created_at': 'Fri Jan 24 20:04:16 +0000 2020',
#     'favourites_count': 1267,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1282,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1220800251709313024/esP-hBER_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220800251709313024/esP-hBER_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 18:13:26 +0000 2020',
#     'id': 1223308322733989889,
#     'id_str': '1223308322733989889',
#     'text': "US Supreme Court says it has scheduled oral argument March 31 for 3 cases involving access to President Trump's fin… https://t.co/Gg5biuGVNg",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Gg5biuGVNg',
#        'expanded_url': 'https://twitter.com/i/web/status/1223308322733989889',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 14173315,
#      'id_str': '14173315',
#      'name': 'NBC News',
#      'screen_name': 'NBCNews',
#      'location': 'New York, NY',
#      'description': 'The leading source of global news and info for more than 75 years. Our new free streaming service: @NBCNewsNow',
#      'url': 'https://t.co/Z73is4fJ3x',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Z73is4fJ3x',
#          'expanded_url': 'http://NBCNews.com',
#          'display_url': 'NBCNews.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7109794,
#      'friends_count': 1814,
#      'listed_count': 42975,
#      'created_at': 'Tue Mar 18 23:19:17 +0000 2008',
#      'favourites_count': 764,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 242766,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '062131',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1108426393287868423/CyLn5GVQ_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1108426393287868423/CyLn5GVQ_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14173315/1579898186',
#      'profile_link_color': '5172A0',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'FFFFFF',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 101,
#     'favorite_count': 197,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 101,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:23 +0000 2020',
#    'id': 1223337500900376576,
#    'id_str': '1223337500900376576',
#    'text': 'RT @BernieSanders: From the start of this campaign, we knew we would be taking on the entire political establishment, the corporate media,…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BernieSanders',
#       'name': 'Bernie Sanders',
#       'id': 216776631,
#       'id_str': '216776631',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 576600484,
#     'id_str': '576600484',
#     'name': 'Rich Wood',
#     'screen_name': 'RichardHWood',
#     'location': 'Pacific NW;  SF, CA',
#     'description': "Radical from the edge of the wilderness, writer, rend (as in Hafez' poetry); activist when able, opponent of any form of imperialism, racism, and misogyny.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 492,
#     'friends_count': 1932,
#     'listed_count': 3,
#     'created_at': 'Thu May 10 21:43:46 +0000 2012',
#     'favourites_count': 6914,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 37073,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/825477666341937152/PWvIds8r_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/825477666341937152/PWvIds8r_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/576600484/1485645028',
#     'profile_link_color': 'DD2E44',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 18:22:50 +0000 2020',
#     'id': 1223310685645438976,
#     'id_str': '1223310685645438976',
#     'text': 'From the start of this campaign, we knew we would be taking on the entire political establishment, the corporate me… https://t.co/d8wzWceZxL',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/d8wzWceZxL',
#        'expanded_url': 'https://twitter.com/i/web/status/1223310685645438976',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 216776631,
#      'id_str': '216776631',
#      'name': 'Bernie Sanders',
#      'screen_name': 'BernieSanders',
#      'location': 'Vermont',
#      'description': 'U.S. Senator from Vermont and candidate for President of the United States.',
#      'url': 'https://t.co/jpg8Sp1GhR',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/jpg8Sp1GhR',
#          'expanded_url': 'https://BernieSanders.com',
#          'display_url': 'BernieSanders.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 10404346,
#      'friends_count': 1446,
#      'listed_count': 20961,
#      'created_at': 'Wed Nov 17 17:53:52 +0000 2010',
#      'favourites_count': 979,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 16782,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'EA5047',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1097820307388334080/9ddg5F6v_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097820307388334080/9ddg5F6v_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/216776631/1574466140',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '050005',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 430,
#     'favorite_count': 1748,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 430,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:22 +0000 2020',
#    'id': 1223337499164119042,
#    'id_str': '1223337499164119042',
#    'text': 'RT @seouItan: I don’t know how many times it needs to be said but bts turned a company on the verge of bankruptcy into a financial giant th…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'seouItan',
#       'name': 'naya ⁷',
#       'id': 1194388892671045638,
#       'id_str': '1194388892671045638',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 873741935537778689,
#     'id_str': '873741935537778689',
#     'name': 'nana ♡⁷ | black swan 🖤',
#     'screen_name': 'ddibidibidibi',
#     'location': '',
#     'description': '#JOHNNY #YUTA #DOYOUNG : lesbian rights!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 138,
#     'friends_count': 620,
#     'listed_count': 2,
#     'created_at': 'Sun Jun 11 03:21:25 +0000 2017',
#     'favourites_count': 8597,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3631,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1218332600432873472/iOGfxtFO_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1218332600432873472/iOGfxtFO_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/873741935537778689/1575320984',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 01:23:36 +0000 2020',
#     'id': 1223054189548326912,
#     'id_str': '1223054189548326912',
#     'text': 'I don’t know how many times it needs to be said but bts turned a company on the verge of bankruptcy into a financia… https://t.co/HAhBwYPENM',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/HAhBwYPENM',
#        'expanded_url': 'https://twitter.com/i/web/status/1223054189548326912',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1194388892671045638,
#      'id_str': '1194388892671045638',
#      'name': 'naya ⁷',
#      'screen_name': 'seouItan',
#      'location': '',
#      'description': '@BTS_twt: Real Eyes, Realize, Real Lies ...',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6290,
#      'friends_count': 237,
#      'listed_count': 52,
#      'created_at': 'Tue Nov 12 22:58:05 +0000 2019',
#      'favourites_count': 6554,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 9303,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1208455486523101184/OPDF0Y-z_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208455486523101184/OPDF0Y-z_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1194388892671045638/1573780286',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6380,
#     'favorite_count': 22045,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6380,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:09:18 +0000 2020',
#    'id': 1223337482479194113,
#    'id_str': '1223337482479194113',
#    'text': '@Haggis_UK @afneil 🤔 Choices, choices! Financial services is the Goose that lays the golden eggs for the economy, a… https://t.co/Rcyra1kC7D',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Haggis_UK',
#       'name': 'Haggis_UK 🇬🇧 🇪🇺',
#       'id': 351784239,
#       'id_str': '351784239',
#       'indices': [0, 10]},
#      {'screen_name': 'afneil',
#       'name': 'Andrew Neil',
#       'id': 136004952,
#       'id_str': '136004952',
#       'indices': [11, 18]}],
#     'urls': [{'url': 'https://t.co/Rcyra1kC7D',
#       'expanded_url': 'https://twitter.com/i/web/status/1223337482479194113',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1222870116267954176,
#    'in_reply_to_status_id_str': '1222870116267954176',
#    'in_reply_to_user_id': 351784239,
#    'in_reply_to_user_id_str': '351784239',
#    'in_reply_to_screen_name': 'Haggis_UK',
#    'user': {'id': 99271749,
#     'id_str': '99271749',
#     'name': 'Huggybear!',
#     'screen_name': 'kevinoti',
#     'location': 'Timbuktu',
#     'description': "All views & opinions are my own except the ones I'm paid to have",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 44,
#     'friends_count': 225,
#     'listed_count': 0,
#     'created_at': 'Fri Dec 25 12:01:39 +0000 2009',
#     'favourites_count': 8291,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1431,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
# ...
#      'in_reply_to_user_id': 2940964728,
#      'in_reply_to_user_id_str': '2940964728',
#      'in_reply_to_screen_name': 'IAStartingLine',
#      'user': {'id': 2940964728,
#       'id_str': '2940964728',
#       'name': 'Iowa Starting Line',
#       'screen_name': 'IAStartingLine',
#       'location': '',
#       'description': 'Your home for Iowa Caucus and Iowa politics news and analysis. Founded in 2015, now one of the largest independent news outlets in the state.',
#       'url': 'https://t.co/DpEAYnDMWv',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/DpEAYnDMWv',
#           'expanded_url': 'http://www.iowastartingline.com',
#           'display_url': 'iowastartingline.com',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 27304,
#       'friends_count': 2099,
#       'listed_count': 619,
#       'created_at': 'Tue Dec 23 16:50:35 +0000 2014',
#       'favourites_count': 5410,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': True,
#       'verified': False,
#       'statuses_count': 38685,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'C0DEED',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1181625797188214784/pTbHaeTi_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1181625797188214784/pTbHaeTi_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2940964728/1553885942',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': None,
#       'follow_request_sent': None,
#       'notifications': None,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2295,
#      'favorite_count': 7478,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 157,
#     'favorite_count': 1261,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1222347342931746821,
#    'quoted_status_id_str': '1222347342931746821',
#    'retweet_count': 157,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:08:17 +0000 2020',
#    'id': 1223337225259233287,
#    'id_str': '1223337225259233287',
#    'text': 'RT @dextrade_: 🚀Crypto Initiation Coin (CICX) is listed on Dex-Trade Exchange now!\n\n#Ccoin was created to become a future of Financial Tech…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Ccoin', 'indices': [84, 90]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dextrade_',
#       'name': 'Dex-Trade',
#       'id': 2345975616,
#       'id_str': '2345975616',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1137382084580954112,
#     'id_str': '1137382084580954112',
#     'name': 'Жазира Взаимно читаю всех',
#     'screen_name': 'Zhazi2508',
#     'location': '',
#     'description': 'Я люблю жизнь',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 489,
#     'friends_count': 123,
#     'listed_count': 0,
#     'created_at': 'Sat Jun 08 15:33:15 +0000 2019',
#     'favourites_count': 1176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 119,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1137382248230133760/taShBjct_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1137382248230133760/taShBjct_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1137382084580954112/1560009029',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 14:23:08 +0000 2020',
#     'id': 1223250365837119489,
#     'id_str': '1223250365837119489',
#     'text': '🚀Crypto Initiation Coin (CICX) is listed on Dex-Trade Exchange now!\n\n#Ccoin was created to become a future of Finan… https://t.co/TMESxvUm2w',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Ccoin', 'indices': [69, 75]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/TMESxvUm2w',
#        'expanded_url': 'https://twitter.com/i/web/status/1223250365837119489',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2345975616,
#      'id_str': '2345975616',
#      'name': 'Dex-Trade',
#      'screen_name': 'dextrade_',
#      'location': '',
#      'description': 'Our platform offers one of the most liquid exchange in the world. We focus on provide to users the most highest security systems.',
#      'url': 'https://t.co/FGz9y7rE7c',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/FGz9y7rE7c',
#          'expanded_url': 'http://www.dex-trade.com',
#          'display_url': 'dex-trade.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 16307,
#      'friends_count': 75,
#      'listed_count': 5,
#      'created_at': 'Sun Feb 16 01:08:05 +0000 2014',
#      'favourites_count': 641,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 273,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1220716448282238977/_2zFigyQ_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1220716448282238977/_2zFigyQ_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2345975616/1579876457',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '0010b4cb51ca93d8',
#      'url': 'https://api.twitter.com/1.1/geo/id/0010b4cb51ca93d8.json',
#      'place_type': 'city',
#      'name': 'Santiago',
#      'full_name': 'Santiago, Chile',
#      'country_code': 'CL',
#      'country': 'Chile',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-70.6929589, -33.4785739],
#         [-70.6262719, -33.4785739],
#         [-70.6262719, -33.4257485],
#         [-70.6929589, -33.4257485]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 100,
#     'favorite_count': 114,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 100,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Jan 31 20:08:17 +0000 2020',
#    'id': 1223337223602393088,
#    'id_str': '1223337223602393088',
#    'text': 'RT @alexspeier: LAD have the best current big leaguer in play (Verdugo), SD offering the best prospect (Campusano) as well as the most piec…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'alexspeier',
#       'name': 'Alex Speier',
#       'id': 45027357,
#       'id_str': '45027357',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1197628172981821440,
#     'id_str': '1197628172981821440',
#     'name': 'jonathan mckenzie',
#     'screen_name': 'jonatha48516322',
#     'location': 'California, USA',
#     'description': 'San Diego is full of bandwagon fans. Still mad because an owner decided not to cater to that type of fanbase. How cute.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16,
#     'friends_count': 89,
#     'listed_count': 0,
#     'created_at': 'Thu Nov 21 21:29:50 +0000 2019',
#     'favourites_count': 1578,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 961,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1213145073187078145/TtJllD_f_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213145073187078145/TtJllD_f_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1197628172981821440/1578071323',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Jan 31 13:55:45 +0000 2020',
#     'id': 1223243475216490498,
#     'id_str': '1223243475216490498',
#     'text': 'LAD have the best current big leaguer in play (Verdugo), SD offering the best prospect (Campusano) as well as the m… https://t.co/ysnkZIDlWc',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ysnkZIDlWc',
#        'expanded_url': 'https://twitter.com/i/web/status/1223243475216490498',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1223243470757933056,
#     'in_reply_to_status_id_str': '1223243470757933056',
#     'in_reply_to_user_id': 45027357,
#     'in_reply_to_user_id_str': '45027357',
#     'in_reply_to_screen_name': 'alexspeier',
#     'user': {'id': 45027357,
#      'id_str': '45027357',
#      'name': 'Alex Speier',
#      'screen_name': 'alexspeier',
#      'location': 'To preorder “Homegrown” (8/13)',
#      'description': 'Sports Writer, Boston Globe; author of “Homegrown” (coming 8/13 from William Morrow Books, an imprint of Harper Collins); moonlights on NESN as Stat Masterson',
#      'url': 'https://t.co/n7ljJciqAK',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/n7ljJciqAK',
#          'expanded_url': 'https://www.harpercollins.com/9780062943552/homegrown/',
#          'display_url': 'harpercollins.com/9780062943552/…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 62920,
#      'friends_count': 974,
#      'listed_count': 2269,
#      'created_at': 'Fri Jun 05 23:23:05 +0000 2009',
#      'favourites_count': 1767,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 40433,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '1A1A1A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/827632389023227905/9C0ClX9K_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/827632389023227905/9C0ClX9K_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/45027357/1561753028',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 19,
#     'favorite_count': 56,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 19,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.107,
#   'max_id': 1223337507846266881,
#   'max_id_str': '1223337507846266881',
#   'next_results': '?max_id=1222952347548164097&q=financial&count=100&include_entities=1&result_type=mixed',
#   'query': 'financial',
#   'refresh_url': '?since_id=1223337507846266881&q=financial&result_type=mixed&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}
