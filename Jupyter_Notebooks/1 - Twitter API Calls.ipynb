# %% [markdown]
# # Twitter API

# %% [markdown]
# ___

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#API-Documentation" data-toc-modified-id="API-Documentation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>API Documentation</a></span><ul class="toc-item"><li><span><a href="#Twitter-GET-Endpoints" data-toc-modified-id="Twitter-GET-Endpoints-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Twitter GET Endpoints</a></span></li><li><span><a href="#Twitter-Labs-GET-Endpoints" data-toc-modified-id="Twitter-Labs-GET-Endpoints-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Twitter Labs GET Endpoints</a></span></li><li><span><a href="#Workflow" data-toc-modified-id="Workflow-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Workflow</a></span></li><li><span><a href="#Business-Scenario" data-toc-modified-id="Business-Scenario-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Business Scenario</a></span></li></ul></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Call-Tweets-From-Twitter-API" data-toc-modified-id="Call-Tweets-From-Twitter-API-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Call Tweets From Twitter API</a></span><ul class="toc-item"><li><span><a href="#Define-10-keywords-related-to-financial-tech-that-we-will-use-to-query-for-tweets" data-toc-modified-id="Define-10-keywords-related-to-financial-tech-that-we-will-use-to-query-for-tweets-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Define 10 keywords related to financial tech that we will use to query for tweets</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;investing&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;investing&quot;-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Query for tweets using "investing"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;mobile-payment&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;mobile-payment&quot;-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Query for tweets using "mobile payment"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;mobile-wallet&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;mobile-wallet&quot;-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Query for tweets using "mobile wallet"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;mobile-banking&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;mobile-banking&quot;-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Query for tweets using "mobile banking"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;trading&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;trading&quot;-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Query for tweets using "trading"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;fintech&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;fintech&quot;-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Query for tweets using "fintech"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;financial&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;financial&quot;-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Query for tweets using "financial"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;money-management&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;money-management&quot;-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Query for tweets using "money management"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;stocks&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;stocks&quot;-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Query for tweets using "stocks"</a></span></li><li><span><a href="#Query-for-tweets-using-&quot;transaction&quot;" data-toc-modified-id="Query-for-tweets-using-&quot;transaction&quot;-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Query for tweets using "transaction"</a></span></li></ul></li><li><span><a href="#Call-To-&quot;labs/1/tweets&quot;-Endpoint-For-Tweet-&quot;Deets&quot;" data-toc-modified-id="Call-To-&quot;labs/1/tweets&quot;-Endpoint-For-Tweet-&quot;Deets&quot;-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Call To "labs/1/tweets" Endpoint For Tweet "Deets"</a></span><ul class="toc-item"><li><span><a href="#Get-Tweet-ids" data-toc-modified-id="Get-Tweet-ids-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Get Tweet ids</a></span></li><li><span><a href="#Query-deets-for-&quot;investing&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;investing&quot;-tweets-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Query deets for "investing" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;mobile-payment&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;mobile-payment&quot;-tweets-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Query deets for "mobile payment" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;mobile-wallet&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;mobile-wallet&quot;-tweets-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Query deets for "mobile wallet" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;mobile-banking&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;mobile-banking&quot;-tweets-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Query deets for "mobile banking" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;trading&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;trading&quot;-tweets-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Query deets for "trading" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;fintech&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;fintech&quot;-tweets-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Query deets for "fintech" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;financial&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;financial&quot;-tweets-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Query deets for "financial" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;money-management&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;money-management&quot;-tweets-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Query deets for "money management" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;stocks&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;stocks&quot;-tweets-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Query deets for "stocks" tweets</a></span></li><li><span><a href="#Query-deets-for-&quot;transaction&quot;-tweets" data-toc-modified-id="Query-deets-for-&quot;transaction&quot;-tweets-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Query deets for "transaction" tweets</a></span></li></ul></li><li><span><a href="#Call-To-&quot;labs/1/users&quot;-Endpoint-For-Tweet-&quot;Users&quot;" data-toc-modified-id="Call-To-&quot;labs/1/users&quot;-Endpoint-For-Tweet-&quot;Users&quot;-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Call To "labs/1/users" Endpoint For Tweet "Users"</a></span><ul class="toc-item"><li><span><a href="#Get-User-ids" data-toc-modified-id="Get-User-ids-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Get User ids</a></span></li><li><span><a href="#Query-users-for-&quot;investing&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;investing&quot;-tweets-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Query users for "investing" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;mobile-payment&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;mobile-payment&quot;-tweets-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Query users for "mobile payment" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;mobile-wallet&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;mobile-wallet&quot;-tweets-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Query users for "mobile wallet" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;mobile-banking&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;mobile-banking&quot;-tweets-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Query users for "mobile banking" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;trading&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;trading&quot;-tweets-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Query users for "trading" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;fintech&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;fintech&quot;-tweets-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Query users for "fintech" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;financial&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;financial&quot;-tweets-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Query users for "financial" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;money-management&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;money-management&quot;-tweets-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Query users for "money management" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;stocks&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;stocks&quot;-tweets-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Query users for "stocks" tweets</a></span></li><li><span><a href="#Query-users-for-&quot;transaction&quot;-tweets" data-toc-modified-id="Query-users-for-&quot;transaction&quot;-tweets-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Query users for "transaction" tweets</a></span></li></ul></li></ul></div>

# %% [markdown]
# ___

# %% [markdown]
# ## API Documentation

# %% [markdown]
# **Rules:**
# - Request window is 15 minute.
# - Requests per 15 minutes is as little as 15 requests, and as much as 900 requests.
# - See Twitter rate limit documentation here: https://developer.twitter.com/en/docs/basics/rate-limiting
# - See Twitter Basic API endpoint documentation here: https://developer.twitter.com/en/docs/basics/rate-limits
# - See complete Twitter API Reference Index here: https://developer.twitter.com/en/docs/api-reference-index

# %% [markdown]
# ### Twitter GET Endpoints

# %% [markdown]
# - **/1.1/search/tweets.json**
#     - Returns a collection of relevant Tweets matching a specified query. The Twitter Search API searches against a sampling of recent Tweets published in the past 7 days. It’s important to know that the standard search API is focused on relevance and not completeness.
#         - id (of the tweet)
#         - id (of the user)
#         - name (of the user)
#         - id (user_mentions)
#         - name (user_mentions)
#         - text (of the tweet)
#         - location
#         - entities
#         - followers_count (user)
#         - friends_count (user)
#         - listed_count
#         - favourites_count
#         - statuses_count
#         - retweet_count (of the tweet)
#         - favorite_count

# %% [markdown]
# ### Twitter Labs GET Endpoints

# %% [markdown]
# - **/labs/1/users**
#     - Returns a variety of information about one or more Users specified by the requested IDs or usernames.
#         - description
#         - id
#         - location
#         - name
#         - username
#         - stats
#             - followers_count
#             - following_count
#             - tweet_count
#             - listed_count
#
#
# - **/labs/1/tweets**
#     - Returns a variety of information about the Tweet specified by the requested ID or list of IDs.
#         - attachments (to the tweet)
#         - stats (for the tweet)
#             - retweet_count
#             - reply_count
#             - like_count
#             - quote_count
#         - text (tweet content)
#
#
# - **/labs/1/tweets/search**
#     - Returns Tweets from the last 7 days that match a search query (max 100 results per call).
#         - all keys from /search/tweets.json
#         - next_token (to paginate)

# %% [markdown]
# ### Workflow

# %% [markdown]
# - **Step 1.** Use **/1.1/search/tweets.json** endpoint to get tweets from the past 7 days for a particular query.
# - **Step 2.** Use **/labs/1/tweets** to get detailed tweet metrics using the tweet ID extracted from Step 1.
# - **Step 3.** Use **/labs/1/users** to get detailed info about the users for the tweets in our query from Step 1.
# - **Step 4.** Merge all data into one DataFrame and export to .CSV.

# %% [markdown]
# ### Business Scenario

# %% [markdown]
# - **A startup financial tech company just deployed a new mobile app and wants to get the word out globally. They want to maximize retweets of their "launch" tweet about their new app. They want to know how to make a tweet cross a high threshold of retweets.**
#
#
# - **Pulling Financial Tweets Strategy: (7 day history of tweets using Basic Twitter Developer Account)**
#     - Search tweets by query criteria:
#         - The word "investing"
#         - The word "mobile payment"
#         - The word "mobile wallet"
#         - The word "mobile banking"
#         - The word "trading"
#         - The word "fintech"
#         - The word "financial"
#         - The word "money management"
#         - The word "stocks"
#         - The word "transaction"

# %% [markdown]
# ___

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append("..")

# %%
# Import necessary python packages and functions
from Py_Files.imports import *
from Py_Files.max_range import *
# %matplotlib inline

# %%
client_key = 'YOUR_CLIENT_KEY'
client_secret = 'YOUR_CLIENT_SECRET_KEY'

import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)

# %%
auth_resp.status_code
# Out:
# 200

# %%
auth_resp.json().keys()
# Out:
# dict_keys(['token_type', 'access_token'])

# %%
auth_resp.json()

#{'token_type': 'bearer',
# 'access_token': 'YOUR_ACCESS_TOKEN'}

# %% [markdown]
# ## Call Tweets From Twitter API

# %% [markdown]
# ### Define 10 keywords related to financial tech that we will use to query for tweets

# %% [markdown]
# - "investing"
# - "mobile payment"
# - "mobile wallet"
# - "mobile banking"
# - "trading"
# - "fintech"
# - "financial"
# - "money management"
# - "stocks"
# - "transaction"

# %% [markdown]
# ### Query for tweets using "investing"

# %%
tweets_search = []

# %%
#ran 50 times to get 5,000 results for "investing" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'investing',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1223011430862974975
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search.append(search.json())

# %%
tweets_search[49]['search_metadata']['next_results']
# Out:
# '?max_id=1223010459932135429&q=investing&lang=en&count=100&include_entities=1&result_type=mixed'

# %% [markdown]
# ___

# %%
numbers_1 = list(range(0,50))
numbers_2 = list(range(0,100))
followers = []

for x in numbers_1:
    for y in numbers_2:
        followers.append(tweets_search[x]['statuses'][y]['user']['followers_count'])

# %%
check = []

# %%
def check_followers(list_name):
    for number in list_name:
        if number < 1000:
            check.append(False)
        elif number > 10000:
            check.append(False)
        else:
            check.append(True)

# %%
check_followers(followers)

# %%
#how many results MEET our criteria for "followers"?
#we want this number to be at least 1000 to get a good dataset.

check.count(True)
# Out:
# 1893

# %%
#how many results DO NOT MEET our criteria for "followers"?
check.count(False)
# Out:
# 3107

# %%
#how many total results?
len(followers)
# Out:
# 5000

# %%
#how many people have a distinct number of followers?
len(set(followers))
# Out:
# 2330

# %%
# number of duplicate occurances of follower counts - format is [num_followers, occurances]
[[x,followers.count(x)] for x in set(followers)]
# Out:
# [[0, 23],
#  [1, 11],
#  [2, 12],
#  [3, 15],
#  [4, 18],
#  [5, 16],
#  [6, 19],
#  [7, 13],
#  [8, 12],
#  [9, 14],
#  [10, 7],
#  [11, 9],
#  [12, 17],
#  [13, 17],
#  [14, 7],
#  [15, 9],
#  [16, 7],
#  [17, 19],
#  [18, 20],
#  [19, 12],
#  [20, 13],
#  [21, 9],
#  [22, 5],
#  [23, 12],
#  [24, 9],
#  [25, 11],
#  [26, 8],
#  [27, 13],
#  [28, 4],
#  [29, 13],
#  [30, 6],
#  [31, 11],
#  [32, 7],
#  [33, 8],
#  [34, 9],
#  [35, 7],
#  [36, 9],
#  [37, 11],
#  [8230, 2],
#  [39, 7],
#  [38, 8],
#  [41, 12],
#  [42, 6],
#  [43, 9],
#  [40, 7],
#  [45, 6],
#  [46, 10],
#  [47, 6],
#  [48, 10],
#  [44, 11],
#  [50, 5],
#  [51, 9],
#  [52, 5],
#  [53, 6],
#  [54, 8],
#  [55, 11],
#  [56, 7],
#  [57, 10],
#  [58, 9],
#  [59, 7],
#  [60, 6],
#  [61, 7],
#  [62, 11],
#  [63, 8],
#  [64, 11],
#  [65, 9],
#  [66, 7],
#  [67, 9],
#  [68, 8],
#  [69, 7],
#  [70, 7],
#  [71, 11],
#  [72, 5],
#  [73, 2],
#  [74, 8],
#  [75, 4],
#  [76, 8],
#  [77, 9],
#  [78, 6],
#  [79, 8],
#  [80, 7],
# ...

# %%
tweets_search_investing = tweets_search

# %% [markdown]
# **Save out JSON for safe keeping**

# %%
# with open('investing.json', 'w', encoding='utf-8') as f:
#     json.dump(tweets_search_investing, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "mobile payment"

# %% [markdown]
# - Need to get tweets_search_mobile_payment[x]['search_metadata']['next_results']
# - Assign variable to this value ^ and put as an integer for the "max_id" parameter
# - Have this variable update with each call.
# - Append each result to the list tweets_search_mobile_payment

# %%
def find_between(s, first, last):
    try:
        start = s.index(first) + len(first)
        end = s.index(last, start)
        return s[start:end]
    except ValueError:
        return ""

find_between(s, "?max_id=", "&")
# Out:
# '1223079825566359551'

# %%
# calls = list(range(0,50))
# for x in calls:
#     for result in tweets_search_mobile_payment[x]['search_metadata']['next_results']:
#         max_id = find_between(result, "?max_id=", "&")

# %%
tweets_search_mobile_payment = []

# %%
#ran 13 times - this was the maximum number of paginations for "mobile payment" as query

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'mobile payment',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1220920693317083135
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_mobile_payment.append(search.json())

# %%
tweets_search_mobile_payment[12]['search_metadata']['next_results']
# Out:
# '?max_id=1220920693317083135&q=mobile%20payment&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
tweets_search_mobile_payment[12]
# Out:
# {'statuses': [{'created_at': 'Sat Jan 25 14:54:01 +0000 2020',
#    'id': 1221083810017792000,
#    'id_str': '1221083810017792000',
#    'text': 'Singapore dominates mobile payment market for Chinese tourists - via @SBRMagazine https://t.co/jiIbnd6CX1',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SBRMagazine',
#       'name': 'SBR Magazine',
#       'id': 106670875,
#       'id_str': '106670875',
#       'indices': [69, 81]}],
#     'urls': [{'url': 'https://t.co/jiIbnd6CX1',
#       'expanded_url': 'https://aciw.co/2RSe2F3',
#       'display_url': 'aciw.co/2RSe2F3',
#       'indices': [82, 105]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.oktopost.com" rel="nofollow">Oktopost</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
# ...

# %%
with open('mobile_payment.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_mobile_payment, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "mobile wallet"

# %%
tweets_search_mobile_wallet = []

# %%
#ran 22 times - this was the maximum number of paginations for "mobile wallet" as query

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'mobile wallet',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1220919826849259520
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_mobile_wallet.append(search.json())

# %%
tweets_search_mobile_wallet[21]['search_metadata']['next_results']
# Out:
# '?max_id=1220919826849259520&q=mobile%20wallet&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('mobile_wallet.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_mobile_wallet, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "mobile banking"

# %%
tweets_search_mobile_banking = []

# %%
#ran 13 times - this was the maximum number of paginations for "mobile banking" as query

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'mobile banking',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1220909983858073600
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_mobile_banking.append(search.json())

# %%
tweets_search_mobile_banking[12]['search_metadata']['next_results']
# Out:
# '?max_id=1220909983858073600&q=mobile%20banking&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('mobile_banking.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_mobile_banking, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "trading"

# %%
tweets_search_trading = []

# %%
#ran 50 times to get 5,000 results for "trading" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'trading',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1223272720336449535
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_trading.append(search.json())

# %%
tweets_search_trading[49]['search_metadata']['next_results']
# Out:
# '?max_id=1223272251484667910&q=trading&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('trading.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_trading, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "fintech"

# %%
tweets_search_fintech = []

# %%
#ran 50 times to get 5,000 results for "fintech" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'fintech',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1222990630760210431
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_fintech.append(search.json())

# %%
tweets_search_fintech[49]['search_metadata']['next_results']
# Out:
# '?max_id=1222986924228587525&q=fintech&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('fintech.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_fintech, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "financial"

# %%
tweets_search_financial = []

# %%
#ran 50 times to get 5,000 results for "financial" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'financial',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1223337914848944132
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_financial.append(search.json())

# %%
tweets_search_financial[49]['search_metadata']['next_results']
# Out:
# '?max_id=1223337618366238724&q=financial&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('financial.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_financial, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "money management"

# %%
tweets_search_money_management = []

# %%
#ran 50 times to get 5,000 results for "money management" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'money management',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1221657930031697919
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_money_management.append(search.json())

# %%
tweets_search_money_management[49]['search_metadata']['next_results']
# Out:
# '?max_id=1221565274190753791&q=money%20management&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('money_management.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_money_management, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "stocks"

# %%
tweets_search_stocks = []

# %%
#ran 50 times to get 5,000 results for "stocks" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'stocks',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1223218945567547391
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_stocks.append(search.json())

# %%
tweets_search_stocks[49]['search_metadata']['next_results']
# Out:
# '?max_id=1223217911399055359&q=stocks&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('stocks.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_stocks, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query for tweets using "transaction"

# %%
tweets_search_transaction = []

# %%
#ran 50 times to get 5,000 results for "transaction" as query...did not run out of paginations.

search_headers = {
    'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
}

search_params = {
    'q': 'transaction',
    'lang': 'en',
    'result_type': 'mixed',
    'count': 100,
    'include_entities': 'true',
    'max_id': 1223069702206869503
}

search_url = 'https://api.twitter.com/1.1/search/tweets.json'

search = requests.get(search_url, headers=search_headers, params=search_params)
tweets_search_transaction.append(search.json())

# %%
tweets_search_transaction[49]['search_metadata']['next_results']
# Out:
# '?max_id=1223066250810540031&q=transaction&lang=en&count=100&include_entities=1&result_type=mixed'

# %%
with open('transaction.json', 'w', encoding='utf-8') as f:
    json.dump(tweets_search_transaction, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ___

# %% [markdown]
# ## Call To "labs/1/tweets" Endpoint For Tweet "Deets"

# %% [markdown]
# ### Get Tweet ids

# %% [markdown]
# - 900 requests per 15-minute window
# - 100 ids per request
# - So we need to convert our lists of ids into sets of 100.
# - Then convert these sets of 100 into individual strings.
# - Each id needs to be separated with a comma with no spaces to feed into each call.

# %%
#accessing tweet ids
tweets_search_investing[0]['statuses'][0]['id']
# Out:
# 1223351165523578885

# %%
tweet_ids_investing = []
tweet_ids_mobile_payment = []
tweet_ids_mobile_wallet = []
tweet_ids_mobile_banking = []
tweet_ids_trading = []
tweet_ids_fintech = []
tweet_ids_financial = []
tweet_ids_money_management = []
tweet_ids_stocks = []
tweet_ids_transaction = []

for x in range(len(tweets_search_investing)):
    for y in range(len(tweets_search_investing[0]['statuses'])):
        try:
            tweet_ids_investing.append(tweets_search_investing[x]['statuses'][y]['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_payment)):
    for y in range(len(tweets_search_mobile_payment[0]['statuses'])):
        try:
            tweet_ids_mobile_payment.append(tweets_search_mobile_payment[x]['statuses'][y]['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_wallet)):
    for y in range(len(tweets_search_mobile_wallet[0]['statuses'])):
        try:        
            tweet_ids_mobile_wallet.append(tweets_search_mobile_wallet[x]['statuses'][y]['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_banking)):
    for y in range(len(tweets_search_mobile_banking[0]['statuses'])):
        try:
            tweet_ids_mobile_banking.append(tweets_search_mobile_banking[x]['statuses'][y]['id'])
        except:
            continue
            
for x in range(len(tweets_search_trading)):
    for y in range(len(tweets_search_trading[0]['statuses'])):
        try:        
            tweet_ids_trading.append(tweets_search_trading[x]['statuses'][y]['id'])
        except:
            continue
            
for x in range(len(tweets_search_fintech)):
    for y in range(len(tweets_search_fintech[0]['statuses'])):
        try:        
            tweet_ids_fintech.append(tweets_search_fintech[x]['statuses'][y]['id'])
        except:
            continue

for x in range(len(tweets_search_financial)):
    for y in range(len(tweets_search_financial[0]['statuses'])):
        try:   
            tweet_ids_financial.append(tweets_search_financial[x]['statuses'][y]['id'])
        except:
            continue

for x in range(len(tweets_search_money_management)):
    for y in range(len(tweets_search_money_management[0]['statuses'])):
        try:        
            tweet_ids_money_management.append(tweets_search_money_management[x]['statuses'][y]['id'])
        except:
            continue
        
for x in range(len(tweets_search_stocks)):
    for y in range(len(tweets_search_stocks[0]['statuses'])):
        try:        
            tweet_ids_stocks.append(tweets_search_stocks[x]['statuses'][y]['id'])
        except:
            continue
        
for x in range(len(tweets_search_transaction)):
    for y in range(len(tweets_search_transaction[0]['statuses'])):
        try:        
            tweet_ids_transaction.append(tweets_search_transaction[x]['statuses'][y]['id'])
        except:
            continue

# %%
def split_list(list_name, items_per_split):
    for x in range(0, len(list_name), items_per_split):
        yield list_name[x:x + items_per_split]

# %% [markdown]
# ### Query deets for "investing" tweets

# %%
ids_investing_split = list(split_list(tweet_ids_investing, 100))

# %%
#this should be 100
len(ids_investing_split[49])
# Out:
# 100

# %%
for x in list(range(0,50)):
    print("ids_investing_{} = str(ids_investing_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_investing_0 = str(ids_investing_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_1 = str(ids_investing_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_2 = str(ids_investing_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_3 = str(ids_investing_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_4 = str(ids_investing_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_5 = str(ids_investing_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_6 = str(ids_investing_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_7 = str(ids_investing_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_8 = str(ids_investing_split[8]).replace(', ',',').replace('[','').replace(']','')
# ids_investing_9 = str(ids_investing_split[9]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_investing_0 = str(ids_investing_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_investing_1 = str(ids_investing_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_investing_2 = str(ids_investing_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_investing_3 = str(ids_investing_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_investing_4 = str(ids_investing_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_investing_5 = str(ids_investing_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_investing_6 = str(ids_investing_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_investing_7 = str(ids_investing_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_investing_8 = str(ids_investing_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_investing_9 = str(ids_investing_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_investing_10 = str(ids_investing_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_investing_11 = str(ids_investing_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_investing_12 = str(ids_investing_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_investing_13 = str(ids_investing_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_investing_14 = str(ids_investing_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_investing_15 = str(ids_investing_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_investing_16 = str(ids_investing_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_investing_17 = str(ids_investing_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_investing_18 = str(ids_investing_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_investing_19 = str(ids_investing_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_investing_20 = str(ids_investing_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_investing_21 = str(ids_investing_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_investing_22 = str(ids_investing_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_investing_23 = str(ids_investing_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_investing_24 = str(ids_investing_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_investing_25 = str(ids_investing_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_investing_26 = str(ids_investing_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_investing_27 = str(ids_investing_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_investing_28 = str(ids_investing_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_investing_29 = str(ids_investing_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_investing_30 = str(ids_investing_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_investing_31 = str(ids_investing_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_investing_32 = str(ids_investing_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_investing_33 = str(ids_investing_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_investing_34 = str(ids_investing_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_investing_35 = str(ids_investing_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_investing_36 = str(ids_investing_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_investing_37 = str(ids_investing_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_investing_38 = str(ids_investing_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_investing_39 = str(ids_investing_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_investing_40 = str(ids_investing_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_investing_41 = str(ids_investing_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_investing_42 = str(ids_investing_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_investing_43 = str(ids_investing_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_investing_44 = str(ids_investing_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_investing_45 = str(ids_investing_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_investing_46 = str(ids_investing_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_investing_47 = str(ids_investing_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_investing_48 = str(ids_investing_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_investing_49 = str(ids_investing_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
#looks good - one long string of ids can be passed into the API call
ids_investing_1
# Out:
# '1223079825398587399,1223079807661027328,1223079795921022977,1223079793857564672,1223079789805785088,1223079767529811969,1223079734281527296,1223079732423675905,1223079726987841537,1223079698428833794,1223079689096331264,1223079679667535872,1223079679269199873,1223079677700583424,1223079656435474433,1223079645144240130,1223079628002099200,1223079617277227011,1223079567096573952,1223079561216364544,1223079559416946688,1223079513325821954,1223079507038547968,1223079497664286720,1223079490080976896,1223079471143706625,1223079467112747008,1223079466533978112,1223079466043432960,1223079449366712320,1223079439744897024,1223079427061493767,1223079409567109120,1223079385671991297,1223079347252273152,1223079329384620032,1223079308060700672,1223079305430884352,1223079301832216577,1223079288557228032,1223079271247286272,1223079261625438210,1223079251026567169,1223079208785592322,1223079193933570050,1223079153265709057,1223079089881350145,1223079082860019714,1223079033841209344,12230789705660252
# ...

# %%
for x in list(range(0,50)):
    print('ids_investing_{},'.format(x))
# Out:
# ids_investing_0,
# ids_investing_1,
# ids_investing_2,
# ids_investing_3,
# ids_investing_4,
# ids_investing_5,
# ids_investing_6,
# ids_investing_7,
# ids_investing_8,
# ids_investing_9,
# ids_investing_10,
# ids_investing_11,
# ids_investing_12,
# ids_investing_13,
# ids_investing_14,
# ids_investing_15,
# ids_investing_16,
# ids_investing_17,
# ids_investing_18,
# ids_investing_19,
# ids_investing_20,
# ids_investing_21,
# ids_investing_22,
# ids_investing_23,
# ids_investing_24,
# ids_investing_25,
# ids_investing_26,
# ids_investing_27,
# ids_investing_28,
# ids_investing_29,
# ids_investing_30,
# ids_investing_31,
# ids_investing_32,
# ids_investing_33,
# ids_investing_34,
# ids_investing_35,
# ids_investing_36,
# ids_investing_37,
# ids_investing_38,
# ids_investing_39,
# ids_investing_40,
# ids_investing_41,
# ids_investing_42,
# ids_investing_43,
# ids_investing_44,
# ids_investing_45,
# ids_investing_46,
# ids_investing_47,
# ids_investing_48,
# ids_investing_49,

# %%
ids_investing_list = [
    
ids_investing_0,
ids_investing_1,
ids_investing_2,
ids_investing_3,
ids_investing_4,
ids_investing_5,
ids_investing_6,
ids_investing_7,
ids_investing_8,
ids_investing_9,
ids_investing_10,
ids_investing_11,
ids_investing_12,
ids_investing_13,
ids_investing_14,
ids_investing_15,
ids_investing_16,
ids_investing_17,
ids_investing_18,
ids_investing_19,
ids_investing_20,
ids_investing_21,
ids_investing_22,
ids_investing_23,
ids_investing_24,
ids_investing_25,
ids_investing_26,
ids_investing_27,
ids_investing_28,
ids_investing_29,
ids_investing_30,
ids_investing_31,
ids_investing_32,
ids_investing_33,
ids_investing_34,
ids_investing_35,
ids_investing_36,
ids_investing_37,
ids_investing_38,
ids_investing_39,
ids_investing_40,
ids_investing_41,
ids_investing_42,
ids_investing_43,
ids_investing_44,
ids_investing_45,
ids_investing_46,
ids_investing_47,
ids_investing_48,
ids_investing_49,
    
]

# %%
deets_investing = []

# %%
for x in ids_investing_list:
    
    search_headers = {
        'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
    }

    search_params = {
        'ids': x,
        'format': 'detailed',
        'tweet.format': 'detailed',
        'user.format': 'detailed',
        'place.format': 'detailed'
    }

    search_url = 'https://api.twitter.com/labs/1/tweets'

    search = requests.get(search_url, headers=search_headers, params=search_params)
    deets_investing.append(search.json())

# %% [markdown]
# **Looks like there are 4 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,50)):
    try:
        print(deets_investing[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223712316484657152].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223712316484657152', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223059538833739776].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223059538833739776', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223030644227428352].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223030644227428352', 'resource_type': 'tweet'}]
# ...

# %%
with open('deets_investing.json', 'w', encoding='utf-8') as f:
    json.dump(deets_investing, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "mobile payment" tweets

# %%
ids_mobile_payment_split = list(split_list(tweet_ids_mobile_payment, 100))

# %%
for x in list(range(0,len(ids_mobile_payment_split))):
    print("ids_mobile_payment_{} = str(ids_mobile_payment_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_mobile_payment_0 = str(ids_mobile_payment_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_1 = str(ids_mobile_payment_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_2 = str(ids_mobile_payment_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_3 = str(ids_mobile_payment_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_4 = str(ids_mobile_payment_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_5 = str(ids_mobile_payment_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_6 = str(ids_mobile_payment_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_7 = str(ids_mobile_payment_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_payment_8 = str(ids_mobile_payment_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_mobile_payment_0 = str(ids_mobile_payment_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_1 = str(ids_mobile_payment_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_2 = str(ids_mobile_payment_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_3 = str(ids_mobile_payment_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_4 = str(ids_mobile_payment_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_5 = str(ids_mobile_payment_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_6 = str(ids_mobile_payment_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_7 = str(ids_mobile_payment_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_8 = str(ids_mobile_payment_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_9 = str(ids_mobile_payment_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_10 = str(ids_mobile_payment_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_11 = str(ids_mobile_payment_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_payment_12 = str(ids_mobile_payment_split[12]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_mobile_payment_split))):
    print('ids_mobile_payment_{},'.format(x))
# Out:
# ids_mobile_payment_0,
# ids_mobile_payment_1,
# ids_mobile_payment_2,
# ids_mobile_payment_3,
# ids_mobile_payment_4,
# ids_mobile_payment_5,
# ids_mobile_payment_6,
# ids_mobile_payment_7,
# ids_mobile_payment_8,
# ids_mobile_payment_9,
# ids_mobile_payment_10,
# ids_mobile_payment_11,
# ids_mobile_payment_12,

# %%
ids_mobile_payment_list = [
    
ids_mobile_payment_0,
ids_mobile_payment_1,
ids_mobile_payment_2,
ids_mobile_payment_3,
ids_mobile_payment_4,
ids_mobile_payment_5,
ids_mobile_payment_6,
ids_mobile_payment_7,
ids_mobile_payment_8,
ids_mobile_payment_9,
ids_mobile_payment_10,
ids_mobile_payment_11,
ids_mobile_payment_12
    
]

# %%
deets_mobile_payment = []

# %%
for x in ids_mobile_payment_list:
    
    search_headers = {
        'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
    }

    search_params = {
        'ids': x,
        'format': 'detailed',
        'tweet.format': 'detailed',
        'user.format': 'detailed',
        'place.format': 'detailed'
    }

    search_url = 'https://api.twitter.com/labs/1/tweets'

    search = requests.get(search_url, headers=search_headers, params=search_params)
    deets_mobile_payment.append(search.json())

# %% [markdown]
# **Looks like there are 0 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_mobile_payment_list))):
    try:
        print(deets_mobile_payment[x]['errors'])
    except:
        pass

# %%
with open('deets_mobile_payment.json', 'w', encoding='utf-8') as f:
    json.dump(deets_mobile_payment, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "mobile wallet" tweets

# %%
ids_mobile_wallet_split = list(split_list(tweet_ids_mobile_wallet, 100))

# %%
for x in list(range(0,len(ids_mobile_wallet_split))):
    print("ids_mobile_wallet_{} = str(ids_mobile_wallet_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_mobile_wallet_0 = str(ids_mobile_wallet_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_1 = str(ids_mobile_wallet_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_2 = str(ids_mobile_wallet_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_3 = str(ids_mobile_wallet_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_4 = str(ids_mobile_wallet_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_5 = str(ids_mobile_wallet_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_6 = str(ids_mobile_wallet_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_7 = str(ids_mobile_wallet_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_wallet_8 = str(ids_mobile_wallet_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_mobile_wallet_0 = str(ids_mobile_wallet_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_1 = str(ids_mobile_wallet_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_2 = str(ids_mobile_wallet_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_3 = str(ids_mobile_wallet_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_4 = str(ids_mobile_wallet_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_5 = str(ids_mobile_wallet_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_6 = str(ids_mobile_wallet_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_7 = str(ids_mobile_wallet_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_8 = str(ids_mobile_wallet_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_9 = str(ids_mobile_wallet_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_10 = str(ids_mobile_wallet_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_11 = str(ids_mobile_wallet_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_12 = str(ids_mobile_wallet_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_13 = str(ids_mobile_wallet_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_14 = str(ids_mobile_wallet_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_15 = str(ids_mobile_wallet_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_16 = str(ids_mobile_wallet_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_17 = str(ids_mobile_wallet_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_18 = str(ids_mobile_wallet_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_19 = str(ids_mobile_wallet_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_wallet_20 = str(ids_mobile_wallet_split[20]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_mobile_wallet_split))):
    print('ids_mobile_wallet_{},'.format(x))
# Out:
# ids_mobile_wallet_0,
# ids_mobile_wallet_1,
# ids_mobile_wallet_2,
# ids_mobile_wallet_3,
# ids_mobile_wallet_4,
# ids_mobile_wallet_5,
# ids_mobile_wallet_6,
# ids_mobile_wallet_7,
# ids_mobile_wallet_8,
# ids_mobile_wallet_9,
# ids_mobile_wallet_10,
# ids_mobile_wallet_11,
# ids_mobile_wallet_12,
# ids_mobile_wallet_13,
# ids_mobile_wallet_14,
# ids_mobile_wallet_15,
# ids_mobile_wallet_16,
# ids_mobile_wallet_17,
# ids_mobile_wallet_18,
# ids_mobile_wallet_19,
# ids_mobile_wallet_20,

# %%
ids_mobile_wallet_list = [
    
ids_mobile_wallet_0,
ids_mobile_wallet_1,
ids_mobile_wallet_2,
ids_mobile_wallet_3,
ids_mobile_wallet_4,
ids_mobile_wallet_5,
ids_mobile_wallet_6,
ids_mobile_wallet_7,
ids_mobile_wallet_8,
ids_mobile_wallet_9,
ids_mobile_wallet_10,
ids_mobile_wallet_11,
ids_mobile_wallet_12,
ids_mobile_wallet_13,
ids_mobile_wallet_14,
ids_mobile_wallet_15,
ids_mobile_wallet_16,
ids_mobile_wallet_17,
ids_mobile_wallet_18,
ids_mobile_wallet_19,
ids_mobile_wallet_20
    
]

# %%
deets_mobile_wallet = []

# %%
for x in ids_mobile_wallet_list:
    
    search_headers = {
        'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
    }

    search_params = {
        'ids': x,
        'format': 'detailed',
        'tweet.format': 'detailed',
        'user.format': 'detailed',
        'place.format': 'detailed'
    }

    search_url = 'https://api.twitter.com/labs/1/tweets'

    search = requests.get(search_url, headers=search_headers, params=search_params)
    deets_mobile_wallet.append(search.json())

# %% [markdown]
# **Looks like there are 3 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_mobile_wallet_list))):
    try:
        print(deets_mobile_wallet[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223625536511057922].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223625536511057922', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223726725894492160].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223726725894492160', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223254389869228032].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223254389869228032', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1222371156168257536].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1222371156168257536', 'resource_type': 'tweet'}]

# %%
with open('deets_mobile_wallet.json', 'w', encoding='utf-8') as f:
    json.dump(deets_mobile_wallet, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "mobile banking" tweets

# %%
ids_mobile_banking_split = list(split_list(tweet_ids_mobile_banking, 100))

# %%
for x in list(range(0,len(ids_mobile_banking_split))):
    print("ids_mobile_banking_{} = str(ids_mobile_banking_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_mobile_banking_0 = str(ids_mobile_banking_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_1 = str(ids_mobile_banking_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_2 = str(ids_mobile_banking_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_3 = str(ids_mobile_banking_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_4 = str(ids_mobile_banking_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_5 = str(ids_mobile_banking_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_6 = str(ids_mobile_banking_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_7 = str(ids_mobile_banking_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_mobile_banking_8 = str(ids_mobile_banking_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_mobile_banking_0 = str(ids_mobile_banking_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_1 = str(ids_mobile_banking_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_2 = str(ids_mobile_banking_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_3 = str(ids_mobile_banking_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_4 = str(ids_mobile_banking_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_5 = str(ids_mobile_banking_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_6 = str(ids_mobile_banking_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_7 = str(ids_mobile_banking_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_8 = str(ids_mobile_banking_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_9 = str(ids_mobile_banking_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_10 = str(ids_mobile_banking_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_11 = str(ids_mobile_banking_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_mobile_banking_12 = str(ids_mobile_banking_split[12]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_mobile_banking_split))):
    print('ids_mobile_banking_{},'.format(x))
# Out:
# ids_mobile_banking_0,
# ids_mobile_banking_1,
# ids_mobile_banking_2,
# ids_mobile_banking_3,
# ids_mobile_banking_4,
# ids_mobile_banking_5,
# ids_mobile_banking_6,
# ids_mobile_banking_7,
# ids_mobile_banking_8,
# ids_mobile_banking_9,
# ids_mobile_banking_10,
# ids_mobile_banking_11,
# ids_mobile_banking_12,

# %%
ids_mobile_banking_list = [
    
ids_mobile_banking_0,
ids_mobile_banking_1,
ids_mobile_banking_2,
ids_mobile_banking_3,
ids_mobile_banking_4,
ids_mobile_banking_5,
ids_mobile_banking_6,
ids_mobile_banking_7,
ids_mobile_banking_8,
ids_mobile_banking_9,
ids_mobile_banking_10,
ids_mobile_banking_11,
ids_mobile_banking_12
    
]

# %%
deets_mobile_banking = []

# %%
for x in ids_mobile_banking_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_mobile_banking.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 3 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_mobile_banking_list))):
    try:
        print(deets_mobile_banking[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223682438146117632].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223682438146117632', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1221217706571005953].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1221217706571005953', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1221179325782716417].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1221179325782716417', 'resource_type': 'tweet'}]

# %%
with open('deets_mobile_banking.json', 'w', encoding='utf-8') as f:
    json.dump(deets_mobile_banking, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "trading" tweets

# %%
ids_trading_split = list(split_list(tweet_ids_trading, 100))

# %%
for x in list(range(0,len(ids_trading_split))):
    print("ids_trading_{} = str(ids_trading_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_trading_0 = str(ids_trading_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_1 = str(ids_trading_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_2 = str(ids_trading_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_3 = str(ids_trading_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_4 = str(ids_trading_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_5 = str(ids_trading_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_6 = str(ids_trading_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_7 = str(ids_trading_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_8 = str(ids_trading_split[8]).replace(', ',',').replace('[','').replace(']','')
# ids_trading_9 = str(ids_trading_split[9]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_trading_0 = str(ids_trading_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_trading_1 = str(ids_trading_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_trading_2 = str(ids_trading_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_trading_3 = str(ids_trading_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_trading_4 = str(ids_trading_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_trading_5 = str(ids_trading_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_trading_6 = str(ids_trading_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_trading_7 = str(ids_trading_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_trading_8 = str(ids_trading_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_trading_9 = str(ids_trading_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_trading_10 = str(ids_trading_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_trading_11 = str(ids_trading_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_trading_12 = str(ids_trading_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_trading_13 = str(ids_trading_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_trading_14 = str(ids_trading_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_trading_15 = str(ids_trading_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_trading_16 = str(ids_trading_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_trading_17 = str(ids_trading_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_trading_18 = str(ids_trading_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_trading_19 = str(ids_trading_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_trading_20 = str(ids_trading_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_trading_21 = str(ids_trading_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_trading_22 = str(ids_trading_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_trading_23 = str(ids_trading_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_trading_24 = str(ids_trading_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_trading_25 = str(ids_trading_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_trading_26 = str(ids_trading_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_trading_27 = str(ids_trading_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_trading_28 = str(ids_trading_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_trading_29 = str(ids_trading_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_trading_30 = str(ids_trading_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_trading_31 = str(ids_trading_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_trading_32 = str(ids_trading_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_trading_33 = str(ids_trading_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_trading_34 = str(ids_trading_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_trading_35 = str(ids_trading_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_trading_36 = str(ids_trading_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_trading_37 = str(ids_trading_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_trading_38 = str(ids_trading_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_trading_39 = str(ids_trading_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_trading_40 = str(ids_trading_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_trading_41 = str(ids_trading_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_trading_42 = str(ids_trading_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_trading_43 = str(ids_trading_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_trading_44 = str(ids_trading_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_trading_45 = str(ids_trading_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_trading_46 = str(ids_trading_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_trading_47 = str(ids_trading_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_trading_48 = str(ids_trading_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_trading_49 = str(ids_trading_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_trading_split))):
    print('ids_trading_{},'.format(x))
# Out:
# ids_trading_0,
# ids_trading_1,
# ids_trading_2,
# ids_trading_3,
# ids_trading_4,
# ids_trading_5,
# ids_trading_6,
# ids_trading_7,
# ids_trading_8,
# ids_trading_9,
# ids_trading_10,
# ids_trading_11,
# ids_trading_12,
# ids_trading_13,
# ids_trading_14,
# ids_trading_15,
# ids_trading_16,
# ids_trading_17,
# ids_trading_18,
# ids_trading_19,
# ids_trading_20,
# ids_trading_21,
# ids_trading_22,
# ids_trading_23,
# ids_trading_24,
# ids_trading_25,
# ids_trading_26,
# ids_trading_27,
# ids_trading_28,
# ids_trading_29,
# ids_trading_30,
# ids_trading_31,
# ids_trading_32,
# ids_trading_33,
# ids_trading_34,
# ids_trading_35,
# ids_trading_36,
# ids_trading_37,
# ids_trading_38,
# ids_trading_39,
# ids_trading_40,
# ids_trading_41,
# ids_trading_42,
# ids_trading_43,
# ids_trading_44,
# ids_trading_45,
# ids_trading_46,
# ids_trading_47,
# ids_trading_48,
# ids_trading_49,

# %%
ids_trading_list = [
    
ids_trading_0,
ids_trading_1,
ids_trading_2,
ids_trading_3,
ids_trading_4,
ids_trading_5,
ids_trading_6,
ids_trading_7,
ids_trading_8,
ids_trading_9,
ids_trading_10,
ids_trading_11,
ids_trading_12,
ids_trading_13,
ids_trading_14,
ids_trading_15,
ids_trading_16,
ids_trading_17,
ids_trading_18,
ids_trading_19,
ids_trading_20,
ids_trading_21,
ids_trading_22,
ids_trading_23,
ids_trading_24,
ids_trading_25,
ids_trading_26,
ids_trading_27,
ids_trading_28,
ids_trading_29,
ids_trading_30,
ids_trading_31,
ids_trading_32,
ids_trading_33,
ids_trading_34,
ids_trading_35,
ids_trading_36,
ids_trading_37,
ids_trading_38,
ids_trading_39,
ids_trading_40,
ids_trading_41,
ids_trading_42,
ids_trading_43,
ids_trading_44,
ids_trading_45,
ids_trading_46,
ids_trading_47,
ids_trading_48,
ids_trading_49
    
]

# %%
deets_trading = []

# %%
for x in ids_trading_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_trading.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 25 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_trading_list))):
    try:
        print(deets_trading[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223744840162250754].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223744840162250754', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223745489599967232].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223745489599967232', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223745192525729792].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223745192525729792', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223745451314294784].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223745451314294784', 'resource_type': 'tweet'}, {'detail': 'Could
# ...

# %%
with open('deets_trading.json', 'w', encoding='utf-8') as f:
    json.dump(deets_trading, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "fintech" tweets

# %%
ids_fintech_split = list(split_list(tweet_ids_fintech, 100))

# %%
for x in list(range(0,len(ids_fintech_split))):
    print("ids_fintech_{} = str(ids_fintech_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_fintech_0 = str(ids_fintech_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_1 = str(ids_fintech_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_2 = str(ids_fintech_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_3 = str(ids_fintech_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_4 = str(ids_fintech_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_5 = str(ids_fintech_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_6 = str(ids_fintech_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_7 = str(ids_fintech_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_8 = str(ids_fintech_split[8]).replace(', ',',').replace('[','').replace(']','')
# ids_fintech_9 = str(ids_fintech_split[9]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_fintech_0 = str(ids_fintech_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_1 = str(ids_fintech_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_2 = str(ids_fintech_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_3 = str(ids_fintech_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_4 = str(ids_fintech_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_5 = str(ids_fintech_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_6 = str(ids_fintech_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_7 = str(ids_fintech_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_8 = str(ids_fintech_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_9 = str(ids_fintech_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_10 = str(ids_fintech_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_11 = str(ids_fintech_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_12 = str(ids_fintech_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_13 = str(ids_fintech_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_14 = str(ids_fintech_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_15 = str(ids_fintech_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_16 = str(ids_fintech_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_17 = str(ids_fintech_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_18 = str(ids_fintech_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_19 = str(ids_fintech_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_20 = str(ids_fintech_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_21 = str(ids_fintech_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_22 = str(ids_fintech_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_23 = str(ids_fintech_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_24 = str(ids_fintech_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_25 = str(ids_fintech_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_26 = str(ids_fintech_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_27 = str(ids_fintech_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_28 = str(ids_fintech_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_29 = str(ids_fintech_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_30 = str(ids_fintech_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_31 = str(ids_fintech_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_32 = str(ids_fintech_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_33 = str(ids_fintech_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_34 = str(ids_fintech_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_35 = str(ids_fintech_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_36 = str(ids_fintech_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_37 = str(ids_fintech_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_38 = str(ids_fintech_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_39 = str(ids_fintech_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_40 = str(ids_fintech_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_41 = str(ids_fintech_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_42 = str(ids_fintech_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_43 = str(ids_fintech_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_44 = str(ids_fintech_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_45 = str(ids_fintech_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_46 = str(ids_fintech_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_47 = str(ids_fintech_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_48 = str(ids_fintech_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_fintech_49 = str(ids_fintech_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_fintech_split))):
    print('ids_fintech_{},'.format(x))
# Out:
# ids_fintech_0,
# ids_fintech_1,
# ids_fintech_2,
# ids_fintech_3,
# ids_fintech_4,
# ids_fintech_5,
# ids_fintech_6,
# ids_fintech_7,
# ids_fintech_8,
# ids_fintech_9,
# ids_fintech_10,
# ids_fintech_11,
# ids_fintech_12,
# ids_fintech_13,
# ids_fintech_14,
# ids_fintech_15,
# ids_fintech_16,
# ids_fintech_17,
# ids_fintech_18,
# ids_fintech_19,
# ids_fintech_20,
# ids_fintech_21,
# ids_fintech_22,
# ids_fintech_23,
# ids_fintech_24,
# ids_fintech_25,
# ids_fintech_26,
# ids_fintech_27,
# ids_fintech_28,
# ids_fintech_29,
# ids_fintech_30,
# ids_fintech_31,
# ids_fintech_32,
# ids_fintech_33,
# ids_fintech_34,
# ids_fintech_35,
# ids_fintech_36,
# ids_fintech_37,
# ids_fintech_38,
# ids_fintech_39,
# ids_fintech_40,
# ids_fintech_41,
# ids_fintech_42,
# ids_fintech_43,
# ids_fintech_44,
# ids_fintech_45,
# ids_fintech_46,
# ids_fintech_47,
# ids_fintech_48,
# ids_fintech_49,

# %%
ids_fintech_list = [
    
ids_fintech_0,
ids_fintech_1,
ids_fintech_2,
ids_fintech_3,
ids_fintech_4,
ids_fintech_5,
ids_fintech_6,
ids_fintech_7,
ids_fintech_8,
ids_fintech_9,
ids_fintech_10,
ids_fintech_11,
ids_fintech_12,
ids_fintech_13,
ids_fintech_14,
ids_fintech_15,
ids_fintech_16,
ids_fintech_17,
ids_fintech_18,
ids_fintech_19,
ids_fintech_20,
ids_fintech_21,
ids_fintech_22,
ids_fintech_23,
ids_fintech_24,
ids_fintech_25,
ids_fintech_26,
ids_fintech_27,
ids_fintech_28,
ids_fintech_29,
ids_fintech_30,
ids_fintech_31,
ids_fintech_32,
ids_fintech_33,
ids_fintech_34,
ids_fintech_35,
ids_fintech_36,
ids_fintech_37,
ids_fintech_38,
ids_fintech_39,
ids_fintech_40,
ids_fintech_41,
ids_fintech_42,
ids_fintech_43,
ids_fintech_44,
ids_fintech_45,
ids_fintech_46,
ids_fintech_47,
ids_fintech_48,
ids_fintech_49,
    
]

# %%
deets_fintech = []

# %%
for x in ids_fintech_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_fintech.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 3 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_fintech_list))):
    try:
        print(deets_fintech[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223131411042824192].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223131411042824192', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223100829600608256].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223100829600608256', 'resource_type': 'tweet'}]
# [{'resource_id': '1223057371540291587', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}]

# %%
with open('deets_fintech.json', 'w', encoding='utf-8') as f:
    json.dump(deets_fintech, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "financial" tweets

# %%
ids_financial_split = list(split_list(tweet_ids_financial, 100))

# %%
for x in list(range(0,len(ids_financial_split))):
    print("ids_financial_{} = str(ids_financial_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_financial_0 = str(ids_financial_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_1 = str(ids_financial_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_2 = str(ids_financial_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_3 = str(ids_financial_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_4 = str(ids_financial_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_5 = str(ids_financial_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_6 = str(ids_financial_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_7 = str(ids_financial_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_8 = str(ids_financial_split[8]).replace(', ',',').replace('[','').replace(']','')
# ids_financial_9 = str(ids_financial_split[9]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_financial_0 = str(ids_financial_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_financial_1 = str(ids_financial_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_financial_2 = str(ids_financial_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_financial_3 = str(ids_financial_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_financial_4 = str(ids_financial_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_financial_5 = str(ids_financial_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_financial_6 = str(ids_financial_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_financial_7 = str(ids_financial_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_financial_8 = str(ids_financial_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_financial_9 = str(ids_financial_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_financial_10 = str(ids_financial_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_financial_11 = str(ids_financial_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_financial_12 = str(ids_financial_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_financial_13 = str(ids_financial_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_financial_14 = str(ids_financial_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_financial_15 = str(ids_financial_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_financial_16 = str(ids_financial_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_financial_17 = str(ids_financial_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_financial_18 = str(ids_financial_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_financial_19 = str(ids_financial_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_financial_20 = str(ids_financial_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_financial_21 = str(ids_financial_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_financial_22 = str(ids_financial_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_financial_23 = str(ids_financial_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_financial_24 = str(ids_financial_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_financial_25 = str(ids_financial_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_financial_26 = str(ids_financial_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_financial_27 = str(ids_financial_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_financial_28 = str(ids_financial_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_financial_29 = str(ids_financial_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_financial_30 = str(ids_financial_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_financial_31 = str(ids_financial_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_financial_32 = str(ids_financial_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_financial_33 = str(ids_financial_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_financial_34 = str(ids_financial_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_financial_35 = str(ids_financial_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_financial_36 = str(ids_financial_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_financial_37 = str(ids_financial_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_financial_38 = str(ids_financial_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_financial_39 = str(ids_financial_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_financial_40 = str(ids_financial_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_financial_41 = str(ids_financial_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_financial_42 = str(ids_financial_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_financial_43 = str(ids_financial_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_financial_44 = str(ids_financial_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_financial_45 = str(ids_financial_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_financial_46 = str(ids_financial_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_financial_47 = str(ids_financial_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_financial_48 = str(ids_financial_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_financial_49 = str(ids_financial_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_financial_split))):
    print('ids_financial_{},'.format(x))
# Out:
# ids_financial_0,
# ids_financial_1,
# ids_financial_2,
# ids_financial_3,
# ids_financial_4,
# ids_financial_5,
# ids_financial_6,
# ids_financial_7,
# ids_financial_8,
# ids_financial_9,
# ids_financial_10,
# ids_financial_11,
# ids_financial_12,
# ids_financial_13,
# ids_financial_14,
# ids_financial_15,
# ids_financial_16,
# ids_financial_17,
# ids_financial_18,
# ids_financial_19,
# ids_financial_20,
# ids_financial_21,
# ids_financial_22,
# ids_financial_23,
# ids_financial_24,
# ids_financial_25,
# ids_financial_26,
# ids_financial_27,
# ids_financial_28,
# ids_financial_29,
# ids_financial_30,
# ids_financial_31,
# ids_financial_32,
# ids_financial_33,
# ids_financial_34,
# ids_financial_35,
# ids_financial_36,
# ids_financial_37,
# ids_financial_38,
# ids_financial_39,
# ids_financial_40,
# ids_financial_41,
# ids_financial_42,
# ids_financial_43,
# ids_financial_44,
# ids_financial_45,
# ids_financial_46,
# ids_financial_47,
# ids_financial_48,
# ids_financial_49,

# %%
ids_financial_list = [
    
ids_financial_0,
ids_financial_1,
ids_financial_2,
ids_financial_3,
ids_financial_4,
ids_financial_5,
ids_financial_6,
ids_financial_7,
ids_financial_8,
ids_financial_9,
ids_financial_10,
ids_financial_11,
ids_financial_12,
ids_financial_13,
ids_financial_14,
ids_financial_15,
ids_financial_16,
ids_financial_17,
ids_financial_18,
ids_financial_19,
ids_financial_20,
ids_financial_21,
ids_financial_22,
ids_financial_23,
ids_financial_24,
ids_financial_25,
ids_financial_26,
ids_financial_27,
ids_financial_28,
ids_financial_29,
ids_financial_30,
ids_financial_31,
ids_financial_32,
ids_financial_33,
ids_financial_34,
ids_financial_35,
ids_financial_36,
ids_financial_37,
ids_financial_38,
ids_financial_39,
ids_financial_40,
ids_financial_41,
ids_financial_42,
ids_financial_43,
ids_financial_44,
ids_financial_45,
ids_financial_46,
ids_financial_47,
ids_financial_48,
ids_financial_49
    
]

# %%
deets_financial = []

# %%
for x in ids_financial_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_financial.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 11 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_financial_list))):
    try:
        print(deets_financial[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223749902687096833].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223749902687096833', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223352861502906369].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223352861502906369', 'resource_type': 'tweet'}]
# [{'resource_id': '1223351786729242624', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}]
# ...

# %%
with open('deets_financial.json', 'w', encoding='utf-8') as f:
    json.dump(deets_financial, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "money management" tweets

# %%
ids_money_management_split = list(split_list(tweet_ids_money_management, 100))

# %%
for x in list(range(0,len(ids_money_management_split))):
    print("ids_money_management_{} = str(ids_money_management_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_money_management_0 = str(ids_money_management_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_1 = str(ids_money_management_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_2 = str(ids_money_management_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_3 = str(ids_money_management_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_4 = str(ids_money_management_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_5 = str(ids_money_management_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_6 = str(ids_money_management_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_money_management_7 = str(ids_money_management_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_money_management_0 = str(ids_money_management_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_1 = str(ids_money_management_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_2 = str(ids_money_management_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_3 = str(ids_money_management_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_4 = str(ids_money_management_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_5 = str(ids_money_management_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_6 = str(ids_money_management_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_7 = str(ids_money_management_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_8 = str(ids_money_management_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_9 = str(ids_money_management_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_10 = str(ids_money_management_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_11 = str(ids_money_management_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_12 = str(ids_money_management_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_13 = str(ids_money_management_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_14 = str(ids_money_management_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_15 = str(ids_money_management_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_16 = str(ids_money_management_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_17 = str(ids_money_management_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_18 = str(ids_money_management_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_19 = str(ids_money_management_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_20 = str(ids_money_management_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_21 = str(ids_money_management_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_22 = str(ids_money_management_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_23 = str(ids_money_management_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_24 = str(ids_money_management_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_25 = str(ids_money_management_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_26 = str(ids_money_management_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_27 = str(ids_money_management_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_28 = str(ids_money_management_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_29 = str(ids_money_management_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_30 = str(ids_money_management_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_31 = str(ids_money_management_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_32 = str(ids_money_management_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_33 = str(ids_money_management_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_34 = str(ids_money_management_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_35 = str(ids_money_management_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_36 = str(ids_money_management_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_37 = str(ids_money_management_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_38 = str(ids_money_management_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_39 = str(ids_money_management_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_40 = str(ids_money_management_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_41 = str(ids_money_management_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_42 = str(ids_money_management_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_43 = str(ids_money_management_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_44 = str(ids_money_management_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_45 = str(ids_money_management_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_46 = str(ids_money_management_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_47 = str(ids_money_management_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_48 = str(ids_money_management_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_money_management_49 = str(ids_money_management_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_money_management_split))):
    print('ids_money_management_{},'.format(x))
# Out:
# ids_money_management_0,
# ids_money_management_1,
# ids_money_management_2,
# ids_money_management_3,
# ids_money_management_4,
# ids_money_management_5,
# ids_money_management_6,
# ids_money_management_7,
# ids_money_management_8,
# ids_money_management_9,
# ids_money_management_10,
# ids_money_management_11,
# ids_money_management_12,
# ids_money_management_13,
# ids_money_management_14,
# ids_money_management_15,
# ids_money_management_16,
# ids_money_management_17,
# ids_money_management_18,
# ids_money_management_19,
# ids_money_management_20,
# ids_money_management_21,
# ids_money_management_22,
# ids_money_management_23,
# ids_money_management_24,
# ids_money_management_25,
# ids_money_management_26,
# ids_money_management_27,
# ids_money_management_28,
# ids_money_management_29,
# ids_money_management_30,
# ids_money_management_31,
# ids_money_management_32,
# ids_money_management_33,
# ids_money_management_34,
# ids_money_management_35,
# ids_money_management_36,
# ...

# %%
ids_money_management_list = [
    
ids_money_management_0,
ids_money_management_1,
ids_money_management_2,
ids_money_management_3,
ids_money_management_4,
ids_money_management_5,
ids_money_management_6,
ids_money_management_7,
ids_money_management_8,
ids_money_management_9,
ids_money_management_10,
ids_money_management_11,
ids_money_management_12,
ids_money_management_13,
ids_money_management_14,
ids_money_management_15,
ids_money_management_16,
ids_money_management_17,
ids_money_management_18,
ids_money_management_19,
ids_money_management_20,
ids_money_management_21,
ids_money_management_22,
ids_money_management_23,
ids_money_management_24,
ids_money_management_25,
ids_money_management_26,
ids_money_management_27,
ids_money_management_28,
ids_money_management_29,
ids_money_management_30,
ids_money_management_31,
ids_money_management_32,
ids_money_management_33,
ids_money_management_34,
ids_money_management_35,
ids_money_management_36,
ids_money_management_37,
ids_money_management_38,
ids_money_management_39,
ids_money_management_40,
ids_money_management_41,
ids_money_management_42,
ids_money_management_43,
ids_money_management_44,
ids_money_management_45,
ids_money_management_46,
ids_money_management_47,
ids_money_management_48,
ids_money_management_49
    
]

# %%
deets_money_management = []

# %%
for x in ids_money_management_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_money_management.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 12 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_money_management_list))):
    try:
        print(deets_money_management[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find tweet with ids: [1223753031612801026].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223753031612801026', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223741132204650496].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223741132204650496', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223743652603813889].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223743652603813889', 'resource_type': 'tweet'}]
# ...

# %%
with open('deets_money_management.json', 'w', encoding='utf-8') as f:
    json.dump(deets_money_management, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "stocks" tweets

# %%
ids_stocks_split = list(split_list(tweet_ids_stocks, 100))

# %%
for x in list(range(0,len(ids_stocks_split))):
    print("ids_stocks_{} = str(ids_stocks_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_stocks_0 = str(ids_stocks_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_1 = str(ids_stocks_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_2 = str(ids_stocks_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_3 = str(ids_stocks_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_4 = str(ids_stocks_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_5 = str(ids_stocks_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_6 = str(ids_stocks_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_7 = str(ids_stocks_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_8 = str(ids_stocks_split[8]).replace(', ',',').replace('[','').replace(']','')
# ids_stocks_9 = str(ids_stocks_split[9]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_stocks_0 = str(ids_stocks_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_1 = str(ids_stocks_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_2 = str(ids_stocks_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_3 = str(ids_stocks_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_4 = str(ids_stocks_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_5 = str(ids_stocks_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_6 = str(ids_stocks_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_7 = str(ids_stocks_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_8 = str(ids_stocks_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_9 = str(ids_stocks_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_10 = str(ids_stocks_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_11 = str(ids_stocks_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_12 = str(ids_stocks_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_13 = str(ids_stocks_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_14 = str(ids_stocks_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_15 = str(ids_stocks_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_16 = str(ids_stocks_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_17 = str(ids_stocks_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_18 = str(ids_stocks_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_19 = str(ids_stocks_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_20 = str(ids_stocks_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_21 = str(ids_stocks_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_22 = str(ids_stocks_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_23 = str(ids_stocks_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_24 = str(ids_stocks_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_25 = str(ids_stocks_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_26 = str(ids_stocks_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_27 = str(ids_stocks_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_28 = str(ids_stocks_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_29 = str(ids_stocks_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_30 = str(ids_stocks_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_31 = str(ids_stocks_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_32 = str(ids_stocks_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_33 = str(ids_stocks_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_34 = str(ids_stocks_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_35 = str(ids_stocks_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_36 = str(ids_stocks_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_37 = str(ids_stocks_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_38 = str(ids_stocks_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_39 = str(ids_stocks_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_40 = str(ids_stocks_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_41 = str(ids_stocks_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_42 = str(ids_stocks_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_43 = str(ids_stocks_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_44 = str(ids_stocks_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_45 = str(ids_stocks_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_stocks_46 = str(ids_stocks_split[46]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_stocks_split))):
    print('ids_stocks_{},'.format(x))
# Out:
# ids_stocks_0,
# ids_stocks_1,
# ids_stocks_2,
# ids_stocks_3,
# ids_stocks_4,
# ids_stocks_5,
# ids_stocks_6,
# ids_stocks_7,
# ids_stocks_8,
# ids_stocks_9,
# ids_stocks_10,
# ids_stocks_11,
# ids_stocks_12,
# ids_stocks_13,
# ids_stocks_14,
# ids_stocks_15,
# ids_stocks_16,
# ids_stocks_17,
# ids_stocks_18,
# ids_stocks_19,
# ids_stocks_20,
# ids_stocks_21,
# ids_stocks_22,
# ids_stocks_23,
# ids_stocks_24,
# ids_stocks_25,
# ids_stocks_26,
# ids_stocks_27,
# ids_stocks_28,
# ids_stocks_29,
# ids_stocks_30,
# ids_stocks_31,
# ids_stocks_32,
# ids_stocks_33,
# ids_stocks_34,
# ids_stocks_35,
# ids_stocks_36,
# ids_stocks_37,
# ids_stocks_38,
# ids_stocks_39,
# ids_stocks_40,
# ids_stocks_41,
# ids_stocks_42,
# ids_stocks_43,
# ids_stocks_44,
# ids_stocks_45,
# ids_stocks_46,

# %%
ids_stocks_list = [
    
ids_stocks_0,
ids_stocks_1,
ids_stocks_2,
ids_stocks_3,
ids_stocks_4,
ids_stocks_5,
ids_stocks_6,
ids_stocks_7,
ids_stocks_8,
ids_stocks_9,
ids_stocks_10,
ids_stocks_11,
ids_stocks_12,
ids_stocks_13,
ids_stocks_14,
ids_stocks_15,
ids_stocks_16,
ids_stocks_17,
ids_stocks_18,
ids_stocks_19,
ids_stocks_20,
ids_stocks_21,
ids_stocks_22,
ids_stocks_23,
ids_stocks_24,
ids_stocks_25,
ids_stocks_26,
ids_stocks_27,
ids_stocks_28,
ids_stocks_29,
ids_stocks_30,
ids_stocks_31,
ids_stocks_32,
ids_stocks_33,
ids_stocks_34,
ids_stocks_35,
ids_stocks_36,
ids_stocks_37,
ids_stocks_38,
ids_stocks_39,
ids_stocks_40,
ids_stocks_41,
ids_stocks_42,
ids_stocks_43,
ids_stocks_44,
ids_stocks_45,
ids_stocks_46,
    
]

# %%
deets_stocks = []

# %%
for x in ids_stocks_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_stocks.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 8 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_stocks_list))):
    try:
        print(deets_stocks[x]['errors'])
    except:
        pass
# Out:
# [{'resource_id': '1223266829700927490', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223262847196696576].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223262847196696576', 'resource_type': 'tweet'}]
# [{'detail': 'Could not find tweet with ids: [1223253676107669504].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223253676107669504', 'resource_type': 'tweet'}]
# ...

# %%
with open('deets_stocks.json', 'w', encoding='utf-8') as f:
    json.dump(deets_stocks, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query deets for "transaction" tweets

# %%
ids_transaction_split = list(split_list(tweet_ids_transaction, 100))

# %%
for x in list(range(0,len(ids_transaction_split))):
    print("ids_transaction_{} = str(ids_transaction_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# ids_transaction_0 = str(ids_transaction_split[0]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_1 = str(ids_transaction_split[1]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_2 = str(ids_transaction_split[2]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_3 = str(ids_transaction_split[3]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_4 = str(ids_transaction_split[4]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_5 = str(ids_transaction_split[5]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_6 = str(ids_transaction_split[6]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_7 = str(ids_transaction_split[7]).replace(', ',',').replace('[','').replace(']','')
# ids_transaction_8 = str(ids_transaction_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
ids_transaction_0 = str(ids_transaction_split[0]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_1 = str(ids_transaction_split[1]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_2 = str(ids_transaction_split[2]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_3 = str(ids_transaction_split[3]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_4 = str(ids_transaction_split[4]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_5 = str(ids_transaction_split[5]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_6 = str(ids_transaction_split[6]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_7 = str(ids_transaction_split[7]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_8 = str(ids_transaction_split[8]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_9 = str(ids_transaction_split[9]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_10 = str(ids_transaction_split[10]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_11 = str(ids_transaction_split[11]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_12 = str(ids_transaction_split[12]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_13 = str(ids_transaction_split[13]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_14 = str(ids_transaction_split[14]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_15 = str(ids_transaction_split[15]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_16 = str(ids_transaction_split[16]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_17 = str(ids_transaction_split[17]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_18 = str(ids_transaction_split[18]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_19 = str(ids_transaction_split[19]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_20 = str(ids_transaction_split[20]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_21 = str(ids_transaction_split[21]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_22 = str(ids_transaction_split[22]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_23 = str(ids_transaction_split[23]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_24 = str(ids_transaction_split[24]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_25 = str(ids_transaction_split[25]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_26 = str(ids_transaction_split[26]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_27 = str(ids_transaction_split[27]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_28 = str(ids_transaction_split[28]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_29 = str(ids_transaction_split[29]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_30 = str(ids_transaction_split[30]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_31 = str(ids_transaction_split[31]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_32 = str(ids_transaction_split[32]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_33 = str(ids_transaction_split[33]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_34 = str(ids_transaction_split[34]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_35 = str(ids_transaction_split[35]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_36 = str(ids_transaction_split[36]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_37 = str(ids_transaction_split[37]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_38 = str(ids_transaction_split[38]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_39 = str(ids_transaction_split[39]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_40 = str(ids_transaction_split[40]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_41 = str(ids_transaction_split[41]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_42 = str(ids_transaction_split[42]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_43 = str(ids_transaction_split[43]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_44 = str(ids_transaction_split[44]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_45 = str(ids_transaction_split[45]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_46 = str(ids_transaction_split[46]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_47 = str(ids_transaction_split[47]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_48 = str(ids_transaction_split[48]).replace(', ',',').replace('[','').replace(']','')
ids_transaction_49 = str(ids_transaction_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(ids_transaction_split))):
    print('ids_transaction_{},'.format(x))
# Out:
# ids_transaction_0,
# ids_transaction_1,
# ids_transaction_2,
# ids_transaction_3,
# ids_transaction_4,
# ids_transaction_5,
# ids_transaction_6,
# ids_transaction_7,
# ids_transaction_8,
# ids_transaction_9,
# ids_transaction_10,
# ids_transaction_11,
# ids_transaction_12,
# ids_transaction_13,
# ids_transaction_14,
# ids_transaction_15,
# ids_transaction_16,
# ids_transaction_17,
# ids_transaction_18,
# ids_transaction_19,
# ids_transaction_20,
# ids_transaction_21,
# ids_transaction_22,
# ids_transaction_23,
# ids_transaction_24,
# ids_transaction_25,
# ids_transaction_26,
# ids_transaction_27,
# ids_transaction_28,
# ids_transaction_29,
# ids_transaction_30,
# ids_transaction_31,
# ids_transaction_32,
# ids_transaction_33,
# ids_transaction_34,
# ids_transaction_35,
# ids_transaction_36,
# ids_transaction_37,
# ids_transaction_38,
# ids_transaction_39,
# ids_transaction_40,
# ids_transaction_41,
# ids_transaction_42,
# ids_transaction_43,
# ids_transaction_44,
# ...

# %%
ids_transaction_list = [
    
ids_transaction_0,
ids_transaction_1,
ids_transaction_2,
ids_transaction_3,
ids_transaction_4,
ids_transaction_5,
ids_transaction_6,
ids_transaction_7,
ids_transaction_8,
ids_transaction_9,
ids_transaction_10,
ids_transaction_11,
ids_transaction_12,
ids_transaction_13,
ids_transaction_14,
ids_transaction_15,
ids_transaction_16,
ids_transaction_17,
ids_transaction_18,
ids_transaction_19,
ids_transaction_20,
ids_transaction_21,
ids_transaction_22,
ids_transaction_23,
ids_transaction_24,
ids_transaction_25,
ids_transaction_26,
ids_transaction_27,
ids_transaction_28,
ids_transaction_29,
ids_transaction_30,
ids_transaction_31,
ids_transaction_32,
ids_transaction_33,
ids_transaction_34,
ids_transaction_35,
ids_transaction_36,
ids_transaction_37,
ids_transaction_38,
ids_transaction_39,
ids_transaction_40,
ids_transaction_41,
ids_transaction_42,
ids_transaction_43,
ids_transaction_44,
ids_transaction_45,
ids_transaction_46,
ids_transaction_47,
ids_transaction_48,
ids_transaction_49
    
]

# %%
deets_transaction = []

# %%
for x in ids_transaction_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'tweet.format': 'detailed',
            'user.format': 'detailed',
            'place.format': 'detailed'
        }

        search_url = 'https://api.twitter.com/labs/1/tweets'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        deets_transaction.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 21 tweet ids missing from what we called earlier.**

# %%
for x in list(range(0,len(ids_transaction_list))):
    try:
        print(deets_transaction[x]['errors'])
    except:
        pass
# Out:
# [{'resource_id': '1223759208421584897', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}, {'resource_id': '1223758127214088192', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}, {'resource_id': '1223758090236882944', 'section': 'data', 'type': 'https://api.twitter.com/labs/1/problems/not-authorized-for-resource', 'title': 'Authorization Error', 'detail': 'Sorry, you are not authorized to see this Tweet.', 'resource_type': 'tweet'}, {'detail': 'Could not find tweet with ids: [1223750883990802434].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223750883990802434', 'reso
# ...

# %%
with open('deets_transaction.json', 'w', encoding='utf-8') as f:
    json.dump(deets_transaction, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ___

# %% [markdown]
# ## Call To "labs/1/users" Endpoint For Tweet "Users"

# %% [markdown]
# ### Get User ids

# %% [markdown]
# - 900 requests per 15-minute window
# - 100 ids per request
# - So we need to convert our lists of ids into sets of 100.
# - Then convert these sets of 100 into individual strings.
# - Each id needs to be separated with a comma with no spaces to feed into each call.

# %%
#accessing user ids
tweets_search_investing[0]['statuses'][0]['user']['id']
# Out:
# 284278132

# %%
user_ids_investing = []
user_ids_mobile_payment = []
user_ids_mobile_wallet = []
user_ids_mobile_banking = []
user_ids_trading = []
user_ids_fintech = []
user_ids_financial = []
user_ids_money_management = []
user_ids_stocks = []
user_ids_transaction = []

for x in range(len(tweets_search_investing)):
    for y in range(len(tweets_search_investing[0]['statuses'])):
        try:
            user_ids_investing.append(tweets_search_investing[x]['statuses'][y]['user']['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_payment)):
    for y in range(len(tweets_search_mobile_payment[0]['statuses'])):
        try:
            user_ids_mobile_payment.append(tweets_search_mobile_payment[x]['statuses'][y]['user']['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_wallet)):
    for y in range(len(tweets_search_mobile_wallet[0]['statuses'])):
        try:        
            user_ids_mobile_wallet.append(tweets_search_mobile_wallet[x]['statuses'][y]['user']['id'])
        except:
            continue
        
for x in range(len(tweets_search_mobile_banking)):
    for y in range(len(tweets_search_mobile_banking[0]['statuses'])):
        try:
            user_ids_mobile_banking.append(tweets_search_mobile_banking[x]['statuses'][y]['user']['id'])
        except:
            continue
            
for x in range(len(tweets_search_trading)):
    for y in range(len(tweets_search_trading[0]['statuses'])):
        try:        
            user_ids_trading.append(tweets_search_trading[x]['statuses'][y]['user']['id'])
        except:
            continue
            
for x in range(len(tweets_search_fintech)):
    for y in range(len(tweets_search_fintech[0]['statuses'])):
        try:        
            user_ids_fintech.append(tweets_search_fintech[x]['statuses'][y]['user']['id'])
        except:
            continue

for x in range(len(tweets_search_financial)):
    for y in range(len(tweets_search_financial[0]['statuses'])):
        try:   
            user_ids_financial.append(tweets_search_financial[x]['statuses'][y]['user']['id'])
        except:
            continue

for x in range(len(tweets_search_money_management)):
    for y in range(len(tweets_search_money_management[0]['statuses'])):
        try:        
            user_ids_money_management.append(tweets_search_money_management[x]['statuses'][y]['user']['id'])
        except:
            continue
        
for x in range(len(tweets_search_stocks)):
    for y in range(len(tweets_search_stocks[0]['statuses'])):
        try:        
            user_ids_stocks.append(tweets_search_stocks[x]['statuses'][y]['user']['id'])
        except:
            continue
        
for x in range(len(tweets_search_transaction)):
    for y in range(len(tweets_search_transaction[0]['statuses'])):
        try:        
            user_ids_transaction.append(tweets_search_transaction[x]['statuses'][y]['user']['id'])
        except:
            continue

# %% [markdown]
# ### Query users for "investing" tweets

# %%
user_ids_investing_split = list(split_list(user_ids_investing, 100))

# %%
for x in list(range(0,len(user_ids_investing_split))):
    print("user_ids_investing_{} = str(user_ids_investing_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_investing_0 = str(user_ids_investing_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_1 = str(user_ids_investing_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_2 = str(user_ids_investing_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_3 = str(user_ids_investing_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_4 = str(user_ids_investing_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_5 = str(user_ids_investing_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_6 = str(user_ids_investing_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_7 = str(user_ids_investing_split[7]).replace(', ',',').replace('[','').replace(']','')
# user_ids_investing_8 = str(user_ids_investing_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_investing_0 = str(user_ids_investing_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_1 = str(user_ids_investing_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_2 = str(user_ids_investing_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_3 = str(user_ids_investing_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_4 = str(user_ids_investing_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_5 = str(user_ids_investing_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_6 = str(user_ids_investing_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_7 = str(user_ids_investing_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_8 = str(user_ids_investing_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_9 = str(user_ids_investing_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_10 = str(user_ids_investing_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_11 = str(user_ids_investing_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_12 = str(user_ids_investing_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_13 = str(user_ids_investing_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_14 = str(user_ids_investing_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_15 = str(user_ids_investing_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_16 = str(user_ids_investing_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_17 = str(user_ids_investing_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_18 = str(user_ids_investing_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_19 = str(user_ids_investing_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_20 = str(user_ids_investing_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_21 = str(user_ids_investing_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_22 = str(user_ids_investing_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_23 = str(user_ids_investing_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_24 = str(user_ids_investing_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_25 = str(user_ids_investing_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_26 = str(user_ids_investing_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_27 = str(user_ids_investing_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_28 = str(user_ids_investing_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_29 = str(user_ids_investing_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_30 = str(user_ids_investing_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_31 = str(user_ids_investing_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_32 = str(user_ids_investing_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_33 = str(user_ids_investing_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_34 = str(user_ids_investing_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_35 = str(user_ids_investing_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_36 = str(user_ids_investing_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_37 = str(user_ids_investing_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_38 = str(user_ids_investing_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_39 = str(user_ids_investing_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_40 = str(user_ids_investing_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_41 = str(user_ids_investing_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_42 = str(user_ids_investing_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_43 = str(user_ids_investing_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_44 = str(user_ids_investing_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_45 = str(user_ids_investing_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_46 = str(user_ids_investing_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_47 = str(user_ids_investing_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_48 = str(user_ids_investing_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_investing_49 = str(user_ids_investing_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_investing_split))):
    print('user_ids_investing_{},'.format(x))
# Out:
# user_ids_investing_0,
# user_ids_investing_1,
# user_ids_investing_2,
# user_ids_investing_3,
# user_ids_investing_4,
# user_ids_investing_5,
# user_ids_investing_6,
# user_ids_investing_7,
# user_ids_investing_8,
# user_ids_investing_9,
# user_ids_investing_10,
# user_ids_investing_11,
# user_ids_investing_12,
# user_ids_investing_13,
# user_ids_investing_14,
# user_ids_investing_15,
# user_ids_investing_16,
# user_ids_investing_17,
# user_ids_investing_18,
# user_ids_investing_19,
# user_ids_investing_20,
# user_ids_investing_21,
# user_ids_investing_22,
# user_ids_investing_23,
# user_ids_investing_24,
# user_ids_investing_25,
# user_ids_investing_26,
# user_ids_investing_27,
# user_ids_investing_28,
# user_ids_investing_29,
# user_ids_investing_30,
# user_ids_investing_31,
# user_ids_investing_32,
# user_ids_investing_33,
# user_ids_investing_34,
# user_ids_investing_35,
# user_ids_investing_36,
# user_ids_investing_37,
# user_ids_investing_38,
# user_ids_investing_39,
# ...

# %%
user_ids_investing_list = [
    
user_ids_investing_0,
user_ids_investing_1,
user_ids_investing_2,
user_ids_investing_3,
user_ids_investing_4,
user_ids_investing_5,
user_ids_investing_6,
user_ids_investing_7,
user_ids_investing_8,
user_ids_investing_9,
user_ids_investing_10,
user_ids_investing_11,
user_ids_investing_12,
user_ids_investing_13,
user_ids_investing_14,
user_ids_investing_15,
user_ids_investing_16,
user_ids_investing_17,
user_ids_investing_18,
user_ids_investing_19,
user_ids_investing_20,
user_ids_investing_21,
user_ids_investing_22,
user_ids_investing_23,
user_ids_investing_24,
user_ids_investing_25,
user_ids_investing_26,
user_ids_investing_27,
user_ids_investing_28,
user_ids_investing_29,
user_ids_investing_30,
user_ids_investing_31,
user_ids_investing_32,
user_ids_investing_33,
user_ids_investing_34,
user_ids_investing_35,
user_ids_investing_36,
user_ids_investing_37,
user_ids_investing_38,
user_ids_investing_39,
user_ids_investing_40,
user_ids_investing_41,
user_ids_investing_42,
user_ids_investing_43,
user_ids_investing_44,
user_ids_investing_45,
user_ids_investing_46,
user_ids_investing_47,
user_ids_investing_48,
user_ids_investing_49
    
]

# %%
user_investing = []

# %%
for x in user_ids_investing_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_investing.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 3 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_investing))):
    try:
        print(user_investing[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find user with ids: [794459372944556032].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '794459372944556032', 'resource_type': 'user'}]
# [{'detail': 'Could not find user with ids: [939360009863024640].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '939360009863024640', 'resource_type': 'user'}]
# [{'value': '714991341', 'detail': 'Could not find user with id: [714991341].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'detail': 'Could not find user with ids: [714991341].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '714991341', 'resource_type': 'user'}]

# %%
with open('user_investing.json', 'w', encoding='utf-8') as f:
    json.dump(user_investing, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "mobile payment" tweets

# %%
user_ids_mobile_payment_split = list(split_list(user_ids_mobile_payment, 100))

# %%
for x in list(range(0,len(user_ids_mobile_payment_split))):
    print("user_ids_mobile_payment_{} = str(user_ids_mobile_payment_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_mobile_payment_0 = str(user_ids_mobile_payment_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_1 = str(user_ids_mobile_payment_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_2 = str(user_ids_mobile_payment_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_3 = str(user_ids_mobile_payment_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_4 = str(user_ids_mobile_payment_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_5 = str(user_ids_mobile_payment_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_6 = str(user_ids_mobile_payment_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_payment_7 = str(user_ids_mobile_payment_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_mobile_payment_0 = str(user_ids_mobile_payment_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_1 = str(user_ids_mobile_payment_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_2 = str(user_ids_mobile_payment_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_3 = str(user_ids_mobile_payment_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_4 = str(user_ids_mobile_payment_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_5 = str(user_ids_mobile_payment_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_6 = str(user_ids_mobile_payment_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_7 = str(user_ids_mobile_payment_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_8 = str(user_ids_mobile_payment_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_9 = str(user_ids_mobile_payment_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_10 = str(user_ids_mobile_payment_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_11 = str(user_ids_mobile_payment_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_payment_12 = str(user_ids_mobile_payment_split[12]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_mobile_payment_split))):
    print('user_ids_mobile_payment_{},'.format(x))
# Out:
# user_ids_mobile_payment_0,
# user_ids_mobile_payment_1,
# user_ids_mobile_payment_2,
# user_ids_mobile_payment_3,
# user_ids_mobile_payment_4,
# user_ids_mobile_payment_5,
# user_ids_mobile_payment_6,
# user_ids_mobile_payment_7,
# user_ids_mobile_payment_8,
# user_ids_mobile_payment_9,
# user_ids_mobile_payment_10,
# user_ids_mobile_payment_11,
# user_ids_mobile_payment_12,

# %%
user_ids_mobile_payment_list = [
    
user_ids_mobile_payment_0,
user_ids_mobile_payment_1,
user_ids_mobile_payment_2,
user_ids_mobile_payment_3,
user_ids_mobile_payment_4,
user_ids_mobile_payment_5,
user_ids_mobile_payment_6,
user_ids_mobile_payment_7,
user_ids_mobile_payment_8,
user_ids_mobile_payment_9,
user_ids_mobile_payment_10,
user_ids_mobile_payment_11,
user_ids_mobile_payment_12
    
]

# %%
user_mobile_payment = []

# %%
for x in user_ids_mobile_payment_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_mobile_payment.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 0 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_mobile_payment))):
    try:
        print(user_mobile_payment[x]['errors'])
    except:
        pass

# %%
with open('user_mobile_payment.json', 'w', encoding='utf-8') as f:
    json.dump(user_mobile_payment, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "mobile wallet" tweets

# %%
user_ids_mobile_wallet_split = list(split_list(user_ids_mobile_wallet, 100))

# %%
for x in list(range(0,len(user_ids_mobile_wallet_split))):
    print("user_ids_mobile_wallet_{} = str(user_ids_mobile_wallet_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_mobile_wallet_0 = str(user_ids_mobile_wallet_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_1 = str(user_ids_mobile_wallet_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_2 = str(user_ids_mobile_wallet_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_3 = str(user_ids_mobile_wallet_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_4 = str(user_ids_mobile_wallet_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_5 = str(user_ids_mobile_wallet_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_6 = str(user_ids_mobile_wallet_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_wallet_7 = str(user_ids_mobile_wallet_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_mobile_wallet_0 = str(user_ids_mobile_wallet_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_1 = str(user_ids_mobile_wallet_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_2 = str(user_ids_mobile_wallet_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_3 = str(user_ids_mobile_wallet_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_4 = str(user_ids_mobile_wallet_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_5 = str(user_ids_mobile_wallet_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_6 = str(user_ids_mobile_wallet_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_7 = str(user_ids_mobile_wallet_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_8 = str(user_ids_mobile_wallet_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_9 = str(user_ids_mobile_wallet_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_10 = str(user_ids_mobile_wallet_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_11 = str(user_ids_mobile_wallet_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_12 = str(user_ids_mobile_wallet_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_13 = str(user_ids_mobile_wallet_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_14 = str(user_ids_mobile_wallet_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_15 = str(user_ids_mobile_wallet_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_16 = str(user_ids_mobile_wallet_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_17 = str(user_ids_mobile_wallet_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_18 = str(user_ids_mobile_wallet_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_19 = str(user_ids_mobile_wallet_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_wallet_20 = str(user_ids_mobile_wallet_split[20]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_mobile_wallet_split))):
    print('user_ids_mobile_wallet_{},'.format(x))
# Out:
# user_ids_mobile_wallet_0,
# user_ids_mobile_wallet_1,
# user_ids_mobile_wallet_2,
# user_ids_mobile_wallet_3,
# user_ids_mobile_wallet_4,
# user_ids_mobile_wallet_5,
# user_ids_mobile_wallet_6,
# user_ids_mobile_wallet_7,
# user_ids_mobile_wallet_8,
# user_ids_mobile_wallet_9,
# user_ids_mobile_wallet_10,
# user_ids_mobile_wallet_11,
# user_ids_mobile_wallet_12,
# user_ids_mobile_wallet_13,
# user_ids_mobile_wallet_14,
# user_ids_mobile_wallet_15,
# user_ids_mobile_wallet_16,
# user_ids_mobile_wallet_17,
# user_ids_mobile_wallet_18,
# user_ids_mobile_wallet_19,
# user_ids_mobile_wallet_20,

# %%
user_ids_mobile_wallet_list = [
    
user_ids_mobile_wallet_0,
user_ids_mobile_wallet_1,
user_ids_mobile_wallet_2,
user_ids_mobile_wallet_3,
user_ids_mobile_wallet_4,
user_ids_mobile_wallet_5,
user_ids_mobile_wallet_6,
user_ids_mobile_wallet_7,
user_ids_mobile_wallet_8,
user_ids_mobile_wallet_9,
user_ids_mobile_wallet_10,
user_ids_mobile_wallet_11,
user_ids_mobile_wallet_12,
user_ids_mobile_wallet_13,
user_ids_mobile_wallet_14,
user_ids_mobile_wallet_15,
user_ids_mobile_wallet_16,
user_ids_mobile_wallet_17,
user_ids_mobile_wallet_18,
user_ids_mobile_wallet_19,
user_ids_mobile_wallet_20
    
]

# %%
user_mobile_wallet = []

# %%
for x in user_ids_mobile_wallet_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_mobile_wallet.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 1 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_mobile_wallet))):
    try:
        print(user_mobile_wallet[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find user with ids: [1181976996341014531].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1181976996341014531', 'resource_type': 'user'}]

# %%
with open('user_mobile_wallet.json', 'w', encoding='utf-8') as f:
    json.dump(user_mobile_wallet, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "mobile banking" tweets

# %%
user_ids_mobile_banking_split = list(split_list(user_ids_mobile_banking, 100))

# %%
for x in list(range(0,len(user_ids_mobile_banking_split))):
    print("user_ids_mobile_banking_{} = str(user_ids_mobile_banking_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_mobile_banking_0 = str(user_ids_mobile_banking_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_1 = str(user_ids_mobile_banking_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_2 = str(user_ids_mobile_banking_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_3 = str(user_ids_mobile_banking_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_4 = str(user_ids_mobile_banking_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_5 = str(user_ids_mobile_banking_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_6 = str(user_ids_mobile_banking_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_mobile_banking_7 = str(user_ids_mobile_banking_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_mobile_banking_0 = str(user_ids_mobile_banking_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_1 = str(user_ids_mobile_banking_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_2 = str(user_ids_mobile_banking_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_3 = str(user_ids_mobile_banking_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_4 = str(user_ids_mobile_banking_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_5 = str(user_ids_mobile_banking_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_6 = str(user_ids_mobile_banking_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_7 = str(user_ids_mobile_banking_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_8 = str(user_ids_mobile_banking_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_9 = str(user_ids_mobile_banking_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_10 = str(user_ids_mobile_banking_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_11 = str(user_ids_mobile_banking_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_mobile_banking_12 = str(user_ids_mobile_banking_split[12]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_mobile_banking_split))):
    print('user_ids_mobile_banking_{},'.format(x))
# Out:
# user_ids_mobile_banking_0,
# user_ids_mobile_banking_1,
# user_ids_mobile_banking_2,
# user_ids_mobile_banking_3,
# user_ids_mobile_banking_4,
# user_ids_mobile_banking_5,
# user_ids_mobile_banking_6,
# user_ids_mobile_banking_7,
# user_ids_mobile_banking_8,
# user_ids_mobile_banking_9,
# user_ids_mobile_banking_10,
# user_ids_mobile_banking_11,
# user_ids_mobile_banking_12,

# %%
user_ids_mobile_banking_list = [
    
user_ids_mobile_banking_0,
user_ids_mobile_banking_1,
user_ids_mobile_banking_2,
user_ids_mobile_banking_3,
user_ids_mobile_banking_4,
user_ids_mobile_banking_5,
user_ids_mobile_banking_6,
user_ids_mobile_banking_7,
user_ids_mobile_banking_8,
user_ids_mobile_banking_9,
user_ids_mobile_banking_10,
user_ids_mobile_banking_11,
user_ids_mobile_banking_12
    
]

# %%
user_mobile_banking = []

# %%
for x in user_ids_mobile_banking_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_mobile_banking.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 0 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_mobile_banking))):
    try:
        print(user_mobile_banking[x]['errors'])
    except:
        pass

# %%
with open('user_mobile_banking.json', 'w', encoding='utf-8') as f:
    json.dump(user_mobile_banking, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "trading" tweets

# %%
user_ids_trading_split = list(split_list(user_ids_trading, 100))

# %%
for x in list(range(0,len(user_ids_trading_split))):
    print("user_ids_trading_{} = str(user_ids_trading_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_trading_0 = str(user_ids_trading_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_1 = str(user_ids_trading_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_2 = str(user_ids_trading_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_3 = str(user_ids_trading_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_4 = str(user_ids_trading_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_5 = str(user_ids_trading_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_6 = str(user_ids_trading_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_7 = str(user_ids_trading_split[7]).replace(', ',',').replace('[','').replace(']','')
# user_ids_trading_8 = str(user_ids_trading_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_trading_0 = str(user_ids_trading_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_1 = str(user_ids_trading_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_2 = str(user_ids_trading_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_3 = str(user_ids_trading_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_4 = str(user_ids_trading_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_5 = str(user_ids_trading_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_6 = str(user_ids_trading_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_7 = str(user_ids_trading_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_8 = str(user_ids_trading_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_9 = str(user_ids_trading_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_10 = str(user_ids_trading_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_11 = str(user_ids_trading_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_12 = str(user_ids_trading_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_13 = str(user_ids_trading_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_14 = str(user_ids_trading_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_15 = str(user_ids_trading_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_16 = str(user_ids_trading_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_17 = str(user_ids_trading_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_18 = str(user_ids_trading_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_19 = str(user_ids_trading_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_20 = str(user_ids_trading_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_21 = str(user_ids_trading_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_22 = str(user_ids_trading_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_23 = str(user_ids_trading_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_24 = str(user_ids_trading_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_25 = str(user_ids_trading_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_26 = str(user_ids_trading_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_27 = str(user_ids_trading_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_28 = str(user_ids_trading_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_29 = str(user_ids_trading_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_30 = str(user_ids_trading_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_31 = str(user_ids_trading_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_32 = str(user_ids_trading_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_33 = str(user_ids_trading_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_34 = str(user_ids_trading_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_35 = str(user_ids_trading_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_36 = str(user_ids_trading_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_37 = str(user_ids_trading_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_38 = str(user_ids_trading_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_39 = str(user_ids_trading_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_40 = str(user_ids_trading_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_41 = str(user_ids_trading_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_42 = str(user_ids_trading_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_43 = str(user_ids_trading_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_44 = str(user_ids_trading_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_45 = str(user_ids_trading_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_46 = str(user_ids_trading_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_47 = str(user_ids_trading_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_48 = str(user_ids_trading_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_trading_49 = str(user_ids_trading_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_trading_split))):
    print('user_ids_trading_{},'.format(x))
# Out:
# user_ids_trading_0,
# user_ids_trading_1,
# user_ids_trading_2,
# user_ids_trading_3,
# user_ids_trading_4,
# user_ids_trading_5,
# user_ids_trading_6,
# user_ids_trading_7,
# user_ids_trading_8,
# user_ids_trading_9,
# user_ids_trading_10,
# user_ids_trading_11,
# user_ids_trading_12,
# user_ids_trading_13,
# user_ids_trading_14,
# user_ids_trading_15,
# user_ids_trading_16,
# user_ids_trading_17,
# user_ids_trading_18,
# user_ids_trading_19,
# user_ids_trading_20,
# user_ids_trading_21,
# user_ids_trading_22,
# user_ids_trading_23,
# user_ids_trading_24,
# user_ids_trading_25,
# user_ids_trading_26,
# user_ids_trading_27,
# user_ids_trading_28,
# user_ids_trading_29,
# user_ids_trading_30,
# user_ids_trading_31,
# user_ids_trading_32,
# user_ids_trading_33,
# user_ids_trading_34,
# user_ids_trading_35,
# user_ids_trading_36,
# user_ids_trading_37,
# user_ids_trading_38,
# user_ids_trading_39,
# user_ids_trading_40,
# user_ids_trading_41,
# user_ids_trading_42,
# ...

# %%
user_ids_trading_list = [
    
user_ids_trading_0,
user_ids_trading_1,
user_ids_trading_2,
user_ids_trading_3,
user_ids_trading_4,
user_ids_trading_5,
user_ids_trading_6,
user_ids_trading_7,
user_ids_trading_8,
user_ids_trading_9,
user_ids_trading_10,
user_ids_trading_11,
user_ids_trading_12,
user_ids_trading_13,
user_ids_trading_14,
user_ids_trading_15,
user_ids_trading_16,
user_ids_trading_17,
user_ids_trading_18,
user_ids_trading_19,
user_ids_trading_20,
user_ids_trading_21,
user_ids_trading_22,
user_ids_trading_23,
user_ids_trading_24,
user_ids_trading_25,
user_ids_trading_26,
user_ids_trading_27,
user_ids_trading_28,
user_ids_trading_29,
user_ids_trading_30,
user_ids_trading_31,
user_ids_trading_32,
user_ids_trading_33,
user_ids_trading_34,
user_ids_trading_35,
user_ids_trading_36,
user_ids_trading_37,
user_ids_trading_38,
user_ids_trading_39,
user_ids_trading_40,
user_ids_trading_41,
user_ids_trading_42,
user_ids_trading_43,
user_ids_trading_44,
user_ids_trading_45,
user_ids_trading_46,
user_ids_trading_47,
user_ids_trading_48,
user_ids_trading_49
    
]

# %%
user_trading = []

# %%
for x in user_ids_trading_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_trading.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 4 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_trading))):
    try:
        print(user_trading[x]['errors'])
    except:
        pass
# Out:
# [{'value': '1223260510658990087', 'detail': 'Could not find user with id: [1223260510658990087].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'value': '1223260510658990087', 'detail': 'Could not find user with id: [1223260510658990087].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'detail': 'Could not find user with ids: [1223260510658990087].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1223260510658990087', 'resource_type': 'user'}]
# ...

# %%
with open('user_trading.json', 'w', encoding='utf-8') as f:
    json.dump(user_trading, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "fintech" tweets

# %%
user_ids_fintech_split = list(split_list(user_ids_fintech, 100))

# %%
for x in list(range(0,len(user_ids_fintech_split))):
    print("user_ids_fintech_{} = str(user_ids_fintech_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_fintech_0 = str(user_ids_fintech_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_1 = str(user_ids_fintech_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_2 = str(user_ids_fintech_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_3 = str(user_ids_fintech_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_4 = str(user_ids_fintech_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_5 = str(user_ids_fintech_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_6 = str(user_ids_fintech_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_7 = str(user_ids_fintech_split[7]).replace(', ',',').replace('[','').replace(']','')
# user_ids_fintech_8 = str(user_ids_fintech_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_fintech_0 = str(user_ids_fintech_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_1 = str(user_ids_fintech_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_2 = str(user_ids_fintech_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_3 = str(user_ids_fintech_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_4 = str(user_ids_fintech_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_5 = str(user_ids_fintech_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_6 = str(user_ids_fintech_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_7 = str(user_ids_fintech_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_8 = str(user_ids_fintech_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_9 = str(user_ids_fintech_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_10 = str(user_ids_fintech_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_11 = str(user_ids_fintech_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_12 = str(user_ids_fintech_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_13 = str(user_ids_fintech_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_14 = str(user_ids_fintech_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_15 = str(user_ids_fintech_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_16 = str(user_ids_fintech_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_17 = str(user_ids_fintech_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_18 = str(user_ids_fintech_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_19 = str(user_ids_fintech_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_20 = str(user_ids_fintech_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_21 = str(user_ids_fintech_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_22 = str(user_ids_fintech_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_23 = str(user_ids_fintech_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_24 = str(user_ids_fintech_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_25 = str(user_ids_fintech_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_26 = str(user_ids_fintech_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_27 = str(user_ids_fintech_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_28 = str(user_ids_fintech_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_29 = str(user_ids_fintech_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_30 = str(user_ids_fintech_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_31 = str(user_ids_fintech_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_32 = str(user_ids_fintech_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_33 = str(user_ids_fintech_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_34 = str(user_ids_fintech_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_35 = str(user_ids_fintech_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_36 = str(user_ids_fintech_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_37 = str(user_ids_fintech_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_38 = str(user_ids_fintech_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_39 = str(user_ids_fintech_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_40 = str(user_ids_fintech_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_41 = str(user_ids_fintech_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_42 = str(user_ids_fintech_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_43 = str(user_ids_fintech_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_44 = str(user_ids_fintech_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_45 = str(user_ids_fintech_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_46 = str(user_ids_fintech_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_47 = str(user_ids_fintech_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_48 = str(user_ids_fintech_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_fintech_49 = str(user_ids_fintech_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_fintech_split))):
    print('user_ids_fintech_{},'.format(x))
# Out:
# user_ids_fintech_0,
# user_ids_fintech_1,
# user_ids_fintech_2,
# user_ids_fintech_3,
# user_ids_fintech_4,
# user_ids_fintech_5,
# user_ids_fintech_6,
# user_ids_fintech_7,
# user_ids_fintech_8,
# user_ids_fintech_9,
# user_ids_fintech_10,
# user_ids_fintech_11,
# user_ids_fintech_12,
# user_ids_fintech_13,
# user_ids_fintech_14,
# user_ids_fintech_15,
# user_ids_fintech_16,
# user_ids_fintech_17,
# user_ids_fintech_18,
# user_ids_fintech_19,
# user_ids_fintech_20,
# user_ids_fintech_21,
# user_ids_fintech_22,
# user_ids_fintech_23,
# user_ids_fintech_24,
# user_ids_fintech_25,
# user_ids_fintech_26,
# user_ids_fintech_27,
# user_ids_fintech_28,
# user_ids_fintech_29,
# user_ids_fintech_30,
# user_ids_fintech_31,
# user_ids_fintech_32,
# user_ids_fintech_33,
# user_ids_fintech_34,
# user_ids_fintech_35,
# user_ids_fintech_36,
# user_ids_fintech_37,
# user_ids_fintech_38,
# user_ids_fintech_39,
# user_ids_fintech_40,
# user_ids_fintech_41,
# user_ids_fintech_42,
# ...

# %%
user_ids_fintech_list = [
    
user_ids_fintech_0,
user_ids_fintech_1,
user_ids_fintech_2,
user_ids_fintech_3,
user_ids_fintech_4,
user_ids_fintech_5,
user_ids_fintech_6,
user_ids_fintech_7,
user_ids_fintech_8,
user_ids_fintech_9,
user_ids_fintech_10,
user_ids_fintech_11,
user_ids_fintech_12,
user_ids_fintech_13,
user_ids_fintech_14,
user_ids_fintech_15,
user_ids_fintech_16,
user_ids_fintech_17,
user_ids_fintech_18,
user_ids_fintech_19,
user_ids_fintech_20,
user_ids_fintech_21,
user_ids_fintech_22,
user_ids_fintech_23,
user_ids_fintech_24,
user_ids_fintech_25,
user_ids_fintech_26,
user_ids_fintech_27,
user_ids_fintech_28,
user_ids_fintech_29,
user_ids_fintech_30,
user_ids_fintech_31,
user_ids_fintech_32,
user_ids_fintech_33,
user_ids_fintech_34,
user_ids_fintech_35,
user_ids_fintech_36,
user_ids_fintech_37,
user_ids_fintech_38,
user_ids_fintech_39,
user_ids_fintech_40,
user_ids_fintech_41,
user_ids_fintech_42,
user_ids_fintech_43,
user_ids_fintech_44,
user_ids_fintech_45,
user_ids_fintech_46,
user_ids_fintech_47,
user_ids_fintech_48,
user_ids_fintech_49
    
]

# %%
user_fintech = []

# %%
for x in user_ids_fintech_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_fintech.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 0 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_fintech))):
    try:
        print(user_fintech[x]['errors'])
    except:
        pass

# %%
with open('user_fintech.json', 'w', encoding='utf-8') as f:
    json.dump(user_fintech, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "financial" tweets

# %%
user_ids_financial_split = list(split_list(user_ids_financial, 100))

# %%
for x in list(range(0,len(user_ids_financial_split))):
    print("user_ids_financial_{} = str(user_ids_financial_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_financial_0 = str(user_ids_financial_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_1 = str(user_ids_financial_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_2 = str(user_ids_financial_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_3 = str(user_ids_financial_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_4 = str(user_ids_financial_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_5 = str(user_ids_financial_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_6 = str(user_ids_financial_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_7 = str(user_ids_financial_split[7]).replace(', ',',').replace('[','').replace(']','')
# user_ids_financial_8 = str(user_ids_financial_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_financial_0 = str(user_ids_financial_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_1 = str(user_ids_financial_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_2 = str(user_ids_financial_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_3 = str(user_ids_financial_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_4 = str(user_ids_financial_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_5 = str(user_ids_financial_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_6 = str(user_ids_financial_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_7 = str(user_ids_financial_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_8 = str(user_ids_financial_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_9 = str(user_ids_financial_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_10 = str(user_ids_financial_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_11 = str(user_ids_financial_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_12 = str(user_ids_financial_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_13 = str(user_ids_financial_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_14 = str(user_ids_financial_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_15 = str(user_ids_financial_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_16 = str(user_ids_financial_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_17 = str(user_ids_financial_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_18 = str(user_ids_financial_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_19 = str(user_ids_financial_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_20 = str(user_ids_financial_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_21 = str(user_ids_financial_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_22 = str(user_ids_financial_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_23 = str(user_ids_financial_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_24 = str(user_ids_financial_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_25 = str(user_ids_financial_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_26 = str(user_ids_financial_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_27 = str(user_ids_financial_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_28 = str(user_ids_financial_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_29 = str(user_ids_financial_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_30 = str(user_ids_financial_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_31 = str(user_ids_financial_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_32 = str(user_ids_financial_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_33 = str(user_ids_financial_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_34 = str(user_ids_financial_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_35 = str(user_ids_financial_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_36 = str(user_ids_financial_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_37 = str(user_ids_financial_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_38 = str(user_ids_financial_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_39 = str(user_ids_financial_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_40 = str(user_ids_financial_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_41 = str(user_ids_financial_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_42 = str(user_ids_financial_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_43 = str(user_ids_financial_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_44 = str(user_ids_financial_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_45 = str(user_ids_financial_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_46 = str(user_ids_financial_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_47 = str(user_ids_financial_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_48 = str(user_ids_financial_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_financial_49 = str(user_ids_financial_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_financial_split))):
    print('user_ids_financial_{},'.format(x))
# Out:
# user_ids_financial_0,
# user_ids_financial_1,
# user_ids_financial_2,
# user_ids_financial_3,
# user_ids_financial_4,
# user_ids_financial_5,
# user_ids_financial_6,
# user_ids_financial_7,
# user_ids_financial_8,
# user_ids_financial_9,
# user_ids_financial_10,
# user_ids_financial_11,
# user_ids_financial_12,
# user_ids_financial_13,
# user_ids_financial_14,
# user_ids_financial_15,
# user_ids_financial_16,
# user_ids_financial_17,
# user_ids_financial_18,
# user_ids_financial_19,
# user_ids_financial_20,
# user_ids_financial_21,
# user_ids_financial_22,
# user_ids_financial_23,
# user_ids_financial_24,
# user_ids_financial_25,
# user_ids_financial_26,
# user_ids_financial_27,
# user_ids_financial_28,
# user_ids_financial_29,
# user_ids_financial_30,
# user_ids_financial_31,
# user_ids_financial_32,
# user_ids_financial_33,
# user_ids_financial_34,
# user_ids_financial_35,
# user_ids_financial_36,
# user_ids_financial_37,
# user_ids_financial_38,
# user_ids_financial_39,
# ...

# %%
user_ids_financial_list = [
    
user_ids_financial_0,
user_ids_financial_1,
user_ids_financial_2,
user_ids_financial_3,
user_ids_financial_4,
user_ids_financial_5,
user_ids_financial_6,
user_ids_financial_7,
user_ids_financial_8,
user_ids_financial_9,
user_ids_financial_10,
user_ids_financial_11,
user_ids_financial_12,
user_ids_financial_13,
user_ids_financial_14,
user_ids_financial_15,
user_ids_financial_16,
user_ids_financial_17,
user_ids_financial_18,
user_ids_financial_19,
user_ids_financial_20,
user_ids_financial_21,
user_ids_financial_22,
user_ids_financial_23,
user_ids_financial_24,
user_ids_financial_25,
user_ids_financial_26,
user_ids_financial_27,
user_ids_financial_28,
user_ids_financial_29,
user_ids_financial_30,
user_ids_financial_31,
user_ids_financial_32,
user_ids_financial_33,
user_ids_financial_34,
user_ids_financial_35,
user_ids_financial_36,
user_ids_financial_37,
user_ids_financial_38,
user_ids_financial_39,
user_ids_financial_40,
user_ids_financial_41,
user_ids_financial_42,
user_ids_financial_43,
user_ids_financial_44,
user_ids_financial_45,
user_ids_financial_46,
user_ids_financial_47,
user_ids_financial_48,
user_ids_financial_49
    
]

# %%
user_financial = []

# %%
for x in user_ids_financial_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_financial.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 1 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_financial))):
    try:
        print(user_financial[x]['errors'])
    except:
        pass
# Out:
# [{'value': '1212494311708741632', 'detail': 'Could not find user with id: [1212494311708741632].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'detail': 'Could not find user with ids: [1212494311708741632].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1212494311708741632', 'resource_type': 'user'}]

# %%
with open('user_financial.json', 'w', encoding='utf-8') as f:
    json.dump(user_financial, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "money management" tweets

# %%
user_ids_money_management_split = list(split_list(user_ids_money_management, 100))

# %%
for x in list(range(0,len(user_ids_money_management_split))):
    print("user_ids_money_management_{} = str(user_ids_money_management_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_money_management_0 = str(user_ids_money_management_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_1 = str(user_ids_money_management_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_2 = str(user_ids_money_management_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_3 = str(user_ids_money_management_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_4 = str(user_ids_money_management_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_5 = str(user_ids_money_management_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_6 = str(user_ids_money_management_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_money_management_7 = str(user_ids_money_management_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_money_management_0 = str(user_ids_money_management_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_1 = str(user_ids_money_management_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_2 = str(user_ids_money_management_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_3 = str(user_ids_money_management_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_4 = str(user_ids_money_management_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_5 = str(user_ids_money_management_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_6 = str(user_ids_money_management_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_7 = str(user_ids_money_management_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_8 = str(user_ids_money_management_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_9 = str(user_ids_money_management_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_10 = str(user_ids_money_management_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_11 = str(user_ids_money_management_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_12 = str(user_ids_money_management_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_13 = str(user_ids_money_management_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_14 = str(user_ids_money_management_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_15 = str(user_ids_money_management_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_16 = str(user_ids_money_management_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_17 = str(user_ids_money_management_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_18 = str(user_ids_money_management_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_19 = str(user_ids_money_management_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_20 = str(user_ids_money_management_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_21 = str(user_ids_money_management_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_22 = str(user_ids_money_management_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_23 = str(user_ids_money_management_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_24 = str(user_ids_money_management_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_25 = str(user_ids_money_management_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_26 = str(user_ids_money_management_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_27 = str(user_ids_money_management_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_28 = str(user_ids_money_management_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_29 = str(user_ids_money_management_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_30 = str(user_ids_money_management_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_31 = str(user_ids_money_management_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_32 = str(user_ids_money_management_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_33 = str(user_ids_money_management_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_34 = str(user_ids_money_management_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_35 = str(user_ids_money_management_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_36 = str(user_ids_money_management_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_37 = str(user_ids_money_management_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_38 = str(user_ids_money_management_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_39 = str(user_ids_money_management_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_40 = str(user_ids_money_management_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_41 = str(user_ids_money_management_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_42 = str(user_ids_money_management_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_43 = str(user_ids_money_management_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_44 = str(user_ids_money_management_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_45 = str(user_ids_money_management_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_46 = str(user_ids_money_management_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_47 = str(user_ids_money_management_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_48 = str(user_ids_money_management_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_money_management_49 = str(user_ids_money_management_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_money_management_split))):
    print('user_ids_money_management_{},'.format(x))
# Out:
# user_ids_money_management_0,
# user_ids_money_management_1,
# user_ids_money_management_2,
# user_ids_money_management_3,
# user_ids_money_management_4,
# user_ids_money_management_5,
# user_ids_money_management_6,
# user_ids_money_management_7,
# user_ids_money_management_8,
# user_ids_money_management_9,
# user_ids_money_management_10,
# user_ids_money_management_11,
# user_ids_money_management_12,
# user_ids_money_management_13,
# user_ids_money_management_14,
# user_ids_money_management_15,
# user_ids_money_management_16,
# user_ids_money_management_17,
# user_ids_money_management_18,
# user_ids_money_management_19,
# user_ids_money_management_20,
# user_ids_money_management_21,
# user_ids_money_management_22,
# user_ids_money_management_23,
# user_ids_money_management_24,
# user_ids_money_management_25,
# user_ids_money_management_26,
# user_ids_money_management_27,
# user_ids_money_management_28,
# user_ids_money_management_29,
# user_ids_money_management_30,
# ...

# %%
user_ids_money_management_list = [
    
user_ids_money_management_0,
user_ids_money_management_1,
user_ids_money_management_2,
user_ids_money_management_3,
user_ids_money_management_4,
user_ids_money_management_5,
user_ids_money_management_6,
user_ids_money_management_7,
user_ids_money_management_8,
user_ids_money_management_9,
user_ids_money_management_10,
user_ids_money_management_11,
user_ids_money_management_12,
user_ids_money_management_13,
user_ids_money_management_14,
user_ids_money_management_15,
user_ids_money_management_16,
user_ids_money_management_17,
user_ids_money_management_18,
user_ids_money_management_19,
user_ids_money_management_20,
user_ids_money_management_21,
user_ids_money_management_22,
user_ids_money_management_23,
user_ids_money_management_24,
user_ids_money_management_25,
user_ids_money_management_26,
user_ids_money_management_27,
user_ids_money_management_28,
user_ids_money_management_29,
user_ids_money_management_30,
user_ids_money_management_31,
user_ids_money_management_32,
user_ids_money_management_33,
user_ids_money_management_34,
user_ids_money_management_35,
user_ids_money_management_36,
user_ids_money_management_37,
user_ids_money_management_38,
user_ids_money_management_39,
user_ids_money_management_40,
user_ids_money_management_41,
user_ids_money_management_42,
user_ids_money_management_43,
user_ids_money_management_44,
user_ids_money_management_45,
user_ids_money_management_46,
user_ids_money_management_47,
user_ids_money_management_48,
user_ids_money_management_49
    
]

# %%
user_money_management = []

# %%
for x in user_ids_money_management_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_money_management.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 0 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_money_management))):
    try:
        print(user_money_management[x]['errors'])
    except:
        pass

# %%
with open('user_money_management.json', 'w', encoding='utf-8') as f:
    json.dump(user_money_management, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "stocks" tweets

# %%
user_ids_stocks_split = list(split_list(user_ids_stocks, 100))

# %%
for x in list(range(0,len(user_ids_stocks_split))):
    print("user_ids_stocks_{} = str(user_ids_stocks_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_stocks_0 = str(user_ids_stocks_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_1 = str(user_ids_stocks_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_2 = str(user_ids_stocks_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_3 = str(user_ids_stocks_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_4 = str(user_ids_stocks_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_5 = str(user_ids_stocks_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_6 = str(user_ids_stocks_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_7 = str(user_ids_stocks_split[7]).replace(', ',',').replace('[','').replace(']','')
# user_ids_stocks_8 = str(user_ids_stocks_split[8]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_stocks_0 = str(user_ids_stocks_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_1 = str(user_ids_stocks_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_2 = str(user_ids_stocks_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_3 = str(user_ids_stocks_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_4 = str(user_ids_stocks_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_5 = str(user_ids_stocks_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_6 = str(user_ids_stocks_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_7 = str(user_ids_stocks_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_8 = str(user_ids_stocks_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_9 = str(user_ids_stocks_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_10 = str(user_ids_stocks_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_11 = str(user_ids_stocks_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_12 = str(user_ids_stocks_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_13 = str(user_ids_stocks_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_14 = str(user_ids_stocks_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_15 = str(user_ids_stocks_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_16 = str(user_ids_stocks_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_17 = str(user_ids_stocks_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_18 = str(user_ids_stocks_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_19 = str(user_ids_stocks_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_20 = str(user_ids_stocks_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_21 = str(user_ids_stocks_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_22 = str(user_ids_stocks_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_23 = str(user_ids_stocks_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_24 = str(user_ids_stocks_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_25 = str(user_ids_stocks_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_26 = str(user_ids_stocks_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_27 = str(user_ids_stocks_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_28 = str(user_ids_stocks_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_29 = str(user_ids_stocks_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_30 = str(user_ids_stocks_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_31 = str(user_ids_stocks_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_32 = str(user_ids_stocks_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_33 = str(user_ids_stocks_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_34 = str(user_ids_stocks_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_35 = str(user_ids_stocks_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_36 = str(user_ids_stocks_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_37 = str(user_ids_stocks_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_38 = str(user_ids_stocks_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_39 = str(user_ids_stocks_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_40 = str(user_ids_stocks_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_41 = str(user_ids_stocks_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_42 = str(user_ids_stocks_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_43 = str(user_ids_stocks_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_44 = str(user_ids_stocks_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_45 = str(user_ids_stocks_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_stocks_46 = str(user_ids_stocks_split[46]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_stocks_split))):
    print('user_ids_stocks_{},'.format(x))
# Out:
# user_ids_stocks_0,
# user_ids_stocks_1,
# user_ids_stocks_2,
# user_ids_stocks_3,
# user_ids_stocks_4,
# user_ids_stocks_5,
# user_ids_stocks_6,
# user_ids_stocks_7,
# user_ids_stocks_8,
# user_ids_stocks_9,
# user_ids_stocks_10,
# user_ids_stocks_11,
# user_ids_stocks_12,
# user_ids_stocks_13,
# user_ids_stocks_14,
# user_ids_stocks_15,
# user_ids_stocks_16,
# user_ids_stocks_17,
# user_ids_stocks_18,
# user_ids_stocks_19,
# user_ids_stocks_20,
# user_ids_stocks_21,
# user_ids_stocks_22,
# user_ids_stocks_23,
# user_ids_stocks_24,
# user_ids_stocks_25,
# user_ids_stocks_26,
# user_ids_stocks_27,
# user_ids_stocks_28,
# user_ids_stocks_29,
# user_ids_stocks_30,
# user_ids_stocks_31,
# user_ids_stocks_32,
# user_ids_stocks_33,
# user_ids_stocks_34,
# user_ids_stocks_35,
# user_ids_stocks_36,
# user_ids_stocks_37,
# user_ids_stocks_38,
# user_ids_stocks_39,
# user_ids_stocks_40,
# user_ids_stocks_41,
# user_ids_stocks_42,
# user_ids_stocks_43,
# user_ids_stocks_44,
# ...

# %%
user_ids_stocks_list = [
    
user_ids_stocks_0,
user_ids_stocks_1,
user_ids_stocks_2,
user_ids_stocks_3,
user_ids_stocks_4,
user_ids_stocks_5,
user_ids_stocks_6,
user_ids_stocks_7,
user_ids_stocks_8,
user_ids_stocks_9,
user_ids_stocks_10,
user_ids_stocks_11,
user_ids_stocks_12,
user_ids_stocks_13,
user_ids_stocks_14,
user_ids_stocks_15,
user_ids_stocks_16,
user_ids_stocks_17,
user_ids_stocks_18,
user_ids_stocks_19,
user_ids_stocks_20,
user_ids_stocks_21,
user_ids_stocks_22,
user_ids_stocks_23,
user_ids_stocks_24,
user_ids_stocks_25,
user_ids_stocks_26,
user_ids_stocks_27,
user_ids_stocks_28,
user_ids_stocks_29,
user_ids_stocks_30,
user_ids_stocks_31,
user_ids_stocks_32,
user_ids_stocks_33,
user_ids_stocks_34,
user_ids_stocks_35,
user_ids_stocks_36,
user_ids_stocks_37,
user_ids_stocks_38,
user_ids_stocks_39,
user_ids_stocks_40,
user_ids_stocks_41,
user_ids_stocks_42,
user_ids_stocks_43,
user_ids_stocks_44,
user_ids_stocks_45,
user_ids_stocks_46
    
]

# %%
user_stocks = []

# %%
for x in user_ids_stocks_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('AAAAAAAAAAAAAAAAAAAAAAvlCAEAAAAAwtmjoshI4rUavHrUhCkw%2F6lBezc%3DP8G7CwGZUMYAfcgjcrX8zuRcGCzEn7VDudpctRjNMPRMo762cz')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_stocks.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 3 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_stocks))):
    try:
        print(user_stocks[x]['errors'])
    except:
        pass
# Out:
# [{'detail': 'Could not find user with ids: [1101843895191777280].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1101843895191777280', 'resource_type': 'user'}]
# [{'detail': 'Could not find user with ids: [141545769].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '141545769', 'resource_type': 'user'}]
# [{'detail': 'Could not find user with ids: [3044438865].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '3044438865', 'resource_type': 'user'}]

# %%
with open('user_stocks.json', 'w', encoding='utf-8') as f:
    json.dump(user_stocks, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Query users for "transaction" tweets

# %%
user_ids_transaction_split = list(split_list(user_ids_transaction, 100))

# %%
for x in list(range(0,len(user_ids_transaction_split))):
    print("user_ids_transaction_{} = str(user_ids_transaction_split[{}]).replace(', ',',').replace('[','').replace(']','')".format(x,x))
# Out:
# user_ids_transaction_0 = str(user_ids_transaction_split[0]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_1 = str(user_ids_transaction_split[1]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_2 = str(user_ids_transaction_split[2]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_3 = str(user_ids_transaction_split[3]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_4 = str(user_ids_transaction_split[4]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_5 = str(user_ids_transaction_split[5]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_6 = str(user_ids_transaction_split[6]).replace(', ',',').replace('[','').replace(']','')
# user_ids_transaction_7 = str(user_ids_transaction_split[7]).replace(', ',',').replace('[','').replace(']','')
# ...

# %%
user_ids_transaction_0 = str(user_ids_transaction_split[0]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_1 = str(user_ids_transaction_split[1]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_2 = str(user_ids_transaction_split[2]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_3 = str(user_ids_transaction_split[3]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_4 = str(user_ids_transaction_split[4]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_5 = str(user_ids_transaction_split[5]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_6 = str(user_ids_transaction_split[6]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_7 = str(user_ids_transaction_split[7]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_8 = str(user_ids_transaction_split[8]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_9 = str(user_ids_transaction_split[9]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_10 = str(user_ids_transaction_split[10]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_11 = str(user_ids_transaction_split[11]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_12 = str(user_ids_transaction_split[12]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_13 = str(user_ids_transaction_split[13]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_14 = str(user_ids_transaction_split[14]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_15 = str(user_ids_transaction_split[15]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_16 = str(user_ids_transaction_split[16]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_17 = str(user_ids_transaction_split[17]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_18 = str(user_ids_transaction_split[18]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_19 = str(user_ids_transaction_split[19]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_20 = str(user_ids_transaction_split[20]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_21 = str(user_ids_transaction_split[21]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_22 = str(user_ids_transaction_split[22]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_23 = str(user_ids_transaction_split[23]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_24 = str(user_ids_transaction_split[24]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_25 = str(user_ids_transaction_split[25]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_26 = str(user_ids_transaction_split[26]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_27 = str(user_ids_transaction_split[27]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_28 = str(user_ids_transaction_split[28]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_29 = str(user_ids_transaction_split[29]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_30 = str(user_ids_transaction_split[30]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_31 = str(user_ids_transaction_split[31]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_32 = str(user_ids_transaction_split[32]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_33 = str(user_ids_transaction_split[33]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_34 = str(user_ids_transaction_split[34]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_35 = str(user_ids_transaction_split[35]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_36 = str(user_ids_transaction_split[36]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_37 = str(user_ids_transaction_split[37]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_38 = str(user_ids_transaction_split[38]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_39 = str(user_ids_transaction_split[39]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_40 = str(user_ids_transaction_split[40]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_41 = str(user_ids_transaction_split[41]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_42 = str(user_ids_transaction_split[42]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_43 = str(user_ids_transaction_split[43]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_44 = str(user_ids_transaction_split[44]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_45 = str(user_ids_transaction_split[45]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_46 = str(user_ids_transaction_split[46]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_47 = str(user_ids_transaction_split[47]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_48 = str(user_ids_transaction_split[48]).replace(', ',',').replace('[','').replace(']','')
user_ids_transaction_49 = str(user_ids_transaction_split[49]).replace(', ',',').replace('[','').replace(']','')

# %%
for x in list(range(0,len(user_ids_transaction_split))):
    print('user_ids_transaction_{},'.format(x))
# Out:
# user_ids_transaction_0,
# user_ids_transaction_1,
# user_ids_transaction_2,
# user_ids_transaction_3,
# user_ids_transaction_4,
# user_ids_transaction_5,
# user_ids_transaction_6,
# user_ids_transaction_7,
# user_ids_transaction_8,
# user_ids_transaction_9,
# user_ids_transaction_10,
# user_ids_transaction_11,
# user_ids_transaction_12,
# user_ids_transaction_13,
# user_ids_transaction_14,
# user_ids_transaction_15,
# user_ids_transaction_16,
# user_ids_transaction_17,
# user_ids_transaction_18,
# user_ids_transaction_19,
# user_ids_transaction_20,
# user_ids_transaction_21,
# user_ids_transaction_22,
# user_ids_transaction_23,
# user_ids_transaction_24,
# user_ids_transaction_25,
# user_ids_transaction_26,
# user_ids_transaction_27,
# user_ids_transaction_28,
# user_ids_transaction_29,
# user_ids_transaction_30,
# user_ids_transaction_31,
# user_ids_transaction_32,
# user_ids_transaction_33,
# user_ids_transaction_34,
# user_ids_transaction_35,
# user_ids_transaction_36,
# ...

# %%
user_ids_transaction_list = [
    
user_ids_transaction_0,
user_ids_transaction_1,
user_ids_transaction_2,
user_ids_transaction_3,
user_ids_transaction_4,
user_ids_transaction_5,
user_ids_transaction_6,
user_ids_transaction_7,
user_ids_transaction_8,
user_ids_transaction_9,
user_ids_transaction_10,
user_ids_transaction_11,
user_ids_transaction_12,
user_ids_transaction_13,
user_ids_transaction_14,
user_ids_transaction_15,
user_ids_transaction_16,
user_ids_transaction_17,
user_ids_transaction_18,
user_ids_transaction_19,
user_ids_transaction_20,
user_ids_transaction_21,
user_ids_transaction_22,
user_ids_transaction_23,
user_ids_transaction_24,
user_ids_transaction_25,
user_ids_transaction_26,
user_ids_transaction_27,
user_ids_transaction_28,
user_ids_transaction_29,
user_ids_transaction_30,
user_ids_transaction_31,
user_ids_transaction_32,
user_ids_transaction_33,
user_ids_transaction_34,
user_ids_transaction_35,
user_ids_transaction_36,
user_ids_transaction_37,
user_ids_transaction_38,
user_ids_transaction_39,
user_ids_transaction_40,
user_ids_transaction_41,
user_ids_transaction_42,
user_ids_transaction_43,
user_ids_transaction_44,
user_ids_transaction_45,
user_ids_transaction_46,
user_ids_transaction_47,
user_ids_transaction_48,
user_ids_transaction_49
    
]

# %%
user_transaction = []

# %%
for x in user_ids_transaction_list:
    try:
        search_headers = {
            'Authorization': 'Bearer {}'.format('YOUR_ACCESS_TOKEN')    
        }

        search_params = {
            'ids': x,
            'format': 'detailed',
            'user.format': 'detailed',
        }

        search_url = 'https://api.twitter.com/labs/1/users'

        search = requests.get(search_url, headers=search_headers, params=search_params)
        user_transaction.append(search.json())
    except:
        continue

# %% [markdown]
# **Looks like there are 5 user ids missing from the tweets that we called earlier.**

# %%
for x in list(range(0,len(user_transaction))):
    try:
        print(user_transaction[x]['errors'])
    except:
        pass
# Out:
# [{'value': '1148987694598381569', 'detail': 'Could not find user with id: [1148987694598381569].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'value': '1148987694598381569', 'detail': 'Could not find user with id: [1148987694598381569].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'value': '1148987694598381569', 'detail': 'Could not find user with id: [1148987694598381569].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'resource_type': 'user', 'parameter': 'id'}, {'detail': 'Could not find user with ids: [1148987694598381569].', 'type': 'https://api.twitter.com/labs/1/problems/resource-not-found', 'title': 'Not Found Error', 'parameter': 'ids', 'value': '1148987694598381569', 'resource_type': 'user'}]
# ...

# %%
with open('user_transaction.json', 'w', encoding='utf-8') as f:
    json.dump(user_transaction, f, ensure_ascii=False, indent=4)
